# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import statsmodels.api as sm
from statsmodels.stats.stattools import durbin_watson
from scipy.stats import ttest_ind, chi2
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import warnings

from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from scipy.stats import ttest_ind, chi2_contingency

# %%
data = pd.read_excel("df_total.xlsx")

# %%
# 去掉8和999
# 轉成字串並去除空白
data['Part_nbr'] = data['Part_nbr'].astype(str).str.strip()

# 建立條件
mask = data['Part_nbr'].str.startswith('8') | data['Part_nbr'].str.startswith('999')

# 過濾資料
data = data.loc[~mask].copy()

# # 驗證
# print("原始數量:", len(data))
# print("過濾後數量:", len(data1))

# # 檢查是否還有 '8' 或 '999' 開頭的
# print(data[data1['Part_nbr'].str.startswith('8')])
# print(data[data1['Part_nbr'].str.startswith('999')])

# %% [markdown]
# <p style = "font_size: 16; color: blue;">欄位選擇</p>

# %%
data = data[['Part_nbr', 'Lot_nbr', 'Layer', 'd_Layer','AVGX','AVGY','MacNo', 'MacRecipe', 'mtl_desc2', 'vend_nbr',
         'layer_2Thick', 'plate_mtl_desc1', 'plate_mtl_desc2','plate_vend_nbr', 'plate_layer_2Thick', 'plate_RC_value',
         'Residual Copper Rate', 'glass_fabric_thickness(mm)',
         'use_cu_upper_thickness', 'use_cu_lower_thickness', 'use_cu_type',
         'glass_fabric_type', 'short', 'long', 'd_PSVarX', 'd_PSVarY']]

data = data.copy()
data['layer_2Thick'] = data['layer_2Thick'].replace('None', np.nan).astype(float)
data['layer_2Thick'] = data['layer_2Thick'].astype('float')

data['plate_mtl_desc2'] = data['plate_mtl_desc2'].astype('float')

data['plate_layer_2Thick'] = pd.to_numeric(data['plate_layer_2Thick'], errors='coerce')
data = data.rename(columns={"glass_fabric_thickness(mm)": "glass_fabric_thickness_mm"})
data = data.rename(columns={"Residual Copper Rate": "Residual_Copper_Rate"})

# %% [markdown]
# <p style = "font_size: 16; color: red;">Full Data</p>

# %% [markdown]
# <p style = "font_size: 16; color: blue;">合併少數料號</p>

# %%
df = data

# 找出小於閾值的料號列表
part_counts = df['Part_nbr'].value_counts()

threshold = 30
below_threshold_parts = part_counts[part_counts < threshold].index.tolist()

print(f"小於 {threshold} 筆數據的料號共有 {len(below_threshold_parts)} 個：")
# print(below_threshold_parts)
# Out:
# 小於 30 筆數據的料號共有 833 個：

# %%
# 計算各料號的觀測數
part_counts = df['Part_nbr'].value_counts()

threshold = 30
df['Part_nbr_grouped'] = np.where(df['Part_nbr'].map(part_counts) < threshold,   'OTHER', df['Part_nbr'])

# 按分位數合併（合併底部25%）
# quantile_threshold = part_counts.quantile(0.25)
# df['Part_nbr_grouped'] = np.where(df['Part_nbr'].map(part_counts) < quantile_threshold, 'OTHER', df['Part_nbr'])

# %% [markdown]
# <p style = "font_size: 16; color: blue;">Modeling 前處理</p>

# %% [markdown]
# <p style = "font_size: 14; color: green;">RC 處理</p>

# %%
# 以每個 lot的RC補NaN
l2_rc_map = (
    df[df['d_Layer'] == 'L2']
    .dropna(subset=['plate_RC_value'])
    .groupby('Lot_nbr')['plate_RC_value']
    .first()
)

first_rc_map = (
    df.dropna(subset=['plate_RC_value'])
    .groupby('Lot_nbr')['plate_RC_value']
    .first()
)

final_rc_map = l2_rc_map.combine_first(first_rc_map)

df['plate_RC_value'] = df['plate_RC_value'].fillna(df['Lot_nbr'].map(final_rc_map))

# %%
# 剩下的用整體中位數補
overall_median_rc = df['plate_RC_value'].median()

rc_missing_parts = df[df['plate_RC_value'].isna()].groupby('Part_nbr')['plate_RC_value'].count()

all_parts_count = df.groupby('Part_nbr')['plate_RC_value'].count()

rc_missing_parts_aligned = rc_missing_parts.reindex(all_parts_count.index, fill_value=0)

fully_missing_parts = all_parts_count[rc_missing_parts_aligned == all_parts_count].index

df.loc[df['Part_nbr'].isin(fully_missing_parts), 'plate_RC_value'] = overall_median_rc

# %% [markdown]
# <p style="font-size: 14px; color: blue;"> 找出遺失值數量(比例)</p>

# %%
features_with_na = [features for features in df.columns if df[features].isnull().sum() > 1]

for feature in features_with_na:
    print(feature, df[feature].isnull().sum(), 'missing values')
# Out:
# MacRecipe 154 missing values
# layer_2Thick 4330 missing values
# plate_layer_2Thick 23796 missing values
# glass_fabric_thickness_mm 778 missing values
# use_cu_upper_thickness 778 missing values
# use_cu_lower_thickness 778 missing values
# use_cu_type 1407 missing values
# glass_fabric_type 1683 missing values
# short 3317 missing values
# long 3317 missing values

# %% [markdown]
# <p style="font-size: 14px; color: blue;">找出有遺失值的數值型特徵<p>

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtypes!='O']

print('Number of features: ',len(numerical_features))

# df[numerical_features].head()
# Out:
# Number of features:  16

# %% [markdown]
# <p style="font-size: 14px; color: blue;">找出有遺失值的離散型特徵<p>

# %%
discrete_feature = [feature for feature in numerical_features if len(df[feature].unique())<25]
print('Discrete variables count: {}'.format(len(discrete_feature)))
discrete_feature
# Out:
# Discrete variables count: 3
# ['MacNo', 'use_cu_upper_thickness', 'use_cu_lower_thickness']

# %% [markdown]
# <p style="font-size: 14px; color: blue;">找出有遺失值的類別型特徵<p>

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']
print(len(categorical_features))
print(categorical_features)
# Out:
# 11
# ['Part_nbr', 'Lot_nbr', 'Layer', 'd_Layer', 'MacRecipe', 'vend_nbr', 'plate_mtl_desc1', 'plate_vend_nbr', 'use_cu_type', 'glass_fabric_type', 'Part_nbr_grouped']

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature, len(df[feature].unique())))
# Out:
# The feature is Part_nbr and number of categories are 1230
# The feature is Lot_nbr and number of categories are 4168
# The feature is Layer and number of categories are 17
# The feature is d_Layer and number of categories are 40
# The feature is MacRecipe and number of categories are 179
# The feature is vend_nbr and number of categories are 11
# The feature is plate_mtl_desc1 and number of categories are 96
# The feature is plate_vend_nbr and number of categories are 9
# The feature is use_cu_type and number of categories are 32
# The feature is glass_fabric_type and number of categories are 77
# The feature is Part_nbr_grouped and number of categories are 398

# %% [markdown]
# <p style="font-size: 14px; color: blue;">處理離散型遺失值<p>

# %%
features_nan = [feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtype=='O']

for feature in features_nan:
    print('{}: {} missing value'.format(feature, df[feature].isnull().sum()))
# Out:
# MacRecipe: 154 missing value
# use_cu_type: 1407 missing value
# glass_fabric_type: 1683 missing value

# %%
#這裡是將有nan的data挑出來，把nan換成Missing 標籤，因為等等要編碼(encode)，它不能是nan
def replace_cat_feature(data, features_nan):
    data1 = data.copy()
    data1[features_nan]=data[features_nan].fillna('Missing')
    return data1

df = replace_cat_feature(df, features_nan)

#nan沒有了，變成了Missing 標籤，所以都是0
df[features_nan].isnull().sum()
# Out:
# MacRecipe            0
# use_cu_type          0
# glass_fabric_type    0
# dtype: int64

# %% [markdown]
# <p style="font-size: 14px; color: blue;">處理數值型遺失值<p>

# %%
numerical_with_nan = [feature for feature in df.columns if df[feature].isnull().sum()>1 and df[feature].dtype!='O']

for feature in numerical_with_nan:
    print('{}: {} missing value'.format(feature, df[feature].isnull().sum()))
# Out:
# layer_2Thick: 4330 missing value
# plate_layer_2Thick: 23796 missing value
# glass_fabric_thickness_mm: 778 missing value
# use_cu_upper_thickness: 778 missing value
# use_cu_lower_thickness: 778 missing value
# short: 3317 missing value
# long: 3317 missing value

# %%
# 先對每個數值欄位進行分群中位數填補
for feature in numerical_with_nan:
    # 新增一欄標示缺失
    df[feature + '_nan'] = np.where(df[feature].isnull(), 1, 0)
    
    # 對每個 (Part_nbr, Lot_nbr) 群組算中位數來填補
    df[feature] = df.groupby(['Part_nbr', 'Lot_nbr'])[feature]\
                        .transform(lambda x: x.fillna(x.median()))

# 若還有 NaN，用整體中位數補
for feature in numerical_with_nan:
    df[feature] = df[feature].fillna(df[feature].median())
# Out:
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# ...
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
df[numerical_with_nan].isnull().sum()
# Out:
# layer_2Thick                 0
# plate_layer_2Thick           0
# glass_fabric_thickness_mm    0
# use_cu_upper_thickness       0
# use_cu_lower_thickness       0
# short                        0
# long                         0
# dtype: int64

# %% [markdown]
# <p style="font-size: 14px; color: blue;">處理類別型遺失值<p>

# %%
categorical_feattures = [feature for feature in df.columns if df[feature].dtypes=='O' ]
categorical_feattures
# Out:
# ['Part_nbr',
#  'Lot_nbr',
#  'Layer',
#  'd_Layer',
#  'MacRecipe',
#  'vend_nbr',
#  'plate_mtl_desc1',
#  'plate_vend_nbr',
#  'use_cu_type',
#  'glass_fabric_type',
#  'Part_nbr_grouped']

# %%
# 你想保留的欄位（不處理的）
excluded_features = ['Part_nbr', 'Lot_nbr', 'Layer', 'd_Layer', 'Part_nbr_grouped']

# 建立一個新的列表，過濾掉 excluded_features
processed_categorical_features = [f for f in categorical_features if f not in excluded_features]

# rare category 合併
for feature in processed_categorical_features:
    temp = df.groupby(feature)['d_PSVarX'].count() / len(df)
    temp_df = temp[temp > 0.01].index
    df[feature] = np.where(df[feature].isin(temp_df), df[feature], 'rare cate')

# target mean encoding
for feature in processed_categorical_features:
    labels_ordered = df.groupby([feature])['d_PSVarX'].mean().sort_values().index
    labels_ordered = {k: i for i, k in enumerate(labels_ordered, 0)}
    df[feature] = df[feature].map(labels_ordered)

# %%
df = df[df['d_PSVarX'] < 4000]
df = df[df['d_PSVarY'] < 4000]
plt.figure(figsize=(10,5))
plt.scatter(df['d_PSVarX'],df['d_PSVarY'])

# %% [markdown]
# <p style="font-size: 14px; color: green;">拆分出異常資料<p>

# %%
target = 'd_PSVarX'
group_cols = ['Part_nbr', 'Lot_nbr']   # 判定「同一批」用的欄位
group_for_mixed = 'Part_nbr_grouped'           # mixed model 的 groups

df_unfiltered = df

# 使用 group_cols 當作 batch key
df_unfiltered['_batch_key'] = df_unfiltered[group_cols].astype(str).agg('__'.join, axis=1)

batch_stats = df_unfiltered.groupby('_batch_key')[target].agg(['count', 'mean', 'min', 'max']).reset_index()
batch_stats['range'] = batch_stats['max'] - batch_stats['min']

# 規則： range <= 3 且 mean in [0,5] -> normal
batch_stats['is_normal'] = (batch_stats['range'] <= 3) & (batch_stats['mean'] >= 0) & (batch_stats['mean'] <= 5)

# map 回原始 df
batch_flag = batch_stats.set_index('_batch_key')['is_normal'].to_dict()
df_unfiltered['batch_is_normal'] = df_unfiltered['_batch_key'].map(batch_flag)

# 切出 filtered df（只保留正常批）
df_filtered = df_unfiltered[df_unfiltered['batch_is_normal']].copy()
print("原始資料筆數:", len(df_unfiltered), "正常批資料筆數:", len(df_filtered))
print("總批數:", batch_stats.shape[0], "正常批數:", batch_stats['is_normal'].sum())
# Out:
# 原始資料筆數: 54485 正常批資料筆數: 29701
# 總批數: 4167 正常批數: 2496

# %% [markdown]
# <p style="font-size: 14px; color: green;">對異常部分的data做GMM<p>

# %%
df_outlier = df_unfiltered[~df_unfiltered['batch_is_normal']].copy()

# %%
# # 標準化
# features = ['MacNo','MacRecipe', 'mtl_desc2', 'vend_nbr', 'layer_2Thick', 'plate_mtl_desc1',
#             'plate_mtl_desc2', 'plate_vend_nbr', 'plate_layer_2Thick',
#             'plate_RC_value', 'Residual_Copper_Rate', 'glass_fabric_thickness_mm',
#             'use_cu_upper_thickness', 'use_cu_lower_thickness', 'use_cu_type',
#             'glass_fabric_type']

# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(df_outlier[features])

# # 用 BIC 選最佳群數
# bic_scores = []
# n_components_range = range(2, 10)  # 群數範圍
# for n in n_components_range:
#     gmm = GaussianMixture(n_components=n, covariance_type='full', random_state=42)
#     gmm.fit(X_scaled)
#     bic_scores.append(gmm.bic(X_scaled))

# best_n = n_components_range[np.argmin(bic_scores)]
# print(f"num of best clusters: {best_n}")

# # 畫 BIC 曲線
# plt.figure(figsize=(10,5))
# plt.plot(n_components_range, bic_scores, marker='o')
# plt.xlabel('num of clusters')
# plt.ylabel('BIC')
# plt.title('num of best clusters by BIC')
# plt.show()

# # 用最佳群數建立 GMM
# gmm_best = GaussianMixture(n_components=best_n, covariance_type='full', random_state=123)
# labels = gmm_best.fit_predict(X_scaled)
# df_outlier['cluster'] = labels

# # # 用 PCA 降成 2D 繪圖（可視化）
# # pca = PCA(n_components=2)
# # X_pca = pca.fit_transform(X_scaled)
# # df_plot = pd.DataFrame(X_pca, columns=['PC1', 'PC2'])
# # df_plot['cluster'] = labels

# # plt.figure(figsize=(8,6))
# # sns.scatterplot(data=df_plot, x='PC1', y='PC2', hue='cluster', palette='Set2')
# # plt.title('GMM 分群結果 (PCA 2D 投影)')
# # plt.show()

# # 檢視各群特徵平均
# cluster_means = df_outlier.groupby('cluster')[features].mean()
# print(cluster_means)

process_cols = ['Part_nbr']

feature_cols = ["mtl_desc2", "layer_2Thick", "plate_layer_2Thick", "plate_RC_value", "Residual_Copper_Rate", "glass_fabric_thickness_mm", 
                "use_cu_upper_thickness", "short", "use_cu_lower_thickness"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_outlier[feature_cols])

# # # 用 BIC 選最佳群數
# bic_scores = []
# n_components_range = range(2, 10)  # 群數範圍
# for n in n_components_range:
#     gmm = GaussianMixture(n_components=n, covariance_type='full', random_state=123)
#     gmm.fit(X_scaled)
#     bic_scores.append(gmm.bic(X_scaled))

# best_n = n_components_range[np.argmin(bic_scores)]
# print(f"num of best clusters: {best_n}")

# # 畫 BIC 曲線
# plt.figure(figsize=(10,5))
# plt.plot(n_components_range, bic_scores, marker='o')
# plt.xlabel('num of clusters')
# plt.ylabel('BIC')
# plt.title('num of best clusters by BIC')
# plt.show()


def detect_anomalies(group, features, n_components):
    # 標準化
    X_scaled = StandardScaler().fit_transform(group[features].values)
    
    # GMM
    gmm = GaussianMixture(n_components=n_components, covariance_type='full', random_state=123)
    labels = gmm.fit_predict(X_scaled)

    # 找異常 cluster
    counts = pd.Series(labels).value_counts()
    anomaly_label = counts.idxmin()

    # 標註
    group_result = group.copy()
    group_result["is_anomaly"] = (labels == anomaly_label).astype(int)

    # 差異分析
    normal_data = group_result[group_result["is_anomaly"] == 0][features]
    anomaly_data = group_result[group_result["is_anomaly"] == 1][features]
    diff = anomaly_data.mean() - normal_data.mean()
    
    return group_result, diff

# 全資料找最佳群數
scaler = StandardScaler()
X_scaled_all = scaler.fit_transform(df_outlier[feature_cols])
bic_scores = []
n_components_range = range(2, 10)
for n in n_components_range:
    gmm = GaussianMixture(n_components=n, covariance_type='full', random_state=123)
    gmm.fit(X_scaled_all)
    bic_scores.append(gmm.bic(X_scaled_all))

best_n = n_components_range[np.argmin(bic_scores)]
print(f"Best number of clusters (global): {best_n}")

# 分組偵測
results = []
for cond, group in df_outlier.groupby(process_cols):
    if len(group) < 40:
        continue
    group_res, diff = detect_anomalies(group, feature_cols, best_n)
    results.append({
        "process_condition": cond,
        "sample_size": len(group),
        "anomaly_ratio": group_res["is_anomaly"].mean(),
        "top_features": diff.abs().sort_values(ascending=False).head(3).to_dict()
    })

summary_df = pd.DataFrame(results).sort_values(by="anomaly_ratio", ascending=False)
print(summary_df)

# print("\n=== 各製程條件異常與正常差異最大的特徵 ===")
# for row in feature_diff_results:
#     print(f"{row['process_condition']}: {row['feature_differences']}")
# Out:
# Best number of clusters (global): 8
# C:\Python310\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
# C:\Python310\lib\site-packages\sklearn\base.py:1473: ConvergenceWarning: Number of distinct clusters (6) found smaller than n_clusters (8). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)
#     process_condition  sample_size  anomaly_ratio  \
# 61     (304G036B48C,)           48       0.166667
# 26     (187G065C4BF,)           48       0.166667
# 39     (269S019D6BG,)           40       0.100000
# 88     (362SA99D6BN,)           40       0.100000
# 125    (480S134G68F,)           60       0.100000
# ..                ...          ...            ...
# 118    (369S085AE8C,)           56       0.035714
# 141    (750Q007CE7G,)           84       0.035714
# 115    (369S080AE8G,)           56       0.035714
# 132    (713S001AF3H,)           60       0.033333
# 77     (307S032AG3B,)           64       0.031250
#
#                                           top_features
# 61   {'plate_RC_value': 9.200000000000003, 'plate_l...
# 26   {'plate_layer_2Thick': 7.416, 'layer_2Thick': ...
# 39   {'plate_RC_value': 8.0, 'plate_layer_2Thick': ...
# 88   {'plate_layer_2Thick': 1.5599999999999996, 'pl...
# 125  {'plate_RC_value': 5.333333333333329, 'layer_2...
# ..                                                 ...
# 118  {'plate_RC_value': 3.1111111111111143, 'use_cu...
# 141  {'plate_RC_value': 0.7407407407407476, 'use_cu...
# 115  {'plate_layer_2Thick': 2.1548148148148156, 'us...
# 132  {'plate_layer_2Thick': 0.09310344827586192, 'l...
# 77   {'plate_RC_value': 5.612903225806448, 'plate_l...
#
# [146 rows x 4 columns]

# %%
group_counts = df.groupby('Part_nbr').size().reset_index(name='count')
big_groups = group_counts[group_counts['count'] >= 40]['Part_nbr']
df_big = df[df['Part_nbr'].isin(big_groups)]

# %%
# import pandas as pd
# from scipy.stats import chi2_contingency, ttest_ind
# import numpy as np
# from statsmodels.stats.multitest import multipletests

# categorical_features = [
#     'MacNo','MacRecipe', 'mtl_desc2', 'vend_nbr', 'plate_mtl_desc1',
#     'plate_mtl_desc2', 'plate_vend_nbr', 'use_cu_type', 'glass_fabric_type'
# ]
# numeric_features = [
#     'layer_2Thick', 'plate_layer_2Thick', 'plate_RC_value',
#     'Residual_Copper_Rate', 'glass_fabric_thickness_mm',
#     'use_cu_upper_thickness', 'use_cu_lower_thickness'
# ]

# results = []

# # 計算 pooled std 用的函數
# def pooled_std(x1, x2):
#     n1, n2 = len(x1), len(x2)
#     var1, var2 = np.var(x1, ddof=1), np.var(x2, ddof=1)
#     return np.sqrt(((n1 -1)*var1 + (n2 -1)*var2) / (n1 + n2 - 2))

# # 類別變數 → 卡方檢定 + Cramér's V
# for col in categorical_features:
#     contingency_table = pd.crosstab(df_big[col].astype('category'),
#                                     df_big['batch_is_normal'])
#     chi2, p, dof, expected = chi2_contingency(contingency_table)
#     n = contingency_table.sum().sum()
#     k = min(contingency_table.shape)  # 取行或列數中較小的
#     cramers_v = np.sqrt(chi2 / (n * (k - 1))) if k > 1 else np.nan
#     results.append([col, 'categorical', chi2, p, cramers_v, np.nan])  # Cohen's d 不適用

# # 數值變數 → t-test + Cohen's d
# for col in numeric_features:
#     abnormal_vals = df_big[df_big['batch_is_normal'] == 0][col].dropna()
#     normal_vals = df_big[df_big['batch_is_normal'] == 1][col].dropna()
#     stat, p = ttest_ind(abnormal_vals, normal_vals, equal_var=False)
#     # 計算 Cohen's d
#     s_pooled = pooled_std(abnormal_vals, normal_vals)
#     cohen_d = (abnormal_vals.mean() - normal_vals.mean()) / s_pooled if s_pooled > 0 else np.nan
#     results.append([col, 'numeric', stat, p, np.nan, cohen_d])

# diff_df = pd.DataFrame(results, columns=['feature', 'type', 'statistic', 'p_value', "cramers_v", "cohen_d"])
# diff_df = diff_df.sort_values('p_value')

# diff_df['p_adj'] = multipletests(diff_df['p_value'], method='fdr_bh')[1]

# print(diff_df)
# Out:
#                       feature         type    statistic        p_value  \
# 1                   MacRecipe  categorical  3262.737949   0.000000e+00
# 2                   mtl_desc2  categorical  2251.804706   0.000000e+00
# 3                    vend_nbr  categorical  1462.101017   0.000000e+00
# 5             plate_mtl_desc2  categorical  3202.812081   0.000000e+00
# 8           glass_fabric_type  categorical  1577.140510   0.000000e+00
# 6              plate_vend_nbr  categorical  1409.692531  1.092913e-302
# 4             plate_mtl_desc1  categorical  1447.245615  1.129740e-298
# 7                 use_cu_type  categorical  1390.584942  1.294284e-291
# 0                       MacNo  categorical  1073.712320  2.106475e-219
# 10         plate_layer_2Thick      numeric   -12.088452   1.392998e-33
# 11             plate_RC_value      numeric     9.326889   1.144471e-20
# 15     use_cu_lower_thickness      numeric    -6.952273   3.650218e-12
# 14     use_cu_upper_thickness      numeric    -5.543669   2.980931e-08
# 12       Residual_Copper_Rate      numeric     2.812024   4.925484e-03
# 9                layer_2Thick      numeric    -2.610348   9.048426e-03
# 13  glass_fabric_thickness_mm      numeric     0.634651   5.256600e-01
#
#     cramers_v   cohen_d          p_adj
# 1    0.285917       NaN   0.000000e+00
# 2    0.237527       NaN   0.000000e+00
# 3    0.191398       NaN   0.000000e+00
# 5    0.283279       NaN   0.000000e+00
# 8    0.198785       NaN   0.000000e+00
# 6    0.187936       NaN  2.914435e-302
# 4    0.190423       NaN  2.582263e-298
# 7    0.186658       NaN  2.588568e-291
# 0    0.164018       NaN  3.744844e-219
# 10        NaN -0.120835   2.228796e-33
# 11        NaN  0.093412   1.664685e-20
# 15        NaN -0.069681   4.866957e-12
# 14        NaN -0.055572   3.668839e-08
# 12        NaN  0.028148   5.629124e-03
# 9         NaN -0.026160   9.651654e-03
# 13        NaN  0.006364   5.256600e-01

# %%
# multipletests?

# %%
# diff_df
# Out:
#                       feature         type    statistic        p_value  \
# 1                   MacRecipe  categorical  3262.737949   0.000000e+00
# 2                   mtl_desc2  categorical  2251.804706   0.000000e+00
# 3                    vend_nbr  categorical  1462.101017   0.000000e+00
# 5             plate_mtl_desc2  categorical  3202.812081   0.000000e+00
# 8           glass_fabric_type  categorical  1577.140510   0.000000e+00
# 6              plate_vend_nbr  categorical  1409.692531  1.092913e-302
# 4             plate_mtl_desc1  categorical  1447.245615  1.129740e-298
# 7                 use_cu_type  categorical  1390.584942  1.294284e-291
# 0                       MacNo  categorical  1073.712320  2.106475e-219
# 10         plate_layer_2Thick      numeric   -12.088452   1.392998e-33
# 11             plate_RC_value      numeric     9.326889   1.144471e-20
# 15     use_cu_lower_thickness      numeric    -6.952273   3.650218e-12
# 14     use_cu_upper_thickness      numeric    -5.543669   2.980931e-08
# 12       Residual_Copper_Rate      numeric     2.812024   4.925484e-03
# 9                layer_2Thick      numeric    -2.610348   9.048426e-03
# 13  glass_fabric_thickness_mm      numeric     0.634651   5.256600e-01
#
#             p_adj
# 1    0.000000e+00
# 2    0.000000e+00
# 3    0.000000e+00
# 5    0.000000e+00
# 8    0.000000e+00
# 6   1.202204e-301
# 4   1.129740e-297
# 7   1.164855e-290
# 0   1.685180e-218
# 10   9.750984e-33
# 11   6.866827e-20
# 15   1.825109e-11
# 14   1.192373e-07
# 12   1.470379e-02
# 9    1.801498e-02
# 13   5.256600e-01

# %% [markdown]
# <p style="font-size: 14px; color: green;">檢查欄位<p>

# %%
df = df.copy() 
target = 'd_PSVarX'
group_cols = ['Part_nbr', 'Lot_nbr']   # 判定「同一批」用的欄位
group_for_mixed = 'Part_nbr_grouped'           # mixed model 的 groups
formula = """
d_PSVarX ~ mtl_desc2 + layer_2Thick + plate_mtl_desc2 + plate_layer_2Thick + plate_RC_value +
           Residual_Copper_Rate + glass_fabric_thickness_mm + use_cu_upper_thickness + short + use_cu_lower_thickness +
           C(use_cu_type) + C(glass_fabric_type) + C(vend_nbr) + C(MacRecipe) + C(MacNo)
           """
# -------------------------------------

# 檢查必要欄位存在
for c in group_cols + [target, group_for_mixed]:
    if c not in df.columns:
        raise ValueError(f"資料裡缺少欄位：{c}")

# 轉成數值
# df[target] = pd.to_numeric(df[target], errors='coerce')

# %% [markdown]
# <p style = "font_size: 16; color: red;">Filter Data</p>

# %% [markdown]
# <p style="font-size: 14px; color: green;">以批號判定正常 / 異常<p>

# %%
df_unfiltered = data

# 使用 group_cols 當作 batch key
df_unfiltered['_batch_key'] = df_unfiltered[group_cols].astype(str).agg('__'.join, axis=1)

batch_stats = df_unfiltered.groupby('_batch_key')[target].agg(['count', 'mean', 'min', 'max']).reset_index()
batch_stats['range'] = batch_stats['max'] - batch_stats['min']

# 規則： range <= 3 且 mean in [0,5] -> normal
batch_stats['is_normal'] = (batch_stats['range'] <= 3) & (batch_stats['mean'] >= 0) & (batch_stats['mean'] <= 5)

# map 回原始 df
batch_flag = batch_stats.set_index('_batch_key')['is_normal'].to_dict()
df_unfiltered['batch_is_normal'] = df_unfiltered['_batch_key'].map(batch_flag)

# 切出 filtered df（只保留正常批）
df_filtered = df_unfiltered[df_unfiltered['batch_is_normal']].copy()
print("原始資料筆數:", len(df), "正常批資料筆數:", len(df_filtered))
print("總批數:", batch_stats.shape[0], "正常批數:", batch_stats['is_normal'].sum())

# 列出不正常的 batch（供檢查）
abnormal_batches = batch_stats[~batch_stats['is_normal']].sort_values(['range','mean'], ascending=[False, True])
abnormal_batches.head(30).to_csv('abnormal_batches_top30.csv', index=False)
print("已輸出 abnormal_batches_top30.csv (供檢查)")
# Out:
# 原始資料筆數: 57169 正常批資料筆數: 30873
# 總批數: 4340 正常批數: 2579
# 已輸出 abnormal_batches_top30.csv (供檢查)

# %%
# 正常批 少量的料號合併
part_counts = df_filtered['Part_nbr'].value_counts()

threshold = 30
df_filtered['Part_nbr_grouped'] = np.where(df_filtered['Part_nbr'].map(part_counts) < threshold,   'OTHER', df_filtered['Part_nbr'])

# %% [markdown]
# <p style = "font_size: 14; color: green;">RC 處理</p>

# %%
# 以每個 lot的RC補NaN
l2_rc_map = (
    df_filtered[df_filtered['d_Layer'] == 'L2']
    .dropna(subset=['plate_RC_value'])
    .groupby('Lot_nbr')['plate_RC_value']
    .first()
)

first_rc_map = (
    df_filtered.dropna(subset=['plate_RC_value'])
    .groupby('Lot_nbr')['plate_RC_value']
    .first()
)

final_rc_map = l2_rc_map.combine_first(first_rc_map)

df_filtered['plate_RC_value'] =df_filtered['plate_RC_value'].fillna(df['Lot_nbr'].map(final_rc_map))

# %%
# 剩下的用整體中位數補
overall_median_rc = df_filtered['plate_RC_value'].median()

rc_missing_parts = df_filtered[df_filtered['plate_RC_value'].isna()].groupby('Part_nbr')['plate_RC_value'].count()

all_parts_count = df_filtered.groupby('Part_nbr')['plate_RC_value'].count()

rc_missing_parts_aligned = rc_missing_parts.reindex(all_parts_count.index, fill_value=0)

fully_missing_parts = all_parts_count[rc_missing_parts_aligned == all_parts_count].index

df_filtered.loc[df_filtered['Part_nbr'].isin(fully_missing_parts), 'plate_RC_value'] = overall_median_rc

# %% [markdown]
# <p style="font-size: 14px; color: blue;"> 找出遺失值數量(比例)</p>

# %%
features_with_na = [features for features in df_filtered.columns if df_filtered[features].isnull().sum() > 1]

for feature in features_with_na:
    print(feature, df_filtered[feature].isnull().sum(), 'missing values')
# Out:
# MacRecipe 80 missing values
# layer_2Thick 2944 missing values
# plate_layer_2Thick 13743 missing values
# glass_fabric_thickness_mm 304 missing values
# use_cu_upper_thickness 304 missing values
# use_cu_lower_thickness 304 missing values
# use_cu_type 624 missing values
# glass_fabric_type 768 missing values
# short 1790 missing values
# long 1790 missing values

# %% [markdown]
# <p style="font-size: 14px; color: blue;">找出有遺失值的數值型特徵<p>

# %%
numerical_features = [feature for feature in df_filtered.columns if df_filtered[feature].dtypes!='O']

print('Number of features: ',len(numerical_features))

# df[numerical_features].head()
# Out:
# Number of features:  17

# %% [markdown]
# <p style="font-size: 14px; color: blue;">找出有遺失值的離散型特徵<p>

# %%
discrete_feature = [feature for feature in numerical_features if len(df_filtered[feature].unique())<25]
print('Discrete variables count: {}'.format(len(discrete_feature)))
discrete_feature
# Out:
# Discrete variables count: 4
# ['MacNo',
#  'use_cu_upper_thickness',
#  'use_cu_lower_thickness',
#  'batch_is_normal']

# %% [markdown]
# <p style="font-size: 14px; color: blue;">找出有遺失值的類別型特徵<p>

# %%
categorical_features = [feature for feature in df_filtered.columns if df_filtered[feature].dtype == 'O']
print(len(categorical_features))
print(categorical_features)
# Out:
# 12
# ['Part_nbr', 'Lot_nbr', 'Layer', 'd_Layer', 'MacRecipe', 'vend_nbr', 'plate_mtl_desc1', 'plate_vend_nbr', 'use_cu_type', 'glass_fabric_type', 'Part_nbr_grouped', '_batch_key']

# %%
for feature in categorical_features:
    print('The feature is {} and number of categories are {}'.format(feature, len(df_filtered[feature].unique())))
# Out:
# The feature is Part_nbr and number of categories are 1041
# The feature is Lot_nbr and number of categories are 2579
# The feature is Layer and number of categories are 16
# The feature is d_Layer and number of categories are 40
# The feature is MacRecipe and number of categories are 164
# The feature is vend_nbr and number of categories are 11
# The feature is plate_mtl_desc1 and number of categories are 99
# The feature is plate_vend_nbr and number of categories are 9
# The feature is use_cu_type and number of categories are 33
# The feature is glass_fabric_type and number of categories are 77
# The feature is Part_nbr_grouped and number of categories are 210
# The feature is _batch_key and number of categories are 2579

# %% [markdown]
# <p style="font-size: 14px; color: blue;">處理離散型遺失值<p>

# %%
features_nan = [feature for feature in df_filtered.columns if df_filtered[feature].isnull().sum()>1 and df_filtered[feature].dtype=='O']

for feature in features_nan:
    print('{}: {} missing value'.format(feature, df_filtered[feature].isnull().sum()))
# Out:
# MacRecipe: 80 missing value
# use_cu_type: 624 missing value
# glass_fabric_type: 768 missing value

# %%
#這裡是將有nan的data挑出來，把nan換成Missing 標籤，因為等等要編碼(encode)，它不能是nan
def replace_cat_feature(data, features_nan):
    data1 = data.copy()
    data1[features_nan]=data[features_nan].fillna('Missing')
    return data1

df_filtered = replace_cat_feature(df_filtered, features_nan)

#nan沒有了，變成了Missing 標籤，所以都是0
df_filtered[features_nan].isnull().sum()
# Out:
# MacRecipe            0
# use_cu_type          0
# glass_fabric_type    0
# dtype: int64

# %% [markdown]
# <p style="font-size: 14px; color: blue;">處理數值型遺失值<p>

# %%
numerical_with_nan = [feature for feature in df_filtered.columns if df_filtered[feature].isnull().sum()>1 and df_filtered[feature].dtype!='O']

for feature in numerical_with_nan:
    print('{}: {} missing value'.format(feature, df_filtered[feature].isnull().sum()))
# Out:
# layer_2Thick: 2944 missing value
# plate_layer_2Thick: 13743 missing value
# glass_fabric_thickness_mm: 304 missing value
# use_cu_upper_thickness: 304 missing value
# use_cu_lower_thickness: 304 missing value
# short: 1790 missing value
# long: 1790 missing value

# %%
# 先對每個數值欄位進行分群中位數填補
for feature in numerical_with_nan:
    # 新增一欄標示缺失
    df_filtered[feature + '_nan'] = np.where(df_filtered[feature].isnull(), 1, 0)
    
    # 對每個 (Part_nbr, Lot_nbr) 群組算中位數來填補
    df_filtered[feature] = df_filtered.groupby(['Part_nbr', 'Lot_nbr'])[feature]\
                             .transform(lambda x: x.fillna(x.median()))
# Out:
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# ...
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Python310\lib\site-packages\numpy\lib\_nanfunctions_impl.py:1231: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
print('numbers of NaN in the all lot with df_filtered: \n')
for feature in numerical_with_nan:
    print('{}: {}'.format(feature, df_filtered[feature].isnull().sum()))
# Out:
# numbers of NaN in the all lot with df_filtered:
#
# layer_2Thick: 2944
# plate_layer_2Thick: 2944
# glass_fabric_thickness_mm: 0
# use_cu_upper_thickness: 0
# use_cu_lower_thickness: 0
# short: 1632
# long: 1632

# %%
# 若還有 NaN，用整體中位數補
for feature in numerical_with_nan:
    df_filtered[feature] = df_filtered[feature].fillna(df_filtered[feature].median())

# %%
df_filtered[numerical_with_nan].isnull().sum()
# Out:
# layer_2Thick                 0
# plate_layer_2Thick           0
# glass_fabric_thickness_mm    0
# use_cu_upper_thickness       0
# use_cu_lower_thickness       0
# short                        0
# long                         0
# dtype: int64

# %% [markdown]
# <p style="font-size: 14px; color: blue;">處理類別型遺失值<p>

# %%
categorical_feattures = [feature for feature in df_filtered.columns if df_filtered[feature].dtypes=='O' ]
categorical_feattures
# Out:
# ['Part_nbr',
#  'Lot_nbr',
#  'Layer',
#  'd_Layer',
#  'MacRecipe',
#  'vend_nbr',
#  'plate_mtl_desc1',
#  'plate_vend_nbr',
#  'use_cu_type',
#  'glass_fabric_type',
#  'Part_nbr_grouped',
#  '_batch_key']

# %%
# 你想保留的欄位（不處理的）
excluded_features = ['Part_nbr', 'Lot_nbr', 'Layer', 'd_Layer', 'Part_nbr_grouped']

# 建立一個新的列表，過濾掉 excluded_features
processed_categorical_features = [f for f in categorical_features if f not in excluded_features]

# rare category 合併
for feature in processed_categorical_features:
    temp = df_filtered.groupby(feature)['d_PSVarX'].count() / len(df_filtered)
    temp_df = temp[temp > 0.01].index
    df_filtered[feature] = np.where(df_filtered[feature].isin(temp_df), df_filtered[feature], 'rare cate')

# target mean encoding
for feature in processed_categorical_features:
    labels_ordered = df_filtered.groupby([feature])['d_PSVarX'].mean().sort_values().index
    labels_ordered = {k: i for i, k in enumerate(labels_ordered, 0)}
    df_filtered[feature] = df_filtered[feature].map(labels_ordered)

# %%
plt.scatter(df_filtered['d_PSVarX'],df_filtered['d_PSVarY'])

# %%
# 你想保留的欄位（不處理的）
excluded_features = ['Part_nbr', 'Lot_nbr', 'Layer', 'd_Layer', 'Part_nbr_grouped']

# 建立一個新的列表，過濾掉 excluded_features
processed_categorical_features = [f for f in categorical_features if f not in excluded_features]

# rare category 合併
for feature in processed_categorical_features:
    temp = df_filtered.groupby(feature)['d_PSVarX'].count() / len(df)
    temp_df = temp[temp > 0.01].index
    df_filtered[feature] = np.where(df_filtered[feature].isin(temp_df), df_filtered[feature], 'rare cate')

# target mean encoding
for feature in processed_categorical_features:
    labels_ordered = df_filtered.groupby([feature])['d_PSVarX'].mean().sort_values().index
    labels_ordered = {k: i for i, k in enumerate(labels_ordered, 0)}
    df_filtered[feature] = df_filtered[feature].map(labels_ordered)

# %%
import pandas as pd
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler

# 假設你的 DataFrame 名為 df
# 製程條件欄位（先換成你的實際欄位名稱）
process_cols = ['Part_nbr']

# 你要用來判斷異常的數值型特徵（可以放多個）
feature_cols = ["mtl_desc2", "layer_2Thick", "plate_layer_2Thick", "plate_RC_value", "Residual_Copper_Rate", "glass_fabric_thickness_mm", 
                "use_cu_upper_thickness", "short", "use_cu_lower_thickness"]

# 存結果
results = []

# 逐製程條件分組
for cond, group in df.groupby(process_cols):
    if len(group) < 5:
        continue  # 太小的群跳過，避免 GMM 不穩

    # 標準化
    X = group[feature_cols].values
    X_scaled = StandardScaler().fit_transform(X)

    # GMM 假設分兩類（一類正常，一類異常）
    gmm = GaussianMixture(n_components=2, covariance_type='full', random_state=123)
    labels = gmm.fit_predict(X_scaled)

    # 判斷哪個 cluster 是異常 → 用 cluster 的樣本數少的那個
    counts = pd.Series(labels).value_counts()
    anomaly_label = counts.idxmin()

    # 標註異常
    group_result = group.copy()
    group_result["is_anomaly"] = (labels == anomaly_label).astype(int)

    # 統計異常比例
    anomaly_ratio = group_result["is_anomaly"].mean()

    results.append({
        "process_condition": cond,
        "sample_size": len(group),
        "anomaly_ratio": anomaly_ratio
    })

    # 如果要保留每筆標註後的資料，可以另外存起來
    # all_labeled_data.append(group_result)

# 彙整統計表
summary_df = pd.DataFrame(results)
summary_df.sort_values(by="anomaly_ratio", ascending=False, inplace=True)

print(summary_df)
# Out:
#      process_condition  sample_size  anomaly_ratio
# 1218    (999S690AA0N,)           60       0.500000
# 27      (120SH04B58N,)            8       0.500000
# 1190    (867S072A53N,)            8       0.500000
# 1175    (811S187A5GF,)           16       0.500000
# 1179    (833S035E93G,)           16       0.500000
# ...                ...          ...            ...
# 1099    (708S009HDLG,)           52       0.076923
# 1108    (713S007BD3G,)           52       0.076923
# 343     (187S037B88C,)           70       0.071429
# 133     (120SP08CEBC,)          196       0.071429
# 974     (369S065B93F,)          144       0.062500
#
# [1251 rows x 3 columns]

# %% [markdown]
# <p style="font-size: 16px; color: blue;">Modeling<p>

# %% [markdown]
# <p style="font-size: 14px; color: green;">檢查欄位<p>

# %%
df = df.copy() 
target = 'd_PSVarX'
group_cols = ['Part_nbr', 'Lot_nbr']   # 判定「同一批」用的欄位
group_for_mixed = 'Part_nbr_grouped'           # mixed model 的 groups
formula = """
d_PSVarX ~ mtl_desc2 + layer_2Thick + plate_mtl_desc2 + plate_layer_2Thick + plate_RC_value +
           Residual_Copper_Rate + glass_fabric_thickness_mm + use_cu_upper_thickness + short + use_cu_lower_thickness +
           C(use_cu_type) + C(glass_fabric_type) + C(vend_nbr) + C(MacRecipe) + C(MacNo)
           """
# -------------------------------------

# 檢查必要欄位存在
for c in group_cols + [target, group_for_mixed]:
    if c not in df.columns:
        raise ValueError(f"資料裡缺少欄位：{c}")

# 轉成數值
# df[target] = pd.to_numeric(df[target], errors='coerce')

# %%
df_filtered = df_filtered.copy() 
target = 'd_PSVarX'
group_cols = ['Part_nbr', 'Lot_nbr']   # 判定「同一批」用的欄位
group_for_mixed = 'Part_nbr_grouped'           # mixed model 的 groups
formula = """
d_PSVarX ~ mtl_desc2 + layer_2Thick + plate_mtl_desc2 + plate_layer_2Thick + plate_RC_value +
           Residual_Copper_Rate + glass_fabric_thickness_mm + use_cu_upper_thickness + short + use_cu_lower_thickness +
           C(use_cu_type) + C(glass_fabric_type) + C(vend_nbr) + C(MacRecipe) + C(MacNo)
           """
# -------------------------------------

# 檢查必要欄位存在
for c in group_cols + [target, group_for_mixed]:
    if c not in df.columns:
        raise ValueError(f"資料裡缺少欄位：{c}")

# 轉成數值
# df[target] = pd.to_numeric(df[target], errors='coerce')

# %%
df_filtered[group_for_mixed].value_counts().describe() # check極端小的group
# Out:
# count     321.000000
# mean       92.526480
# std       449.172072
# min         8.000000
# 25%        20.000000
# 50%        36.000000
# 75%        56.000000
# max      7609.000000
# Name: count, dtype: float64

# %% [markdown]
# <p style="font-size: 14px; color: green;">定義 fit + diagnostics 函式<p>

# %%
def fit_mixed_and_diagnostics(df_input, label):
    """
    Fit MixedLM with reml=False (for model comparison) and reml=True (final),
    return results dict and draw diagnostics.
    """
    part_counts = df_input['Part_nbr'].value_counts()
    df_input['weights'] = df_input['Part_nbr'].map(lambda x: 1 / part_counts[x])
    
    # fit with ML (reml=False) for fair comparison via AIC/BIC/LLF if needed
    md_ml = smf.mixedlm(formula, df_input, groups=df_input[group_for_mixed], re_formula="1 + Residual_Copper_Rate")
    try:
        res_ml = md_ml.fit(reml=False, method='bfgs',  maxiter=2000)
    except Exception as e:
        print("[WARN] ML fit failed, try default method. Err:", e)
        res_ml = md_ml.fit(reml=False)
    
    # fit final with REML for better variance components
    md_reml = smf.mixedlm(formula, df_input, groups=df_input[group_for_mixed], re_formula="1 + Residual_Copper_Rate")
    try:
        res_reml = md_reml.fit(reml=True, method='bfgs', maxiter=2000)
    except Exception:
        res_reml = md_reml.fit(reml=True, method='bfgs')
    
    # diagnostics
    fitted = res_ml.fittedvalues   # use ML-fitted values for comparability
    resid = res_ml.resid

    random_effects = res_ml.random_effects  # 從 res_ml 取出隨機效應
    
    out = {
        'label': label,
        'res_ml': res_ml,
        'res_reml': res_reml,
        'fitted': fitted,
        'resid': resid,
        'random_effects': random_effects
    }
    return out

# %%
# fit on full and filtered
print("開始 fit 全資料 (ML)... 這可能需要一段時間")
full_mod = fit_mixed_and_diagnostics(df, label='full')
# Out:
# 開始 fit 全資料 (ML)... 這可能需要一段時間

# %%
print("開始 fit 過濾後資料 (ML)...")
filtered_mod = fit_mixed_and_diagnostics(df_filtered, label='filtered')
# Out:
# 開始 fit 過濾後資料 (ML)...
# C:\Python310\lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 12.760398
#   warnings.warn(msg, ConvergenceWarning)

# %% [markdown]
# <p style="font-size: 14px; color: green;">比較模型指標<p>

# %%
filtered_mod['random_effects']
# Out:
# {'107S004C78C': Group                   0.279938
#  Residual_Copper_Rate   -0.040896
#  dtype: float64,
#  '107S009A78C': Group                   0.342676
#  Residual_Copper_Rate   -0.014534
#  dtype: float64,
#  '107S013B08C': Group                   0.718692
#  Residual_Copper_Rate   -0.005806
#  dtype: float64,
#  '110EB91C58C': Group                   0.858955
#  Residual_Copper_Rate    0.012447
#  dtype: float64,
#  '110EC06A68C': Group                  -1.340005
#  Residual_Copper_Rate    0.017188
#  dtype: float64,
#  '110SB72E78F': Group                   0.029759
#  Residual_Copper_Rate    0.004206
#  dtype: float64,
#  '110SB76D88C': Group                   0.070229
#  Residual_Copper_Rate    0.029086
#  dtype: float64,
#  '110SB82C08C': Group                   1.318839
#  Residual_Copper_Rate   -0.009151
#  dtype: float64,
#  '110SB96D88C': Group                   0.827711
#  Residual_Copper_Rate    0.001788
#  dtype: float64,
#  '110SB99B88C': Group                   0.243148
#  Residual_Copper_Rate    0.010606
#  dtype: float64,
#  '110SC01A98C': Group                  -1.949342
#  Residual_Copper_Rate    0.021973
#  dtype: float64,
#  '110SC01B98C': Group                   0.011588
#  Residual_Copper_Rate    0.006156
#  dtype: float64,
#  '120SG98G68F': Group                   0.433976
#  Residual_Copper_Rate   -0.028114
#  dtype: float64,
#  '120SK74B78C': Group                  -0.614722
#  Residual_Copper_Rate    0.005101
#  dtype: float64,
#  '120SL94F7BC': Group                   0.004905
#  Residual_Copper_Rate    0.004000
#  dtype: float64,
#  '120SM41K78C': Group                  -1.207323
#  Residual_Copper_Rate    0.014825
#  dtype: float64,
#  '120SN12FA8C': Group                  -0.776641
#  Residual_Copper_Rate   -0.010525
#  dtype: float64,
#  '120SN12GA8C': Group                  -0.197665
#  Residual_Copper_Rate   -0.000101
#  dtype: float64,
#  '120SO10E88G': Group                  -0.802016
#  Residual_Copper_Rate    0.019230
#  dtype: float64,
#  '120SO45B88C': Group                   0.379635
#  Residual_Copper_Rate   -0.000776
#  dtype: float64,
#  '120SO67C98C': Group                  -0.005477
#  Residual_Copper_Rate   -0.000865
#  dtype: float64,
#  '120SO80C08C': Group                   0.567931
#  Residual_Copper_Rate   -0.026351
#  dtype: float64,
#  '120SO80F08C': Group                   0.768438
#  Residual_Copper_Rate   -0.006467
#  dtype: float64,
#  '120SO90B08C': Group                  -1.815530
#  Residual_Copper_Rate    0.027188
#  dtype: float64,
#  '120SO98C78C': Group                  -0.468190
#  Residual_Copper_Rate    0.001446
#  dtype: float64,
#  '120SP08BEBC': Group                  -0.406318
#  Residual_Copper_Rate    0.034163
#  dtype: float64,
#  '120SP08CEBC': Group                  -0.194406
#  Residual_Copper_Rate   -0.017770
#  dtype: float64,
#  '120SP17D98C': Group                   0.341438
#  Residual_Copper_Rate    0.002081
#  dtype: float64,
#  '120SP18D78C': Group                  -0.521519
#  Residual_Copper_Rate    0.011454
#  dtype: float64,
#  '120SP29GA8C': Group                   0.745055
#  Residual_Copper_Rate   -0.016936
#  dtype: float64,
#  '120SP34B98C': Group                   0.910090
#  Residual_Copper_Rate   -0.017775
#  dtype: float64,
#  '120SP34C98C': Group                  -1.321079
#  Residual_Copper_Rate    0.020944
#  dtype: float64,
#  '120SP40A98C': Group                  -1.144483
#  Residual_Copper_Rate    0.026814
#  dtype: float64,
#  '120SP40C98C': Group                   0.576715
#  Residual_Copper_Rate    0.004797
#  dtype: float64,
#  '120SP40D98C': Group                  -1.465297
#  Residual_Copper_Rate    0.035358
#  dtype: float64,
#  '120SP49CA8C': Group                  -1.444076
#  Residual_Copper_Rate    0.008138
#  dtype: float64,
#  '120SP54A8BN': Group                   0.307463
#  Residual_Copper_Rate   -0.011129
#  dtype: float64,
#  '120SP55A98C': Group                   0.168745
#  Residual_Copper_Rate   -0.002159
#  dtype: float64,
#  '120SP55B98C': Group                   1.277859
#  Residual_Copper_Rate   -0.019104
#  dtype: float64,
#  '120SP57A08C': Group                   0.932951
#  Residual_Copper_Rate   -0.013201
#  dtype: float64,
#  '120SP57B08C': Group                   1.181277
#  Residual_Copper_Rate   -0.016063
#  dtype: float64,
#  '120SP58B88C': Group                   0.263359
#  Residual_Copper_Rate   -0.008731
#  dtype: float64,
#  '120SP62A98C': Group                  -0.506503
#  Residual_Copper_Rate    0.006440
#  dtype: float64,
#  '120SP62C98C': Group                  -0.133278
#  Residual_Copper_Rate    0.007337
#  dtype: float64,
#  '120SP77AA8C': Group                  -0.422311
#  Residual_Copper_Rate   -0.001530
#  dtype: float64,
#  '120SP77BA8C': Group                  -1.198400
#  Residual_Copper_Rate    0.017976
#  dtype: float64,
#  '120SP80AA8C': Group                  -1.054543
#  Residual_Copper_Rate    0.012913
#  dtype: float64,
#  '120SP80CA8C': Group                  -0.333474
#  Residual_Copper_Rate    0.012783
#  dtype: float64,
#  '120SP82AA8C': Group                   0.053135
#  Residual_Copper_Rate   -0.015075
#  dtype: float64,
#  '120SP92AB8C': Group                  -0.512539
#  Residual_Copper_Rate    0.006278
#  dtype: float64,
#  '120SP92BB8C': Group                   1.807639
#  Residual_Copper_Rate   -0.020522
#  dtype: float64,
#  '120SP92CB8C': Group                  -0.509878
#  Residual_Copper_Rate    0.007171
#  dtype: float64,
#  '120SQ01AA8C': Group                  -2.183811
#  Residual_Copper_Rate    0.011320
#  dtype: float64,
#  '120SQ18A78C': Group                  -0.489649
#  Residual_Copper_Rate    0.006777
#  dtype: float64,
#  '120SQ22AC8C': Group                   1.651257
#  Residual_Copper_Rate   -0.013725
#  dtype: float64,
#  '120SQ24AABC': Group                   1.432166
#  Residual_Copper_Rate   -0.012441
#  dtype: float64,
#  '120SQ87AE8C': Group                   1.561288
#  Residual_Copper_Rate   -0.029505
#  dtype: float64,
#  '120SQ88BC8C': Group                   1.400958
#  Residual_Copper_Rate   -0.014172
#  dtype: float64,
#  '150S064A53C': Group                   0.025504
#  Residual_Copper_Rate   -0.004162
#  dtype: float64,
#  '187G063A78G': Group                   0.080573
#  Residual_Copper_Rate   -0.008433
#  dtype: float64,
#  '187S003D78C': Group                   0.764793
#  Residual_Copper_Rate   -0.083624
#  dtype: float64,
#  '187S010B78C': Group                   0.662838
#  Residual_Copper_Rate    0.003690
#  dtype: float64,
#  '187S022A78B': Group                  -0.601078
#  Residual_Copper_Rate    0.005875
#  dtype: float64,
#  '187S033A08C': Group                   0.513124
#  Residual_Copper_Rate   -0.004974
#  dtype: float64,
#  '187S035C88C': Group                  -0.274826
#  Residual_Copper_Rate    0.006696
#  dtype: float64,
#  '187S037B88C': Group                   0.249591
#  Residual_Copper_Rate   -0.000881
#  dtype: float64,
#  '187S051A88C': Group                  -0.202910
#  Residual_Copper_Rate    0.179668
#  dtype: float64,
#  '187S076C88B': Group                   0.464731
#  Residual_Copper_Rate   -0.006729
#  dtype: float64,
#  '187S092B98B': Group                  -0.289381
#  Residual_Copper_Rate    0.007916
#  dtype: float64,
#  '187S092C98B': Group                   1.196176
#  Residual_Copper_Rate   -0.010417
#  dtype: float64,
#  '187S092D98B': Group                   0.052741
#  Residual_Copper_Rate   -0.011696
#  dtype: float64,
#  '187S093A98C': Group                   0.617640
#  Residual_Copper_Rate   -0.003277
#  dtype: float64,
#  '187S093B98C': Group                   1.662605
#  Residual_Copper_Rate   -0.012665
#  dtype: float64,
#  '187S093C98C': Group                   1.147693
#  Residual_Copper_Rate   -0.014581
#  dtype: float64,
#  '187S102B78C': Group                   1.571469
#  Residual_Copper_Rate   -0.022000
#  dtype: float64,
#  '187S112DA8B': Group                   0.120983
#  Residual_Copper_Rate   -0.017872
#  dtype: float64,
#  '187S113AA8C': Group                   0.225227
#  Residual_Copper_Rate   -0.021174
#  dtype: float64,
#  '187S113BA8C': Group                  -0.126732
#  Residual_Copper_Rate   -0.010570
#  dtype: float64,
#  '200S012A79N': Group                   0.200085
#  Residual_Copper_Rate    0.009819
#  dtype: float64,
#  '200S016A69N': Group                   0.800478
#  Residual_Copper_Rate   -0.004960
#  dtype: float64,
#  '200S022A89N': Group                   0.257616
#  Residual_Copper_Rate   -0.003796
#  dtype: float64,
#  '250SB65F08C': Group                  -0.510017
#  Residual_Copper_Rate    0.005767
#  dtype: float64,
#  '269S007E78C': Group                  -0.505189
#  Residual_Copper_Rate    0.013386
#  dtype: float64,
#  '269S015C6BG': Group                   0.280071
#  Residual_Copper_Rate   -0.004160
#  dtype: float64,
#  '269S015F6BG': Group                   0.207854
#  Residual_Copper_Rate   -0.003880
#  dtype: float64,
#  '269S016BA8C': Group                  -0.250707
#  Residual_Copper_Rate    0.002556
#  dtype: float64,
#  '269S016EA8C': Group                  -1.026875
#  Residual_Copper_Rate    0.007479
#  dtype: float64,
#  '269S017CA8C': Group                  -0.290098
#  Residual_Copper_Rate    0.004871
#  dtype: float64,
#  '269S017DA8C': Group                   0.646134
#  Residual_Copper_Rate    0.010354
#  dtype: float64,
#  '269S018A78C': Group                  -0.107135
#  Residual_Copper_Rate   -0.000881
#  dtype: float64,
#  '269S019D6BG': Group                   0.402605
#  Residual_Copper_Rate   -0.005785
#  dtype: float64,
#  '275S583B78C': Group                  -0.443816
#  Residual_Copper_Rate    0.006398
#  dtype: float64,
#  '275S604B78C': Group                   0.330942
#  Residual_Copper_Rate    0.007082
#  dtype: float64,
#  '275S615BA8C': Group                  -0.067043
#  Residual_Copper_Rate    0.003132
#  dtype: float64,
#  '277S063E78C': Group                  -0.093776
#  Residual_Copper_Rate    0.000080
#  dtype: float64,
#  '277S067D78C': Group                  -0.748249
#  Residual_Copper_Rate    0.009540
#  dtype: float64,
#  '277S083D88C': Group                   0.039658
#  Residual_Copper_Rate    0.005695
#  dtype: float64,
#  '277S084C98C': Group                  -0.926673
#  Residual_Copper_Rate    0.011573
#  dtype: float64,
#  '277S087C78C': Group                  -2.356267
#  Residual_Copper_Rate    0.042080
#  dtype: float64,
#  '277S102BC8C': Group                   0.588226
#  Residual_Copper_Rate   -0.011153
#  dtype: float64,
#  '277S102CC8C': Group                  -1.031773
#  Residual_Copper_Rate    0.009847
#  dtype: float64,
#  '277S103A68C': Group                   0.510857
#  Residual_Copper_Rate    0.022288
#  dtype: float64,
#  '297G011B8BG': Group                   1.240882
#  Residual_Copper_Rate   -0.010690
#  dtype: float64,
#  '297G011F8BG': Group                   1.104942
#  Residual_Copper_Rate   -0.012158
#  dtype: float64,
#  '297G019B6BG': Group                   0.480364
#  Residual_Copper_Rate   -0.005136
#  dtype: float64,
#  '297G019D6BG': Group                   0.353085
#  Residual_Copper_Rate   -0.016580
#  dtype: float64,
#  '297G020B98C': Group                  -0.707074
#  Residual_Copper_Rate    0.005764
#  dtype: float64,
#  '297G020C98C': Group                  -0.177566
#  Residual_Copper_Rate   -0.004480
#  dtype: float64,
#  '297G021A78G': Group                   0.165279
#  Residual_Copper_Rate   -0.006793
#  dtype: float64,
#  '297G036B88C': Group                  -0.938059
#  Residual_Copper_Rate    0.007869
#  dtype: float64,
#  '297G036C88C': Group                  -0.306485
#  Residual_Copper_Rate    0.004126
#  dtype: float64,
#  '297G038C98G': Group                  -0.539137
#  Residual_Copper_Rate    0.010890
#  dtype: float64,
#  '297G041C6BF': Group                   0.068945
#  Residual_Copper_Rate   -0.005991
#  dtype: float64,
#  '297G063A98G': Group                  -0.006577
#  Residual_Copper_Rate    0.000271
#  dtype: float64,
#  '297G063B98G': Group                   0.232170
#  Residual_Copper_Rate    0.004847
#  dtype: float64,
#  '297G069A58C': Group                   0.440594
#  Residual_Copper_Rate    0.000893
#  dtype: float64,
#  '297G071A78G': Group                  -0.086825
#  Residual_Copper_Rate    0.009649
#  dtype: float64,
#  '297G071B78G': Group                   0.089017
#  Residual_Copper_Rate    0.023231
#  dtype: float64,
#  '297G071C78G': Group                  -0.141726
#  Residual_Copper_Rate    0.051623
#  dtype: float64,
#  '297G120A7BG': Group                  -0.052885
#  Residual_Copper_Rate   -0.001664
#  dtype: float64,
#  '297S002F88B': Group                   0.030528
#  Residual_Copper_Rate   -0.011707
#  dtype: float64,
#  '297S005D88C': Group                  -0.746820
#  Residual_Copper_Rate    0.004613
#  dtype: float64,
#  '297S009E58C': Group                   0.019358
#  Residual_Copper_Rate    0.019778
#  dtype: float64,
#  '297S010E58C': Group                  -1.412302
#  Residual_Copper_Rate    0.018839
#  dtype: float64,
#  '297S016E48B': Group                   0.385299
#  Residual_Copper_Rate   -0.009387
#  dtype: float64,
#  '297S025C78B': Group                   1.112298
#  Residual_Copper_Rate   -0.020257
#  dtype: float64,
#  '297S027B88B': Group                   0.586643
#  Residual_Copper_Rate    0.001884
#  dtype: float64,
#  '297S028B88C': Group                   1.228162
#  Residual_Copper_Rate   -0.012201
#  dtype: float64,
#  '297S046AA8G': Group                  -1.870048
#  Residual_Copper_Rate    0.016808
#  dtype: float64,
#  '297S047AA8H': Group                  -0.571547
#  Residual_Copper_Rate    0.014804
#  dtype: float64,
#  '297S047BA8H': Group                   1.050030
#  Residual_Copper_Rate   -0.003022
#  dtype: float64,
#  '297S059A88C': Group                  -0.031246
#  Residual_Copper_Rate    0.025249
#  dtype: float64,
#  '297S064B98C': Group                   0.053068
#  Residual_Copper_Rate    0.022985
#  dtype: float64,
#  '297S064C98C': Group                  -1.437554
#  Residual_Copper_Rate    0.025953
#  dtype: float64,
#  '297S064D98C': Group                   0.256503
#  Residual_Copper_Rate    0.015397
#  dtype: float64,
#  '297S065B98B': Group                  -1.135188
#  Residual_Copper_Rate    0.004206
#  dtype: float64,
#  '297S065C98B': Group                  -0.674936
#  Residual_Copper_Rate    0.017755
#  dtype: float64,
#  '297S065D98B': Group                   0.543076
#  Residual_Copper_Rate    0.083909
#  dtype: float64,
#  '297S066B78C': Group                  -0.427608
#  Residual_Copper_Rate    0.001113
#  dtype: float64,
#  '297S066C78C': Group                   0.323765
#  Residual_Copper_Rate   -0.015339
#  dtype: float64,
#  '297S067B78B': Group                  -0.830551
#  Residual_Copper_Rate    0.002469
#  dtype: float64,
#  '297S067C78B': Group                  -0.455882
#  Residual_Copper_Rate   -0.000055
#  dtype: float64,
#  '297S067D78B': Group                   0.876740
#  Residual_Copper_Rate   -0.027246
#  dtype: float64,
#  '297S075A98G': Group                   0.990071
#  Residual_Copper_Rate   -0.011559
#  dtype: float64,
#  '297S076A98G': Group                   0.924841
#  Residual_Copper_Rate   -0.009170
#  dtype: float64,
#  '297S082A6BG': Group                  -0.262555
#  Residual_Copper_Rate    0.001676
#  dtype: float64,
#  '297S111A78C': Group                   0.746153
#  Residual_Copper_Rate   -0.032959
#  dtype: float64,
#  '297S116B08C': Group                  -0.164227
#  Residual_Copper_Rate    0.007889
#  dtype: float64,
#  '304G036B48C': Group                   1.539142
#  Residual_Copper_Rate   -0.025550
#  dtype: float64,
#  '305E215C68C': Group                  -0.706493
#  Residual_Copper_Rate    0.014972
#  dtype: float64,
#  '305E252A7BC': Group                   0.151525
#  Residual_Copper_Rate    0.000135
#  dtype: float64,
#  '305E252B7BC': Group                   0.051895
#  Residual_Copper_Rate   -0.010226
#  dtype: float64,
#  '305E268A9BC': Group                  -0.205706
#  Residual_Copper_Rate   -0.003469
#  dtype: float64,
#  '305E268C9BC': Group                   0.497067
#  Residual_Copper_Rate   -0.029319
#  dtype: float64,
#  '305E271B63C': Group                   0.296761
#  Residual_Copper_Rate    0.006376
#  dtype: float64,
#  '305E275A48C': Group                  -0.310065
#  Residual_Copper_Rate   -0.016689
#  dtype: float64,
#  '305S087E48N': Group                  -0.585406
#  Residual_Copper_Rate   -0.001214
#  dtype: float64,
#  '305S091E78F': Group                   0.069810
#  Residual_Copper_Rate   -0.003127
#  dtype: float64,
#  '305S180C63C': Group                   0.758529
#  Residual_Copper_Rate   -0.004454
#  dtype: float64,
#  '305S191C53C': Group                  -0.543114
#  Residual_Copper_Rate    0.007587
#  dtype: float64,
#  '305S217BA8C': Group                  -0.301068
#  Residual_Copper_Rate   -0.027279
#  dtype: float64,
#  '305S227D78C': Group                  -0.051882
#  Residual_Copper_Rate    0.039224
#  dtype: float64,
#  '305S230F88C': Group                  -0.844554
#  Residual_Copper_Rate   -0.012862
#  dtype: float64,
#  '305S238H88C': Group                   0.080109
#  Residual_Copper_Rate    0.018345
#  dtype: float64,
#  '305S240B88C': Group                   0.623993
#  Residual_Copper_Rate    0.066411
#  dtype: float64,
#  '305S241G08C': Group                  -0.432148
#  Residual_Copper_Rate    0.012961
#  dtype: float64,
#  '305S247F88C': Group                   0.731345
#  Residual_Copper_Rate   -0.012223
#  dtype: float64,
#  '305S247G88C': Group                   0.716431
#  Residual_Copper_Rate   -0.006877
#  dtype: float64,
#  '305S250E88C': Group                  -0.672641
#  Residual_Copper_Rate    0.005716
#  dtype: float64,
#  '305S250F88C': Group                   0.504014
#  Residual_Copper_Rate    0.003154
#  dtype: float64,
#  '305S259AA3C': Group                   0.199984
#  Residual_Copper_Rate   -0.009248
#  dtype: float64,
#  '305S272B08C': Group                  -1.362633
#  Residual_Copper_Rate    0.019747
#  dtype: float64,
#  '305S272C08C': Group                  -0.447688
#  Residual_Copper_Rate    0.013054
#  dtype: float64,
#  '305S276A98C': Group                   1.227321
#  Residual_Copper_Rate   -0.020383
#  dtype: float64,
#  '305S276B98C': Group                   1.603039
#  Residual_Copper_Rate   -0.005473
#  dtype: float64,
#  '305S277AA8C': Group                   0.196549
#  Residual_Copper_Rate    0.009812
#  dtype: float64,
#  '307S035A73R': Group                   0.845926
#  Residual_Copper_Rate   -0.004588
#  dtype: float64,
#  '307S037AALC': Group                  -0.122465
#  Residual_Copper_Rate   -0.003780
#  dtype: float64,
#  '307S037BALF': Group                  -0.374255
#  Residual_Copper_Rate   -0.007402
#  dtype: float64,
#  '307S040A03H': Group                   0.368878
#  Residual_Copper_Rate    0.009281
#  dtype: float64,
#  '315S627A68N': Group                   0.408997
#  Residual_Copper_Rate   -0.007908
#  dtype: float64,
#  '325S010B54N': Group                   0.69887
#  Residual_Copper_Rate   -0.01269
#  dtype: float64,
#  '327S021A68H': Group                  -1.663906
#  Residual_Copper_Rate    0.020486
#  dtype: float64,
#  '350S303I83H': Group                  -0.406834
#  Residual_Copper_Rate    0.015009
#  dtype: float64,
#  '350S348F63C': Group                  -0.531633
#  Residual_Copper_Rate    0.011376
#  dtype: float64,
#  '350S363C83B': Group                  -0.227929
#  Residual_Copper_Rate    0.010684
#  dtype: float64,
#  '350S412D83C': Group                  -2.408035
#  Residual_Copper_Rate    0.018058
#  dtype: float64,
#  '350S416D83H': Group                   1.118795
#  Residual_Copper_Rate   -0.002308
#  dtype: float64,
#  '350S432E83C': Group                  -0.903585
#  Residual_Copper_Rate   -0.010361
#  dtype: float64,
#  '350S434BC3B': Group                   0.293962
#  Residual_Copper_Rate   -0.006341
#  dtype: float64,
#  '350S479A98C': Group                   0.465729
#  Residual_Copper_Rate   -0.001864
#  dtype: float64,
#  '350S481AA8C': Group                  -0.220590
#  Residual_Copper_Rate    0.000373
#  dtype: float64,
#  '350S487A98C': Group                  -2.383875
#  Residual_Copper_Rate    0.021840
#  dtype: float64,
#  '350S488A78N': Group                   0.731491
#  Residual_Copper_Rate   -0.017655
#  dtype: float64,
#  '353A132DA7C': Group                   0.554654
#  Residual_Copper_Rate   -0.001659
#  dtype: float64,
#  '353S104B77C': Group                   0.052445
#  Residual_Copper_Rate    0.002688
#  dtype: float64,
#  '353S117B77F': Group                  -0.619389
#  Residual_Copper_Rate   -0.006425
#  dtype: float64,
#  '353S122DB7C': Group                   0.042314
#  Residual_Copper_Rate   -0.009699
#  dtype: float64,
#  '353S129B87C': Group                  -1.007527
#  Residual_Copper_Rate    0.017797
#  dtype: float64,
#  '353S133C87C': Group                   0.339097
#  Residual_Copper_Rate   -0.007317
#  dtype: float64,
#  '353S136C5AF': Group                   1.154671
#  Residual_Copper_Rate   -0.014044
#  dtype: float64,
#  '353S137D87B': Group                   0.894256
#  Residual_Copper_Rate   -0.017564
#  dtype: float64,
#  '353S147A77C': Group                  -0.121839
#  Residual_Copper_Rate   -0.010694
#  dtype: float64,
#  '353S149BC7C': Group                  -0.145351
#  Residual_Copper_Rate   -0.012877
#  dtype: float64,
#  '353S156B97B': Group                  -0.579659
#  Residual_Copper_Rate   -0.000892
#  dtype: float64,
#  '362S078J6BC': Group                  -1.441806
#  Residual_Copper_Rate    0.017065
#  dtype: float64,
#  '362S186F68F': Group                  -1.192685
#  Residual_Copper_Rate    0.005129
#  dtype: float64,
#  '362S206E68N': Group                   0.536219
#  Residual_Copper_Rate   -0.002973
#  dtype: float64,
#  '362S247E54F': Group                  -0.312338
#  Residual_Copper_Rate    0.028805
#  dtype: float64,
#  '362S247G54F': Group                   0.012590
#  Residual_Copper_Rate    0.004374
#  dtype: float64,
#  '362S321F78H': Group                   0.980172
#  Residual_Copper_Rate   -0.023188
#  dtype: float64,
#  '362S361D78G': Group                   1.109009
#  Residual_Copper_Rate   -0.011990
#  dtype: float64,
#  '362S424E38N': Group                   1.021602
#  Residual_Copper_Rate   -0.022311
#  dtype: float64,
#  '362S482G68N': Group                   0.664899
#  Residual_Copper_Rate   -0.013960
#  dtype: float64,
#  '362S637B68F': Group                  -0.064958
#  Residual_Copper_Rate    0.000411
#  dtype: float64,
#  '362S677C68F': Group                  -1.149744
#  Residual_Copper_Rate    0.012798
#  dtype: float64,
#  '362S677F68F': Group                  -0.534854
#  Residual_Copper_Rate    0.001678
#  dtype: float64,
#  '362S871F78N': Group                  -0.636868
#  Residual_Copper_Rate    0.010469
#  dtype: float64,
#  '362S871G78N': Group                  -0.500597
#  Residual_Copper_Rate    0.011437
#  dtype: float64,
#  '362S896E78H': Group                  -0.759284
#  Residual_Copper_Rate    0.006111
#  dtype: float64,
#  '362S950D68N': Group                  -1.471086
#  Residual_Copper_Rate    0.012325
#  dtype: float64,
#  '362SA34E78H': Group                   1.014391
#  Residual_Copper_Rate   -0.032008
#  dtype: float64,
#  '362SA99D6BN': Group                  -0.031781
#  Residual_Copper_Rate   -0.008779
#  dtype: float64,
#  '362SB27A48N': Group                   0.582053
#  Residual_Copper_Rate    0.003247
#  dtype: float64,
#  '362SC33C58N': Group                   0.468011
#  Residual_Copper_Rate   -0.006346
#  dtype: float64,
#  '362SD06C88C': Group                   0.430765
#  Residual_Copper_Rate   -0.002835
#  dtype: float64,
#  '362SD48B88C': Group                  -0.089974
#  Residual_Copper_Rate    0.010696
#  dtype: float64,
#  '362SD64B93C': Group                  -1.258727
#  Residual_Copper_Rate    0.013938
#  dtype: float64,
#  '362SD65AE3C': Group                  -0.252809
#  Residual_Copper_Rate   -0.007986
#  dtype: float64,
#  '362SD75A68N': Group                   0.119852
#  Residual_Copper_Rate   -0.000730
#  dtype: float64,
#  '362SD77B73F': Group                  -0.712863
#  Residual_Copper_Rate    0.001732
#  dtype: float64,
#  '366E882C44F': Group                  -0.467126
#  Residual_Copper_Rate    0.001098
#  dtype: float64,
#  '366E885C6BC': Group                  -0.785124
#  Residual_Copper_Rate   -0.000425
#  dtype: float64,
#  '366E912A78C': Group                   0.410851
#  Residual_Copper_Rate   -0.004664
#  dtype: float64,
#  '366E916A6BC': Group                   0.344439
#  Residual_Copper_Rate   -0.007998
#  dtype: float64,
#  '366E925A54G': Group                   0.238136
#  Residual_Copper_Rate   -0.006516
#  dtype: float64,
#  '366E934B6BB': Group                   0.271817
#  Residual_Copper_Rate   -0.000469
#  dtype: float64,
#  '366E948A68C': Group                  -0.334223
#  Residual_Copper_Rate    0.003899
#  dtype: float64,
#  '366S777D44C': Group                   1.055967
#  Residual_Copper_Rate   -0.033819
#  dtype: float64,
#  '366S784E58F': Group                  -0.762039
#  Residual_Copper_Rate    0.017466
#  dtype: float64,
#  '366S803E48F': Group                  -0.119376
#  Residual_Copper_Rate   -0.012027
#  dtype: float64,
#  '366S815F68F': Group                   0.41925
#  Residual_Copper_Rate   -0.00892
#  dtype: float64,
#  '366S816C58F': Group                  -0.199343
#  Residual_Copper_Rate   -0.000854
#  dtype: float64,
#  '366S822C58F': Group                  -1.212809
#  Residual_Copper_Rate    0.004582
#  dtype: float64,
#  '366S842C73C': Group                   0.113792
#  Residual_Copper_Rate   -0.010382
#  dtype: float64,
#  '366S902M88C': Group                   0.359667
#  Residual_Copper_Rate    0.003807
#  dtype: float64,
#  '366S914BA8C': Group                   0.364843
#  Residual_Copper_Rate   -0.030456
#  dtype: float64,
#  '366S917A98C': Group                   0.083571
#  Residual_Copper_Rate   -0.033219
#  dtype: float64,
#  '366S923AA8C': Group                  -0.440799
#  Residual_Copper_Rate    0.009452
#  dtype: float64,
#  '366S923BA8C': Group                  -1.930997
#  Residual_Copper_Rate    0.019095
#  dtype: float64,
#  '366S926D88C': Group                   0.187204
#  Residual_Copper_Rate   -0.002366
#  dtype: float64,
#  '366S930FK8G': Group                   0.030573
#  Residual_Copper_Rate   -0.025857
#  dtype: float64,
#  '366S932A08B': Group                   0.895994
#  Residual_Copper_Rate   -0.002695
#  dtype: float64,
#  '366S932B08B': Group                   0.553298
#  Residual_Copper_Rate   -0.023417
#  dtype: float64,
#  '366S932C08B': Group                  -0.503849
#  Residual_Copper_Rate    0.035146
#  dtype: float64,
#  '366S935AA8C': Group                   1.253645
#  Residual_Copper_Rate   -0.021617
#  dtype: float64,
#  '366S935CA8C': Group                  -0.333797
#  Residual_Copper_Rate    0.005323
#  dtype: float64,
#  '366S937AB8B': Group                  -1.671306
#  Residual_Copper_Rate    0.010834
#  dtype: float64,
#  '366S937BB8B': Group                  -0.923217
#  Residual_Copper_Rate   -0.034659
#  dtype: float64,
#  '366S937EB8B': Group                  -0.030333
#  Residual_Copper_Rate   -0.065894
#  dtype: float64,
#  '366S938BA8C': Group                   1.802938
#  Residual_Copper_Rate   -0.030968
#  dtype: float64,
#  '366S939B08C': Group                   1.014458
#  Residual_Copper_Rate    0.093013
#  dtype: float64,
#  '366S940C7BC': Group                  -1.032186
#  Residual_Copper_Rate    0.020896
#  dtype: float64,
#  '366S945A88C': Group                   1.494354
#  Residual_Copper_Rate   -0.020155
#  dtype: float64,
#  '369S064B63C': Group                   0.257674
#  Residual_Copper_Rate   -0.012422
#  dtype: float64,
#  '369S065B93F': Group                   0.614984
#  Residual_Copper_Rate   -0.004565
#  dtype: float64,
#  '369S070B08C': Group                  -0.298768
#  Residual_Copper_Rate    0.011271
#  dtype: float64,
#  '369S071AB3C': Group                   0.618372
#  Residual_Copper_Rate   -0.032720
#  dtype: float64,
#  '369S075A98B': Group                   0.603322
#  Residual_Copper_Rate   -0.010842
#  dtype: float64,
#  '369S079AB8C': Group                   0.009169
#  Residual_Copper_Rate   -0.011033
#  dtype: float64,
#  '369S084A08G': Group                  -2.467506
#  Residual_Copper_Rate    0.022230
#  dtype: float64,
#  '369S090AD8C': Group                   0.442243
#  Residual_Copper_Rate   -0.011594
#  dtype: float64,
#  '393S001A88C': Group                  -0.928493
#  Residual_Copper_Rate    0.022264
#  dtype: float64,
#  '396S139F43N': Group                   0.490328
#  Residual_Copper_Rate   -0.001136
#  dtype: float64,
#  '477G007C78G': Group                   1.574592
#  Residual_Copper_Rate   -0.066972
#  dtype: float64,
#  '477G082A74G': Group                   0.963843
#  Residual_Copper_Rate   -0.008559
#  dtype: float64,
#  '477G101A7BF': Group                   0.482401
#  Residual_Copper_Rate   -0.004087
#  dtype: float64,
#  '477S006A88C': Group                  -0.009564
#  Residual_Copper_Rate   -0.138326
#  dtype: float64,
#  '477S010C78C': Group                   0.986129
#  Residual_Copper_Rate   -0.007639
#  dtype: float64,
#  '477S010E78C': Group                  -0.235434
#  Residual_Copper_Rate    0.044410
#  dtype: float64,
#  '477S022B5BF': Group                   0.211509
#  Residual_Copper_Rate    0.000189
#  dtype: float64,
#  '477S024C78G': Group                  -1.779283
#  Residual_Copper_Rate    0.021547
#  dtype: float64,
#  '477S034AA8H': Group                  -0.906939
#  Residual_Copper_Rate   -0.008115
#  dtype: float64,
#  '477S038A78F': Group                  -0.264653
#  Residual_Copper_Rate    0.002096
#  dtype: float64,
#  '477S041A98H': Group                   1.003069
#  Residual_Copper_Rate   -0.024345
#  dtype: float64,
#  '477S049A08B': Group                  -0.018001
#  Residual_Copper_Rate   -0.000919
#  dtype: float64,
#  '477S050A98H': Group                  -0.271554
#  Residual_Copper_Rate   -0.001452
#  dtype: float64,
#  '477S060AA8B': Group                   0.123720
#  Residual_Copper_Rate    0.005395
#  dtype: float64,
#  '477S070AA8H': Group                  -0.748533
#  Residual_Copper_Rate    0.015536
#  dtype: float64,
#  '480E155C68C': Group                   0.902456
#  Residual_Copper_Rate   -0.006711
#  dtype: float64,
#  '480E172C63C': Group                   0.482873
#  Residual_Copper_Rate   -0.008061
#  dtype: float64,
#  '480E196A5BG': Group                  -0.309025
#  Residual_Copper_Rate    0.007621
#  dtype: float64,
#  '480S134G68F': Group                   1.326804
#  Residual_Copper_Rate   -0.011780
#  dtype: float64,
#  '480S147B44F': Group                  -0.959114
#  Residual_Copper_Rate    0.010024
#  dtype: float64,
#  '480S177F78C': Group                  -0.428943
#  Residual_Copper_Rate   -0.004739
#  dtype: float64,
#  '480S186F78C': Group                   1.105130
#  Residual_Copper_Rate   -0.010553
#  dtype: float64,
#  '480S189C78C': Group                  -0.764630
#  Residual_Copper_Rate    0.039282
#  dtype: float64,
#  '480S195B08C': Group                  -0.776169
#  Residual_Copper_Rate    0.004629
#  dtype: float64,
#  '620Q023A08C': Group                   0.425774
#  Residual_Copper_Rate   -0.014472
#  dtype: float64,
#  '708Q015AF8C': Group                   1.532724
#  Residual_Copper_Rate   -0.031127
#  dtype: float64,
#  '708Q019BF3G': Group                   1.831685
#  Residual_Copper_Rate   -0.039251
#  dtype: float64,
#  '708S013ADLG': Group                  -1.589522
#  Residual_Copper_Rate    0.022703
#  dtype: float64,
#  '708S016AF3G': Group                  -0.213555
#  Residual_Copper_Rate    0.004217
#  dtype: float64,
#  '713S002AD3H': Group                  -1.431602
#  Residual_Copper_Rate    0.014574
#  dtype: float64,
#  '713S006AB3H': Group                   0.547586
#  Residual_Copper_Rate   -0.014920
#  dtype: float64,
#  '713S007BD3G': Group                   0.849986
#  Residual_Copper_Rate   -0.011971
#  dtype: float64,
#  '713S014AC8Q': Group                   0.215933
#  Residual_Copper_Rate    0.073745
#  dtype: float64,
#  '722S003BC3B': Group                  -0.266069
#  Residual_Copper_Rate   -0.000617
#  dtype: float64,
#  '730S016EC3B': Group                   0.827627
#  Residual_Copper_Rate   -0.007143
#  dtype: float64,
#  '730S087C0IN': Group                   0.839650
#  Residual_Copper_Rate   -0.005758
#  dtype: float64,
#  '730S100C6IG': Group                  -0.358691
#  Residual_Copper_Rate    0.002281
#  dtype: float64,
#  '736Q012FA3C': Group                  -0.058655
#  Residual_Copper_Rate   -0.000009
#  dtype: float64,
#  '736Q014BA3C': Group                  -0.101705
#  Residual_Copper_Rate   -0.001338
#  dtype: float64,
#  '736Q014DA3C': Group                  -1.795356
#  Residual_Copper_Rate    0.012236
#  dtype: float64,
#  '750Q009B5LG': Group                  -1.047810
#  Residual_Copper_Rate    0.010127
#  dtype: float64,
#  '770G033BD8F': Group                   0.508894
#  Residual_Copper_Rate   -0.007725
#  dtype: float64,
#  '770Q029I93C': Group                   0.569098
#  Residual_Copper_Rate   -0.009066
#  dtype: float64,
#  '770Q029J93C': Group                  -0.824886
#  Residual_Copper_Rate    0.006398
#  dtype: float64,
#  '770Q030A88C': Group                  -0.199289
#  Residual_Copper_Rate    0.000426
#  dtype: float64,
#  '791S009AC3B': Group                   0.512412
#  Residual_Copper_Rate   -0.008173
#  dtype: float64,
#  'OTHER': Group                  -0.063043
#  Residual_Copper_Rate   -0.000804
#  dtype: float64}

# %%
def print_compare(full, filtered):
    print("===== ML (reml=False) 比較 =====")
    print("Full:  llf=%.3f   AIC=%.3f   BIC=%.3f   nobs=%d" % (full['res_ml'].llf, full['res_ml'].aic, full['res_ml'].bic, full['res_ml'].nobs))
    print("Filt:  llf=%.3f   AIC=%.3f   BIC=%.3f   nobs=%d" % (filtered['res_ml'].llf, filtered['res_ml'].aic, filtered['res_ml'].bic, filtered['res_ml'].nobs))
    print("\n===== REML (final estimates) 摘要 (filtered) =====")
    print(full['res_reml'].summary())
    print(filtered['res_reml'].summary())
    
print_compare(full_mod, filtered_mod)
# Out:
# ===== ML (reml=False) 比較 =====
# Full:  llf=-113920.438   AIC=228000.876   BIC=228713.331   nobs=54485
# Filt:  llf=-44213.620   AIC=88585.240   BIC=89240.856   nobs=29701
#
# ===== REML (final estimates) 摘要 (filtered) =====
#                    Mixed Linear Model Regression Results
# ============================================================================
# Model:                  MixedLM       Dependent Variable:       d_PSVarX
# No. Observations:       54485         Method:                   REML
# No. Groups:             398           Scale:                    3.7315
# Min. group size:        30            Log-Likelihood:           -114042.8377
# Max. group size:        11441         Converged:                Yes
# Mean group size:        136.9
# ----------------------------------------------------------------------------
#                                  Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------
# Intercept                         6.506    1.096   5.935 0.000  4.358  8.655
# C(use_cu_type)[T.1]              -0.166    0.179  -0.927 0.354 -0.517  0.185
# C(use_cu_type)[T.2]               0.102    0.211   0.484 0.628 -0.311  0.515
# C(use_cu_type)[T.3]               0.079    0.145   0.545 0.586 -0.205  0.362
# C(use_cu_type)[T.4]               0.472    0.144   3.290 0.001  0.191  0.754
# C(use_cu_type)[T.5]              -0.111    0.148  -0.751 0.453 -0.402  0.179
# C(use_cu_type)[T.6]               0.426    0.148   2.881 0.004  0.136  0.716
# C(use_cu_type)[T.7]               0.428    0.149   2.878 0.004  0.137  0.719
# C(use_cu_type)[T.8]               0.602    0.149   4.035 0.000  0.310  0.894
# C(use_cu_type)[T.9]               0.611    0.181   3.367 0.001  0.255  0.967
# C(use_cu_type)[T.10]              0.367    0.147   2.496 0.013  0.079  0.655
# C(use_cu_type)[T.11]              0.293    0.147   2.000 0.045  0.006  0.580
# C(glass_fabric_type)[T.1]        -1.469    0.197  -7.475 0.000 -1.854 -1.084
# C(glass_fabric_type)[T.2]        -1.106    0.183  -6.039 0.000 -1.465 -0.747
# C(glass_fabric_type)[T.3]        -1.378    0.216  -6.384 0.000 -1.801 -0.955
# C(glass_fabric_type)[T.4]        -1.207    0.178  -6.767 0.000 -1.556 -0.857
# C(glass_fabric_type)[T.5]        -1.366    0.178  -7.688 0.000 -1.714 -1.018
# C(glass_fabric_type)[T.6]        -1.033    0.201  -5.134 0.000 -1.428 -0.639
# C(glass_fabric_type)[T.7]        -1.058    0.179  -5.917 0.000 -1.408 -0.707
# C(glass_fabric_type)[T.8]        -1.201    0.230  -5.226 0.000 -1.651 -0.750
# C(glass_fabric_type)[T.9]        -1.222    0.212  -5.753 0.000 -1.638 -0.805
# C(glass_fabric_type)[T.10]       -0.604    0.181  -3.335 0.001 -0.959 -0.249
# C(glass_fabric_type)[T.11]       -0.505    0.195  -2.587 0.010 -0.888 -0.122
# C(glass_fabric_type)[T.12]       -1.125    0.173  -6.488 0.000 -1.465 -0.785
# C(glass_fabric_type)[T.13]       -1.202    0.177  -6.788 0.000 -1.549 -0.855
# C(vend_nbr)[T.1]                  0.786    0.216   3.633 0.000  0.362  1.211
# C(vend_nbr)[T.2]                 -0.140    0.177  -0.791 0.429 -0.488  0.207
# C(vend_nbr)[T.3]                  0.742    0.184   4.038 0.000  0.382  1.102
# C(vend_nbr)[T.4]                  0.193    0.180   1.074 0.283 -0.159  0.545
# C(vend_nbr)[T.5]                  0.330    0.270   1.221 0.222 -0.200  0.860
# C(vend_nbr)[T.6]                  0.332    0.172   1.936 0.053 -0.004  0.668
# C(MacRecipe)[T.1]                -2.081    0.440  -4.735 0.000 -2.942 -1.220
# C(MacRecipe)[T.2]                -3.660    0.297 -12.330 0.000 -4.242 -3.078
# C(MacRecipe)[T.3]                -3.665    0.292 -12.560 0.000 -4.237 -3.093
# C(MacRecipe)[T.4]                -2.706    0.343  -7.899 0.000 -3.377 -2.034
# C(MacRecipe)[T.5]                -3.308    0.285 -11.624 0.000 -3.866 -2.750
# C(MacRecipe)[T.6]                -3.161    0.299 -10.570 0.000 -3.748 -2.575
# C(MacRecipe)[T.7]                -3.530    0.294 -12.012 0.000 -4.106 -2.954
# C(MacRecipe)[T.8]                -3.509    0.356  -9.871 0.000 -4.206 -2.812
# C(MacRecipe)[T.9]                -3.491    0.299 -11.660 0.000 -4.077 -2.904
# C(MacRecipe)[T.10]               -3.650    0.296 -12.346 0.000 -4.229 -3.070
# C(MacRecipe)[T.11]               -2.399    0.320  -7.509 0.000 -3.026 -1.773
# C(MacRecipe)[T.12]               -3.035    0.301 -10.097 0.000 -3.625 -2.446
# C(MacRecipe)[T.13]               -0.574    0.476  -1.205 0.228 -1.507  0.360
# C(MacRecipe)[T.14]               -4.471    0.359 -12.451 0.000 -5.175 -3.767
# C(MacRecipe)[T.15]               -3.619    0.302 -11.976 0.000 -4.211 -3.026
# C(MacRecipe)[T.16]               -3.230    0.359  -9.005 0.000 -3.933 -2.527
# C(MacRecipe)[T.17]               -2.961    0.303  -9.763 0.000 -3.555 -2.366
# C(MacRecipe)[T.18]               -1.570    0.310  -5.056 0.000 -2.178 -0.961
# C(MacRecipe)[T.19]               -2.728    0.330  -8.264 0.000 -3.375 -2.081
# C(MacRecipe)[T.20]               -3.451    0.303 -11.396 0.000 -4.045 -2.858
# C(MacNo)[T.2]                     0.168    0.027   6.278 0.000  0.116  0.221
# C(MacNo)[T.3]                    -0.010    0.032  -0.305 0.760 -0.072  0.052
# C(MacNo)[T.4]                     0.425    0.032  13.152 0.000  0.362  0.488
# C(MacNo)[T.11]                    0.593    0.170   3.491 0.000  0.260  0.927
# C(MacNo)[T.21]                    0.173    0.045   3.859 0.000  0.085  0.260
# C(MacNo)[T.22]                    0.009    0.043   0.199 0.842 -0.076  0.094
# C(MacNo)[T.23]                    0.258    0.045   5.724 0.000  0.170  0.347
# C(MacNo)[T.24]                    0.518    0.058   8.975 0.000  0.405  0.631
# C(MacNo)[T.25]                    0.313    0.060   5.220 0.000  0.196  0.431
# C(MacNo)[T.26]                   -0.311    0.164  -1.898 0.058 -0.632  0.010
# C(MacNo)[T.27]                   -0.518    0.142  -3.647 0.000 -0.797 -0.240
# C(MacNo)[T.28]                    1.413    0.437   3.238 0.001  0.558  2.269
# C(MacNo)[T.29]                    0.514    0.172   2.988 0.003  0.177  0.851
# C(MacNo)[T.30]                   -0.174    0.257  -0.678 0.498 -0.678  0.330
# C(MacNo)[T.31]                   -0.314    0.203  -1.547 0.122 -0.712  0.084
# mtl_desc2                        -2.700    0.550  -4.912 0.000 -3.777 -1.623
# layer_2Thick                     -0.010    0.007  -1.509 0.131 -0.023  0.003
# plate_mtl_desc2                   0.019    0.087   0.218 0.827 -0.151  0.189
# plate_layer_2Thick                0.014    0.002   5.529 0.000  0.009  0.019
# plate_RC_value                   -0.004    0.002  -2.046 0.041 -0.008 -0.000
# Residual_Copper_Rate              0.217    0.056   3.901 0.000  0.108  0.326
# glass_fabric_thickness_mm         3.951    0.490   8.067 0.000  2.991  4.910
# use_cu_upper_thickness           -0.026    0.035  -0.757 0.449 -0.095  0.042
# short                             0.678    0.992   0.684 0.494 -1.265  2.622
# use_cu_lower_thickness            0.048    0.035   1.391 0.164 -0.020  0.116
# Group Var                         2.952    0.135
# Group x Residual_Copper_Rate Cov -0.269    0.056
# Residual_Copper_Rate Var          0.055    0.015
# ============================================================================
#
#                    Mixed Linear Model Regression Results
# ===========================================================================
# Model:                  MixedLM       Dependent Variable:       d_PSVarX
# No. Observations:       29701         Method:                   REML
# No. Groups:             321           Scale:                    1.1116
# Min. group size:        8             Log-Likelihood:           -44355.0828
# Max. group size:        7609          Converged:                Yes
# Mean group size:        92.5
# ---------------------------------------------------------------------------
#                                  Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------
# Intercept                         2.880    1.251  2.302 0.021  0.428  5.333
# C(use_cu_type)[T.1]               0.252    0.224  1.123 0.262 -0.188  0.692
# C(use_cu_type)[T.2]               0.858    0.239  3.599 0.000  0.391  1.326
# C(use_cu_type)[T.3]               0.598    0.215  2.779 0.005  0.176  1.020
# C(use_cu_type)[T.4]               0.893    0.214  4.164 0.000  0.472  1.313
# C(use_cu_type)[T.5]               0.592    0.216  2.739 0.006  0.168  1.015
# C(use_cu_type)[T.6]               0.634    0.216  2.934 0.003  0.210  1.057
# C(use_cu_type)[T.7]               0.672    0.216  3.118 0.002  0.250  1.095
# C(use_cu_type)[T.8]               0.947    0.216  4.382 0.000  0.524  1.371
# C(use_cu_type)[T.9]               0.646    0.232  2.784 0.005  0.191  1.100
# C(use_cu_type)[T.10]              0.647    0.215  3.004 0.003  0.225  1.070
# C(use_cu_type)[T.11]              0.611    0.216  2.829 0.005  0.188  1.034
# C(glass_fabric_type)[T.1]        -0.059    0.182 -0.323 0.747 -0.415  0.297
# C(glass_fabric_type)[T.2]        -0.120    0.176 -0.684 0.494 -0.464  0.224
# C(glass_fabric_type)[T.3]        -0.296    0.192 -1.547 0.122 -0.672  0.079
# C(glass_fabric_type)[T.4]        -0.070    0.172 -0.406 0.685 -0.407  0.268
# C(glass_fabric_type)[T.5]        -0.192    0.172 -1.114 0.265 -0.530  0.146
# C(glass_fabric_type)[T.6]         0.163    0.183  0.887 0.375 -0.197  0.522
# C(glass_fabric_type)[T.7]         0.060    0.172  0.348 0.728 -0.278  0.398
# C(glass_fabric_type)[T.8]         0.129    0.204  0.633 0.527 -0.270  0.528
# C(glass_fabric_type)[T.9]        -0.054    0.191 -0.285 0.776 -0.429  0.320
# C(glass_fabric_type)[T.10]        0.258    0.174  1.482 0.138 -0.083  0.599
# C(glass_fabric_type)[T.11]        0.267    0.180  1.481 0.139 -0.086  0.619
# C(glass_fabric_type)[T.12]       -0.053    0.169 -0.316 0.752 -0.384  0.278
# C(glass_fabric_type)[T.13]       -0.067    0.171 -0.393 0.694 -0.402  0.268
# C(vend_nbr)[T.1]                  0.051    0.178  0.287 0.774 -0.298  0.401
# C(vend_nbr)[T.2]                 -0.215    0.157 -1.369 0.171 -0.522  0.093
# C(vend_nbr)[T.3]                  0.216    0.162  1.331 0.183 -0.102  0.533
# C(vend_nbr)[T.4]                 -0.306    0.161 -1.908 0.056 -0.621  0.008
# C(vend_nbr)[T.5]                 -0.119    0.209 -0.567 0.571 -0.529  0.292
# C(vend_nbr)[T.6]                 -0.289    0.158 -1.832 0.067 -0.598  0.020
# C(MacRecipe)[T.1]                -1.966    0.941 -2.089 0.037 -3.810 -0.122
# C(MacRecipe)[T.2]                -1.686    0.912 -1.849 0.064 -3.474  0.101
# C(MacRecipe)[T.3]                -1.642    0.911 -1.803 0.071 -3.428  0.143
# C(MacRecipe)[T.4]                -1.583    0.926 -1.709 0.087 -3.398  0.232
# C(MacRecipe)[T.5]                -1.686    0.910 -1.851 0.064 -3.470  0.099
# C(MacRecipe)[T.6]                -1.526    0.914 -1.671 0.095 -3.317  0.264
# C(MacRecipe)[T.7]                -1.828    0.911 -2.006 0.045 -3.614 -0.042
# C(MacRecipe)[T.8]                -1.376    0.918 -1.499 0.134 -3.175  0.423
# C(MacRecipe)[T.9]                -1.779    0.912 -1.951 0.051 -3.567  0.009
# C(MacRecipe)[T.10]               -1.915    0.911 -2.102 0.036 -3.701 -0.129
# C(MacRecipe)[T.11]               -1.366    0.917 -1.489 0.136 -3.163  0.432
# C(MacRecipe)[T.12]               -1.497    0.912 -1.640 0.101 -3.285  0.292
# C(MacRecipe)[T.13]               -0.964    0.947 -1.018 0.309 -2.820  0.892
# C(MacRecipe)[T.14]               -1.154    0.924 -1.249 0.212 -2.964  0.657
# C(MacRecipe)[T.15]               -1.906    0.912 -2.089 0.037 -3.694 -0.118
# C(MacRecipe)[T.16]               -1.272    0.926 -1.374 0.169 -3.086  0.543
# C(MacRecipe)[T.17]               -1.395    0.913 -1.528 0.126 -3.184  0.394
# C(MacRecipe)[T.18]               -1.858    0.926 -2.007 0.045 -3.673 -0.044
# C(MacRecipe)[T.19]               -0.612    0.921 -0.664 0.506 -2.416  1.193
# C(MacRecipe)[T.20]               -1.405    0.913 -1.539 0.124 -3.195  0.384
# C(MacNo)[T.2]                     0.048    0.019  2.513 0.012  0.011  0.086
# C(MacNo)[T.3]                    -0.147    0.024 -6.242 0.000 -0.193 -0.101
# C(MacNo)[T.4]                     0.171    0.025  6.797 0.000  0.122  0.220
# C(MacNo)[T.11]                    0.137    0.229  0.600 0.548 -0.311  0.586
# C(MacNo)[T.21]                    0.068    0.034  2.001 0.045  0.001  0.134
# C(MacNo)[T.22]                    0.148    0.034  4.387 0.000  0.082  0.214
# C(MacNo)[T.23]                    0.071    0.035  2.036 0.042  0.003  0.140
# C(MacNo)[T.24]                    0.081    0.046  1.763 0.078 -0.009  0.170
# C(MacNo)[T.25]                    0.050    0.046  1.082 0.279 -0.040  0.140
# C(MacNo)[T.26]                    0.608    0.134  4.531 0.000  0.345  0.871
# C(MacNo)[T.27]                    0.004    0.116  0.033 0.974 -0.224  0.231
# C(MacNo)[T.29]                    0.935    0.145  6.439 0.000  0.650  1.219
# C(MacNo)[T.30]                    0.196    0.184  1.070 0.285 -0.163  0.556
# C(MacNo)[T.31]                   -0.397    0.180 -2.212 0.027 -0.749 -0.045
# mtl_desc2                         1.868    0.669  2.795 0.005  0.558  3.178
# layer_2Thick                      0.004    0.005  0.774 0.439 -0.006  0.013
# plate_mtl_desc2                  -0.067    0.061 -1.101 0.271 -0.186  0.052
# plate_layer_2Thick                0.005    0.002  2.780 0.005  0.001  0.008
# plate_RC_value                   -0.001    0.001 -0.713 0.476 -0.004  0.002
# Residual_Copper_Rate              0.190    0.040  4.715 0.000  0.111  0.269
# glass_fabric_thickness_mm        -1.807    0.628 -2.879 0.004 -3.037 -0.577
# use_cu_upper_thickness           -0.109    0.033 -3.306 0.001 -0.174 -0.045
# short                             1.441    0.785  1.836 0.066 -0.098  2.979
# use_cu_lower_thickness           -0.060    0.033 -1.835 0.067 -0.125  0.004
# Group Var                         0.776    0.084
# Group x Residual_Copper_Rate Cov -0.036    0.043
# Residual_Copper_Rate Var          0.013    0.014
# ===========================================================================

# %%
import numpy as np

group_for_mixed = 'Part_nbr_grouped'           # mixed model 的 groups
formula = """
d_PSVarX ~ mtl_desc2 + layer_2Thick + plate_mtl_desc2 + plate_layer_2Thick + plate_RC_value +
           Residual_Copper_Rate + glass_fabric_thickness_mm + use_cu_upper_thickness + short + use_cu_lower_thickness +
           C(use_cu_type) + C(glass_fabric_type) + C(vend_nbr) + C(MacRecipe) + C(MacNo)
           """

n_boot = 500
coef_results = []

for i in range(n_boot):
    boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
    boot_model = smf.mixedlm(formula, boot_df, groups=boot_df["Part_nbr_grouped"])
    boot_result = boot_model.fit()
    coef_results.append(boot_result.params)

coef_df = pd.DataFrame(coef_results)
print(coef_df)  # 看係數分佈
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# ...
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_33856\2109125536.py:14: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   boot_df = df_filtered.groupby('Part_nbr_grouped', group_keys=False).apply(lambda x: x.sample(frac=1, replace=True))
#      Intercept  C(use_cu_type)[T.1]  C(use_cu_type)[T.2]  C(use_cu_type)[T.3]  \
# 0     1.021285             0.226143            -0.018012             0.217701
# 1     0.906013             0.152362            -0.179486             0.116701
# 2     0.633368            -0.132820            -0.094623             0.161108
# 3     1.098547             0.123464            -0.075227             0.178629
# 4     0.642373             0.229035             0.004203             0.254189
# ..         ...                  ...                  ...                  ...
# 495 -96.978258             0.357496            -0.167831             0.102647
# 496   1.291047             0.071496            -0.150818             0.056445
# 497   1.056055             0.141644            -0.140524             0.131425
# 498   1.109802             0.189184            -0.121270             0.208479
# 499   1.025501             0.294749            -0.157391             0.113391
#
#      C(use_cu_type)[T.4]  C(use_cu_type)[T.5]  C(use_cu_type)[T.6]  \
# 0               0.174156             0.182838            -0.063520
# 1               0.101144             0.100185            -0.089948
# 2               0.098459            -0.011899            -0.022234
# 3               0.173048             0.121121            -0.016934
# 4               0.162937             0.129556            -0.028292
# ..                   ...                  ...                  ...
# 495             0.062493             0.090208            -0.110079
# 496             0.070309             0.026093            -0.170646
# 497             0.066890             0.051369            -0.235717
# 498             0.146090             0.068387            -0.068098
# 499             0.066829             0.099291            -0.145779
#
#      C(use_cu_type)[T.7]  C(use_cu_type)[T.8]  C(use_cu_type)[T.9]  ...  \
# 0               0.437732             0.186424             0.186696  ...
# 1               0.377082             0.156871             0.050128  ...
# 2               0.389346             0.164187             0.058097  ...
# 3               0.438956             0.246868             0.087421  ...
# 4               0.432570             0.237917             0.069851  ...
# ..                   ...                  ...                  ...  ...
# 495             0.367846             0.078972             0.045910  ...
# 496             0.367926             0.066496             0.026855  ...
# 497             0.296422             0.107181             0.059622  ...
# 498             0.454713             0.212788             0.067258  ...
# 499             0.330961             0.234746             0.061746  ...
#
#      layer_2Thick  plate_mtl_desc2  plate_layer_2Thick  plate_RC_value  \
# 0        0.011222        -0.023100            0.001573        0.000344
# 1        0.007008        -0.107359            0.002338       -0.000188
# 2        0.009653        -0.027921            0.005990        0.001137
# 3        0.001496        -0.016422            0.007712        0.003130
# 4        0.001666         0.031266            0.004755        0.001740
# ..            ...              ...                 ...             ...
# 495     -0.002148        -0.036496            0.005420       -0.000232
# 496      0.010502        -0.031134            0.004994       -0.001696
# 497     -0.001407        -0.081352            0.004181        0.000213
# 498      0.006869        -0.036334            0.005861        0.000863
# 499      0.007848        -0.071813            0.003653        0.000862
#
#      Residual_Copper_Rate  glass_fabric_thickness_mm  use_cu_upper_thickness  \
# 0                0.215649                  -1.868933               -0.096340
# 1                0.129857                  -0.982700               -0.032015
# 2                0.275452                  -0.572169                0.001176
# 3                0.107158                  -1.711475               -0.075838
# 4                0.246163                  -1.484530               -0.053315
# ..                    ...                        ...                     ...
# 495              0.194680                  -1.990980               -0.051676
# 496              0.233964                  -1.652451               -0.090339
# 497              0.193945                  -0.579862               -0.082150
# 498              0.228454                  -1.814367               -0.114130
# 499              0.221040                  -1.693134               -0.080560
#
#          short  use_cu_lower_thickness  Group Var
# 0     1.551837               -0.030955   0.510291
# 1     1.946804                0.010429   0.515421
# 2     2.073910                0.002205   0.524545
# 3     1.597813               -0.039894   0.491930
# 4     1.826559               -0.038554   0.523242
# ..         ...                     ...        ...
# 495  99.631499               -0.044513   0.505876
# 496   1.689904               -0.030339   0.511518
# 497   1.954748                0.002853   0.515025
# 498   1.571528                0.002839   0.503848
# 499   1.725552               -0.053739   0.509640
#
# [500 rows x 64 columns]

# %%
# coef_df.describe().to_excel('coef_df_BT500.xlsx', index=False)

# %%
# LRT for df_filtered
#    use_cu_type: O
#    glass_fabric_type: O
#    vend_nbr: O
#    MacRecipe: O
#    MacNo: O

formula1 = """
d_PSVarX ~ mtl_desc2 + layer_2Thick + plate_mtl_desc2 + plate_layer_2Thick + plate_RC_value +
           Residual_Copper_Rate + glass_fabric_thickness_mm + use_cu_upper_thickness + short + use_cu_lower_thickness +
           C(use_cu_type) + C(glass_fabric_type) + C(vend_nbr) + C(MacRecipe) + C(MacNo)
           """
full = smf.mixedlm(formula1, df_filtered, groups=df_filtered[group_for_mixed], re_formula="1").fit(reml=False, method='bfgs', maxiter=2000)

formula2 = """
d_PSVarX ~ mtl_desc2 + layer_2Thick + plate_mtl_desc2 + plate_layer_2Thick + plate_RC_value +
           Residual_Copper_Rate + glass_fabric_thickness_mm + use_cu_upper_thickness + short + use_cu_lower_thickness +
           C(use_cu_type) + C(glass_fabric_type) + C(vend_nbr) + C(MacRecipe) + C(MacNo)
           """
reduced = smf.mixedlm(formula2, df_filtered, groups=df_filtered[group_for_mixed], re_formula="1").fit(reml=False, method='bfgs', maxiter=2000)

# df_diff = (len(full.params) - len(reduced.params))
df_diff = full.fe_params.size - reduced.fe_params.size   # 使用 fixed-effects 參數數量差

lr_stat = 2 * (full.llf - reduced.llf) 
p_value = chi2.sf(lr_stat, df=df_diff) 

print(f"Likelihood Ratio Test Results:")
print(f"LR Statistic: {lr_stat:.4f}")
print(f"Degrees of Freedom: {df_diff}")
print(f"p-value: {p_value:.4g}")
# Out:
# Likelihood Ratio Test Results:
# LR Statistic: 0.0000
# Degrees of Freedom: 0
# p-value: nan

# %%
md_reml = smf.mixedlm(formula, df_filtered, groups=df_filtered[group_for_mixed], re_formula="1")
mdf = md_reml.fit()
re = mdf.cov_re

with warnings.catch_warnings():
    # Parameter is often on the boundary
    warnings.simplefilter("ignore")
    likev = mdf.profile_re(0, "re", dist_low=0.1 , dist_high=0.1)

plt.figure(figsize=(10, 8))
plt.plot(likev[:, 0], 2 * likev[:, 1])
plt.xlabel("Variance of random slope", size=17)
lbl = plt.ylabel("-2 times profile log likelihood", size=17)

# %% [markdown]
# <p style="font-size: 14px; color: green;">畫殘差診斷圖 (QQ + Fitted vs Residuals)<p>

# %%
def plot_diagnostics(res_obj, fitted, resid, title_prefix):
    # 創建一個新的圖形，設置大小
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))
    
    # 第一個子圖：QQ圖
    sm.qqplot(resid, line='45', fit=True, ax=ax1)
    ax1.set_title(f'{title_prefix} QQ plot')

    # 第二個子圖：殘差圖
    ax2.scatter(fitted + np.random.normal(0, 1e-6, size=len(fitted)), resid, alpha=0.5, s=10)
    ax2.axhline(0, color='red', linestyle='--')
    ax2.set_xlabel('Fitted values (jittered)')
    ax2.set_ylabel('Residuals')
    ax2.set_title(f'{title_prefix} Residuals vs Fitted')
    
    plt.tight_layout()
    plt.show()

print("Diagnostics: Full model")
plot_diagnostics(full_mod['res_ml'], full_mod['fitted'], full_mod['resid'], 'Full')

print("Diagnostics: Filtered model")
plot_diagnostics(filtered_mod['res_ml'], filtered_mod['fitted'], filtered_mod['resid'], 'Filtered')
# Out:
# Diagnostics: Full model
# Diagnostics: Filtered model

# %%
durbin_watson(filtered_mod['resid']) # 獨立ok
# Out:
# np.float64(0.5410189601965899)

# %% [markdown]
# <p style="font-size: 14px; color: green;">ICC（群內相關係數） —> 直觀看 group variance 比例<p>

# %%
np.corrcoef(data['short'], data['d_PSVarX'])
# Out:
# array([[nan, nan],
#        [nan,  1.]])

# %%
md_full_reml = smf.mixedlm(formula, df, groups=df['Part_nbr_grouped'], re_formula="1")
res_full_reml = md_full_reml.fit(reml=True, method='bfgs', maxiter=2000)

md_filtered_reml = smf.mixedlm(formula, df_filtered, groups=df_filtered['Part_nbr_grouped'], re_formula="1")
res_filtered_reml = md_filtered_reml.fit(reml=True, method='bfgs', maxiter=2000)

def compute_icc(res, verbose=False):
    """
    從 statsmodels MixedLMResults 物件取出 group variance (cov_re) 與 residual variance (scale),
    並計算 ICC = group_var / (group_var + resid_var).
    支援 cov_re 為 DataFrame / ndarray / Series，及 >1 隨機效果的情形 (使用 trace).
    """
    # 1) 取得 cov_re，轉成 ndarray
    cov_re = getattr(res, 'cov_re', None)
    if cov_re is None:
        raise ValueError("res 物件沒有 cov_re 屬性。請確認 res 是 mixedlm 的 fit 結果。")

    # 將可能的 pandas 結構轉為 numpy array
    if isinstance(cov_re, pd.DataFrame) or isinstance(cov_re, pd.Series):
        cov_arr = cov_re.values
    else:
        cov_arr = np.asarray(cov_re)

    # 2) 決定 group variance 的計算方式
    # 若是 1x1，直接取 scalar；否則取 trace（總變異）
    if cov_arr.size == 1:
        group_var = float(cov_arr.ravel()[0])
    else:
        # 若 cov_arr 非方陣，嘗試取方陣部分；一般 cov_re 應為方陣
        if cov_arr.shape[0] != cov_arr.shape[1]:
            if verbose:
                print("警告：cov_re 不是方陣，shape =", cov_arr.shape)
            # 退而求其次：取對角和
            group_var = float(np.diag(cov_arr).sum())
        else:
            group_var = float(np.trace(cov_arr))

    # 3) 取得 residual variance
    resid_var = float(getattr(res, 'scale', np.nan))

    # 4) 數值穩定處理：如果出現負值(理論上不應該)，將其夾到 0
    if np.isnan(group_var) or np.isinf(group_var):
        raise ValueError("group_var 為 NaN 或 infinite，請檢查 fit 結果。")
    if group_var < 0:
        if verbose:
            print(f"注意：group_var = {group_var} < 0，將其設為 0.")
        group_var = 0.0
    if resid_var < 0:
        if verbose:
            print(f"注意：resid_var = {resid_var} < 0，將其設為 0.")
        resid_var = 0.0

    # 5) 計算 ICC（若分母為 0 則回傳 NaN）
    denom = group_var + resid_var
    icc = group_var / denom if denom > 0 else np.nan

    if verbose:
        print("cov_re type:", type(cov_re), "cov_re shape:", getattr(cov_re, 'shape', cov_arr.shape))
        print("group_var:", group_var, "resid_var:", resid_var, "ICC:", icc)

    return group_var, resid_var, icc


gvar_full, rvar_full, icc_full = compute_icc(res_full_reml, verbose=True)
gvar_filt, rvar_filt, icc_filt = compute_icc(res_filtered_reml, verbose=True)

print("FULL  -> group_var: {:.4f}, resid_var: {:.4f}, ICC: {:.3f}".format(gvar_full, rvar_full, icc_full))
print("FILTER-> group_var: {:.4f}, resid_var: {:.4f}, ICC: {:.3f}".format(gvar_filt, rvar_filt, icc_filt))

# ICC 就是「隨機效果總變異 / (總變異 + 殘差變異)」

# ICC 越高代表 Part_nbr 之間的差異相對於總變異越大（群間影響大）；ICC 低則群內變異占比高。

# 比較 full vs filtered 的 ICC，可以看出你過濾掉的資料佔了多少 between/within variation（你之前的數字顯示過濾後 both 減小）。
# Out:
# cov_re type: <class 'pandas.core.frame.DataFrame'> cov_re shape: (1, 1)
# group_var: 3.4274075841274474 resid_var: 4.118243445051695 ICC: 0.454222912095141
# cov_re type: <class 'pandas.core.frame.DataFrame'> cov_re shape: (1, 1)
# group_var: 0.5792720652560741 resid_var: 1.19930971989323 ICC: 0.3256932405880041
# FULL  -> group_var: 3.4274, resid_var: 4.1182, ICC: 0.454
# FILTER-> group_var: 0.5793, resid_var: 1.1993, ICC: 0.326

# %% [markdown]
# <p style="font-size: 14px; color: green;">特徵之間的相關性與共線性（VIF）<p>

# %%
X = df_filtered[['MacNo','MacRecipe', 'mtl_desc2', 'vend_nbr', 'layer_2Thick', 'plate_mtl_desc1',
                'plate_mtl_desc2', 'plate_vend_nbr', 'plate_layer_2Thick',
                'plate_RC_value', 'Residual_Copper_Rate', 'glass_fabric_thickness_mm',
                'use_cu_upper_thickness', 'use_cu_lower_thickness', 'use_cu_type',
                'glass_fabric_type', 'short']]

np.linalg.matrix_rank(X), X.shape[1]
# Out:
# (np.int64(17), 17)

# %%
import patsy
from statsmodels.stats.outliers_influence import variance_inflation_factor

# 建 design matrix for fixed-effects only
formula = """
d_PSVarX ~ layer_2Thick + plate_mtl_desc2 + plate_layer_2Thick + plate_RC_value +
           Residual_Copper_Rate + glass_fabric_thickness_mm + use_cu_upper_thickness + short + use_cu_lower_thickness
           """

design_info = smf.mixedlm(formula, df_filtered, groups=df_filtered[group_for_mixed]).fit_regularized(method='l1', alpha=1.0, reml=False).model.data.design_info
X = patsy.build_design_matrices([design_info], df_filtered)[0]
X_df = pd.DataFrame(X, columns = design_info.column_names)

# VIF (略去 intercept if present)
vif_data = pd.DataFrame()
vif_data["feature"] = X_df.columns
vif_data["VIF"] = [variance_inflation_factor(X_df.values, i) for i in range(X_df.shape[1])]
print(vif_data.sort_values('VIF', ascending=False).head(30))
# Out:
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1193: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(fe_params[j]) < ceps:
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1197: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   fe_params[j] = 0.
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1224: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   fe_params[j] = -(b + pwt1) / (2 * a)
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1222: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   fe_params[j] = -(b - pwt1) / (2 * a)
#                      feature           VIF
# 0                  Intercept  15381.907568
# 1               layer_2Thick      4.891260
# 6  glass_fabric_thickness_mm      4.552382
# 7     use_cu_upper_thickness      2.130753
# 9     use_cu_lower_thickness      2.128058
# 4             plate_RC_value      1.241743
# 3         plate_layer_2Thick      1.195052
# 5       Residual_Copper_Rate      1.140233
# 2            plate_mtl_desc2      1.104935
# 8                      short      1.005793

# %%
# import pandas as pd
# from patsy import dmatrix
# from sklearn.decomposition import PCA
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# # 1. 用 patsy 根據你的 formula 建立 design matrix（包含所有 dummy）
# design_info = smf.mixedlm(formula, df_filtered, groups=df_filtered[group_for_mixed]).fit_regularized(method='l1', alpha=1.0, reml=False).model.data.design_info
# X = patsy.build_design_matrices([design_info], df_filtered)[0]
# X_df = pd.DataFrame(X, columns=design_info.column_names)

# # 2. 找出哪些欄位是同一組 categorical dummy，例如 prefix 相同
# #    這裡示範以你的 categorical_cols 舉例，匹配 dummy 欄位名稱開頭

# grouped_dummies = {}
# for cat in categorical_cols:
#     grouped_dummies[cat] = [col for col in X_df.columns if col.startswith(f"C({cat})")]

# # 3. 對每組 dummy 用 PCA 取第一主成分，替代該組全部 dummy
# pca_features = []
# for cat, cols in grouped_dummies.items():
#     if len(cols) > 1:
#         pca = PCA(n_components=1)
#         pc1 = pca.fit_transform(X_df[cols])
#         pca_features.append(pd.Series(pc1.flatten(), name=f"PCA_{cat}"))
#     else:
#         # 只有一個dummy，直接用該欄位
#         pca_features.append(X_df[cols[0]])

# # 4. 保留數值變數原始欄位 (不含 categorical dummy 的部分)
# non_cat_cols = [col for col in X_df.columns if all(not col.startswith(f"C({cat})") for cat in categorical_cols)]

# # 5. 合併 PCA 轉換後的特徵和非類別特徵
# X_reduced = pd.concat([X_df[non_cat_cols]] + pca_features, axis=1)

# # 6. 計算 VIF
# vif_data = pd.DataFrame()
# vif_data["feature"] = X_reduced.columns
# vif_data["VIF"] = [variance_inflation_factor(X_reduced.values, i) for i in range(X_reduced.shape[1])]

# print(vif_data.sort_values('VIF', ascending=False))
# Out:
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1193: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if abs(fe_params[j]) < ceps:
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1197: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   fe_params[j] = 0.
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1224: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   fe_params[j] = -(b + pwt1) / (2 * a)
# C:\Python310\lib\site-packages\statsmodels\regression\mixed_linear_model.py:1222: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   fe_params[j] = -(b - pwt1) / (2 * a)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 15
#      11 # 2. 找出哪些欄位是同一組 categorical dummy，例如 prefix 相同
#      12 #    這裡示範以你的 categorical_cols 舉例，匹配 dummy 欄位名稱開頭
#      14 grouped_dummies = {}
# ---> 15 for cat in categorical_cols:
#      16     grouped_dummies[cat] = [col for col in X_df.columns if col.startswith(f"C({cat})")]
#      18 # 3. 對每組 dummy 用 PCA 取第一主成分，替代該組全部 dummy
#
# NameError: name 'categorical_cols' is not defined

# %%
explained_var_ratio = pca.explained_variance_ratio_[0]
print(f"PC1 explained variance ratio: {explained_var_ratio:.4f}")

# %%
# requirements:
# pip install scikit-learn statsmodels pandas numpy patsy

import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LassoCV, Lasso
from sklearn.model_selection import KFold
from statsmodels.stats.outliers_influence import variance_inflation_factor
import patsy
import warnings

warnings.filterwarnings("ignore")

# ------------------------
# 1) 建構設計矩陣函式
# ------------------------
def build_design_matrix(df, numeric_cols, categorical_cols, drop_first=True, handle_unknown='ignore'):
    """
    回傳 X (ndarray) 與 X_df (DataFrame with column names)
    - numeric_cols: list of numeric column names
    - categorical_cols: list of categorical column names
    - drop_first: whether to drop first dummy to avoid perfect multicollinearity
    """
    # ColumnTransformer with OneHotEncoder for categoricals
    ohe = OneHotEncoder(drop='first' if drop_first else None,
                        sparse_output=False, handle_unknown=handle_unknown)
    transformers = []
    if categorical_cols:
        transformers.append(('cat', ohe, categorical_cols))
    if numeric_cols:
        transformers.append(('num', 'passthrough', numeric_cols))
    ct = ColumnTransformer(transformers, remainder='drop', sparse_threshold=0)
    X_arr = ct.fit_transform(df)

    # build column names
    col_names = []
    if categorical_cols:
        cat_names = ct.named_transformers_['cat'].get_feature_names_out(categorical_cols)
        col_names.extend(list(cat_names))
    if numeric_cols:
        col_names.extend(numeric_cols)

    X_df = pd.DataFrame(X_arr, columns=col_names, index=df.index)
    return X_arr, X_df, ct

# ------------------------
# 2) 條件數（condition number）
# ------------------------
def condition_number(X, scaled=True):
    """
    計算 condition number = s_max / s_min (SVD singular values)
    若 scaled=True, 會先把 X 每 column 做標準化 (zero mean, unit var)
    """
    Xc = np.array(X, dtype=float)
    if scaled:
        Xc = (Xc - np.nanmean(Xc, axis=0)) / (np.nanstd(Xc, axis=0) + 1e-12)
    # SVD
    s = np.linalg.svd(Xc, compute_uv=False)
    # guard small singular values
    cond = float(s[0] / (s[-1] + 1e-20))
    return cond, s

# ------------------------
# 3) VIF 計算（只建議對數值或有限數量的 dummy）
# ------------------------
def compute_vif(X_df):
    """
    計算 VIF for each column in X_df. X_df should be a pandas DataFrame.
    Warning: VIF for many dummies may be noisy.
    """
    X = X_df.copy().astype(float)
    # add const to avoid singular design for VIF calc
    X['__const__'] = 1.0
    vif_vals = []
    cols = X.columns.tolist()
    for i, col in enumerate(cols[:-1]):  # skip const at the end
        try:
            vif = variance_inflation_factor(X.values, i)
        except Exception:
            vif = np.nan
        vif_vals.append((col, vif))
    return pd.DataFrame(vif_vals, columns=['feature', 'VIF']).sort_values('VIF', ascending=False)

# ------------------------
# 4) LassoCV pipeline fitting
# ------------------------
def fit_lasso_cv(X_df, y, n_alphas=100, cv=5, random_state=42):
    """
    Fit LassoCV and standardize features. Return fitted pipeline and report sparsity.
    """
    scaler = StandardScaler()
    lasso_cv = LassoCV(cv=cv, n_alphas=n_alphas, random_state=random_state, max_iter=2000)
    # Standardize X first
    Xs = scaler.fit_transform(X_df.values)
    lasso_cv.fit(Xs, y.values)
    alpha_opt = lasso_cv.alpha_
    coef = lasso_cv.coef_
    nonzero_idx = np.nonzero(coef)[0]
    nonzero_features = X_df.columns[nonzero_idx].tolist()
    sparsity = 1.0 - (len(nonzero_idx) / X_df.shape[1])
    report = {
        'alpha_opt': alpha_opt,
        'n_features': X_df.shape[1],
        'n_nonzero': len(nonzero_idx),
        'sparsity': sparsity,
        'nonzero_features': nonzero_features,
        'coef': pd.Series(coef, index=X_df.columns)
    }
    return lasso_cv, scaler, report

# ------------------------
# 5) Lasso 穩定性選擇 (bootstrap frequency)
# ------------------------
def lasso_stability_selection(X_df, y, n_boot=100, sample_frac=0.75, alpha=None, cv=3, random_state=0):
    """
    Repeated Lasso fits on bootstrap samples: return selection frequency for each feature.
    If alpha is None, use LassoCV on each bootstrap sample; otherwise use fixed alpha.
    """
    rng = np.random.RandomState(random_state)
    n = X_df.shape[0]
    sel_counts = np.zeros(X_df.shape[1], dtype=int)
    for i in range(n_boot):
        idx = rng.choice(n, size=int(sample_frac * n), replace=True)
        Xs = X_df.values[idx]
        ys = y.values[idx]
        scaler = StandardScaler()
        Xs = scaler.fit_transform(Xs)
        if alpha is None:
            model = LassoCV(cv=cv, random_state=rng.randint(1e6), max_iter=2000).fit(Xs, ys)
            alpha_i = model.alpha_
            lasso = Lasso(alpha=alpha_i, max_iter=2000).fit(Xs, ys)
        else:
            lasso = Lasso(alpha=alpha, max_iter=2000).fit(Xs, ys)
        sel_counts += (np.abs(lasso.coef_) > 1e-8).astype(int)
    freq = sel_counts / float(n_boot)
    return pd.Series(freq, index=X_df.columns).sort_values(ascending=False)

# ------------------------
# 6) 一個整合流程函式
# ------------------------
def collinearity_l1_diagnostics(df, target, numeric_cols, categorical_cols,
                                 do_vif=True, vif_limit_report=30, lasso_cv=True,
                                 stability_boot=100):
    """
    一鍵執行：建立設計矩陣、計算 condition number、(可選)VIF、LassoCV、以及穩定性測試
    回傳一個 dict 包含結果與 dataframe summary
    """
    # build design matrix
    X_arr, X_df, ct = build_design_matrix(df, numeric_cols, categorical_cols, drop_first=True)
    # drop columns with zero variance
    nz_mask = (X_df.std(axis=0) > 1e-12)
    if not nz_mask.all():
        X_df = X_df.loc[:, nz_mask]

    # compute condition number
    cond, svals = condition_number(X_df.values, scaled=True)

    out = {'X_df': X_df, 'condition_number': cond, 'singular_values': svals}

    # optionally compute VIF (warning: expensive for many cols)
    if do_vif:
        # if too many columns, skip or apply to top-k numeric/dummy
        if X_df.shape[1] > 300:
            out['vif'] = None
            out['vif_note'] = f"Too many features ({X_df.shape[1]}), skip full VIF. Consider subset VIF on numeric or top-k dummies."
        else:
            out['vif'] = compute_vif(X_df)
    # LassoCV fit
    if lasso_cv:
        y = df[target]
        lasso_model, scaler, lasso_report = fit_lasso_cv(X_df, y, cv=5)
        out['lasso_report'] = lasso_report
        # model performance on full data (just for quick check)
        Xs_full = scaler.transform(X_df.values)
        out['lasso_r2'] = lasso_model.score(Xs_full, y.values)
    # stability selection
    if stability_boot and lasso_cv:
        alpha_use = out['lasso_report']['alpha_opt']
        freq = lasso_stability_selection(X_df, df[target], n_boot=stability_boot, alpha=alpha_use)
        out['selection_freq'] = freq
    return out

# %%
df.columns

# %%
# ------------------------
# Example usage:
# ------------------------
# 假設 df 是你的 dataframe, target 為 'd_PSVarX'
# numeric_cols = ['mtl_desc2', 'layer_2Thick', 'plate_mtl_desc2', 'plate_layer_2Thick', 'plate_RC_value', 'Residual_Copper_Rate', 
#                 'glass_fabric_thickness_mm', 'use_cu_upper_thickness', 'use_cu_lower_thickness', 'short']
numeric_cols = [ 'layer_2Thick', 'plate_mtl_desc2', 'plate_layer_2Thick', 'plate_RC_value', 'Residual_Copper_Rate', 
                 'glass_fabric_thickness_mm', 'use_cu_upper_thickness', 'use_cu_lower_thickness', 'short']

categorical_cols = ['use_cu_type', 'glass_fabric_type', 'vend_nbr', 'MacRecipe', 'MacNo']
res = collinearity_l1_diagnostics(df_filtered, target='d_PSVarX', numeric_cols=numeric_cols, categorical_cols = [],
                                  do_vif=False, lasso_cv=True, stability_boot=100)

# then:
print("Condition number:", res['condition_number'])
print("Lasso alpha", res['lasso_report']['alpha_opt'])
print("Nonzero features:", res['lasso_report']['n_nonzero'])
print("Top selection freq:\n", res['selection_freq'].head(30))

# %%
def weighted_mean_encoding(df, cat_col, target, weight_col=None):
    if weight_col is None:
        # 權重為1（等權）
        weight_col = '__w__'
        df[weight_col] = 1

    weighted_means = (
        df.groupby(cat_col)
          .apply(lambda g: (g[target] * g[weight_col]).sum() / g[weight_col].sum())
          .to_dict()
    )

    return df[cat_col].map(weighted_means)

# 建立新 DataFrame 做 encoding
df_encoded = df_filtered.copy()

# 用加權平均編碼 categorical_cols
for col in categorical_cols:
    df_encoded[col] = weighted_mean_encoding(
        df_encoded, 
        cat_col=col, 
        target='d_PSVarX', 
        weight_col=None  # 如果有特定權重欄位可以換掉
    )

# 再跑 collinearity_l1_diagnostics
numeric_cols_extended = numeric_cols + categorical_cols  # 因為編碼後都是數字
res = collinearity_l1_diagnostics(
    df_encoded, 
    target='d_PSVarX', 
    numeric_cols=numeric_cols_extended, 
    categorical_cols=[],  # 已經轉成數值
    do_vif=False, 
    lasso_cv=True, 
    stability_boot=100
)

print("Condition number:", res['condition_number'])
print("Lasso alpha", res['lasso_report']['alpha_opt'])
print("Nonzero features:", res['lasso_report']['n_nonzero'])
print("Top selection freq:\n", res['selection_freq'].head(30))

# %% [markdown]
# <p style="font-size: 14px; color: green;">找出對殘差貢獻最大的 Part_nbr / Lot_nbr<p>
