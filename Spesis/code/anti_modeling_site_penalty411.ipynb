# %%
import pandas as pd
import numpy as np
import re 
from IPython.display import display, HTML

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV 
from sklearn.metrics import classification_report, confusion_matrix, f1_score, hamming_loss, jaccard_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from xgboost import XGBClassifier
from sklearn.multioutput import MultiOutputClassifier, ClassifierChain
from sklearn.calibration import CalibratedClassifierCV
from scipy.stats import entropy

import shap

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

data= pd.read_csv(r"‪D:\ML Data\Spesis\anti_total.csv".strip('\u202a'), index_col=False)

# %% [raw]
# 先過濾<500，再分有無感染部位，免得有些抗生素消失(Clindamycin, Gentamicin)

# %% [raw]
# 過濾抗生素使用<500次的，後刪除沒給抗生素的(沒有)

# %%
start_index = data.columns.get_loc('Acyclovir')
end_index = data.columns.get_loc('tenofovir/emtricitabine/rilpivirine')

# %%
abx_cols = data.columns[start_index:end_index+1]
col_sum = data[abx_cols].sum()

# %%
abx_cols = data.columns[start_index:end_index+1]
col_sum = data[abx_cols].sum()

# %%
final_cols = col_sum[col_sum >= 400].index.tolist()
base_cols = [c for c in data.columns if c not in abx_cols]
data_filter = data[base_cols + final_cols]

# %%
data_filter[final_cols].sum().sort_values(ascending=False)
# Out:
# Amoxicillin/Clavulanic acid    5515.0
# Flomoxef                       5196.0
# Cefazolin                      2371.0
# Cefixime                       2166.0
# Ciprofloxacin                  2071.0
# Azithromycin                   2053.0
# Cefuroxime                     1691.0
# Piperacillin/Tazobactam        1511.0
# Cefoperazone/sulbactam         1412.0
# Peramivir                      1119.0
# Baloxavir marboxil             1085.0
# Metronidazole                  1020.0
# Cefadroxil                      918.0
# Oseltamivir                     835.0
# Levofloxacin                    720.0
# Clindamycin                     624.0
# Gentamicin                      623.0
# Ceftriaxone                     610.0
# Cephalexin                      517.0
# Ampicillin                      423.0
# dtype: float64

# %% [raw]
# 分出有感染部位紀錄的data

# %%
all_site_cols = [
    'INFECTIONSITE1', 'INFECTIONSITE2', 'INFECTIONSITE3',
    'INFECTIONSITE4', 'INFECTIONSITE5', 'INFECTIONSITE9', 
    'OTHERINFECTIONSITE_flag'
]

temp_df = data_filter[all_site_cols].copy().astype(str).apply(lambda x: x.str.strip())
temp_df = temp_df.replace(['', 'nan', 'None', 'nan.0'], '0')

temp_df = temp_df.astype(float)

has_site_mask = (temp_df > 0).any(axis=1)

site_samples = data[has_site_mask].copy()

print(f"原始樣本數: {len(data)}")
print(f"至少標註一個部位的樣本數: {len(site_samples)}")
print(f"被排除掉的『全空/全0』樣本數: {len(data) - len(site_samples)}")
# Out:
# 原始樣本數: 27968
# 至少標註一個部位的樣本數: 11880
# 被排除掉的『全空/全0』樣本數: 16088

# %%
len(site_samples), len(site_samples['ACCOUNTNO'])
# Out:
# (11880, 11880)

# %%
site_samples['Clindamycin'].sum(), site_samples['Gentamicin'].sum()
# Out:
# (np.float64(379.0), np.float64(201.0))

# %%
roomno_mapping = {'A': '1', 'C': '2', 'D': '3', 'E': '4', 'H': '5', 'K': '6'}
site_samples['ROOMNO'] = site_samples['ROOMNO'].map(roomno_mapping)          

site_samples['SEX'] = site_samples['SEX'].map({'M': 1, 'F': 0})

yn_cols = [
    'ISSEPSIS0', 'FEVER', 'DM', 'CARDIOVASCULAR', 
    'RESPIRATORY', 'CNS', 'CANCER', 'LIVER', 'KIDNEY', 'AUTOIMMUNE'
]

for col in yn_cols:
    site_samples[col] = site_samples[col].map({'Y': 1, 'N': 0})

# %%
feature_cols = list(set(site_samples.columns) - set(abx_cols))
X = site_samples[feature_cols]
y = site_samples[final_cols]

# %%
X.shape, y.shape
# Out:
# ((11880, 68), (11880, 20))

# %%
X = X.drop(columns=['ACCOUNTNO','ROOMNO', 'INTIME', 'Influenza Virus A level', 'FIRST_ORDERTIME', 'ISSEPSIS0'])
y = y.drop(columns=['Peramivir', 'Baloxavir marboxil', 'Oseltamivir', 'Cephalexin', 'Cefadroxil'])
                    #'Amoxicillin', 'Doxycycline', 'Acyclovir', 'Valaciclovir', 'Tenofovir alafenamide', 'Ceftazidime'])# 去掉抗病毒的藥(前3)

# %%
# 找出至少有一種藥物的樣本 (Row sum > 0)
has_label_mask = (y.sum(axis=1) > 0)

# 同步過濾 X 和 y
X = X[has_label_mask]
y = y[has_label_mask]

print(f"原本樣本數: {len(has_label_mask)}")
print(f"過濾後樣本數: {len(y)}")
print(f"已刪除 {len(has_label_mask) - len(y)} 筆因刪除藥物欄位而變成『無給藥』的樣本")
# Out:
# 原本樣本數: 11880
# 過濾後樣本數: 11470
# 已刪除 410 筆因刪除藥物欄位而變成『無給藥』的樣本

# %%
X.columns
# Out:
# Index(['VITALSIGNSSPO2', 'VITALSIGNSGCS', 'AUTOIMMUNE', 'GPT',
#        'Microscopic RBC level', 'CHECKITEM30SCORE', 'Ht', 'PT', 'Lymphocyte',
#        'Hb', 'PLT', 'K', 'HST', 'CHECKITEM27SCORE', 'CANCER',
#        'CHECKITEM29SCORE', 'FEVER', 'CNS', 'VITALSIGNSBT', 'Bacteria level',
#        'INR', 'Microscopic WBC level', 'Neutrophil Seg.', 'PH', 'CRP',
#        'T.Bilirubin', 'RESPIRATORY', 'APTT', 'INFECTIONSITE2', 'INJURELEVEL',
#        'VITALSIGNSRR', 'Nitrite level', 'INFECTIONSITE4', 'StayTime_hours',
#        'CARDIOVASCULAR', 'PCO2', 'Na', 'KIDNEY', 'INFECTIONSITE9',
#        'VITALSIGNSPR', 'CHECKITEM32SCORE', 'INFECTIONSITE5', 'INFECTIONSITE3',
#        'LIVER', 'VITALSIGNSDBP', 'Absolute Neutrophil count', 'O2 SAT', 'WBC',
#        'Leukocyte level', 'OTHERINFECTIONSITE_flag', 'DM', 'MAP', 'Creatinine',
#        'INFECTIONSITE1', 'CHECKITEM28A', 'CHECKITEM27', 'AGE', 'BE(ecf)',
#        'HCO3', 'CHECKITEM28SCORE', 'SEX', 'CHECKITEM31SCORE'],
#       dtype='object')

# %%
y[y.columns].sum().sort_values(ascending=False)
# Out:
# Flomoxef                       5190.0
# Amoxicillin/Clavulanic acid    1581.0
# Piperacillin/Tazobactam        1509.0
# Cefoperazone/sulbactam         1411.0
# Metronidazole                   916.0
# Ciprofloxacin                   872.0
# Cefixime                        851.0
# Azithromycin                    695.0
# Ceftriaxone                     609.0
# Cefazolin                       589.0
# Levofloxacin                    501.0
# Cefuroxime                      497.0
# Clindamycin                     379.0
# Gentamicin                      201.0
# Ampicillin                       88.0
# dtype: float64

# %% [raw]
# 建立flag for missing above 80%

# %%
####################### Missing 70~80% #######################

# 檢驗

X['Leukocyte level_flag'] = (
     X['Leukocyte level'].fillna('').str.strip().ne('').astype(int))

X['Nitrite level_flag'] = (
     X['Nitrite level'].fillna('').str.strip().ne('').astype(int))

X['Bacteria level_flag'] = (
     X['Bacteria level'].fillna('').str.strip().ne('').astype(int))

X['Microscopic RBC level_flag'] = (
     X['Microscopic RBC level'].fillna('').str.strip().ne('').astype(int))

X['Microscopic WBC level_flag'] = (
     X['Microscopic WBC level'].fillna('').str.strip().ne('').astype(int))

X['PH_flag'] = (
     X['Microscopic RBC level'].fillna('').str.strip().ne('').astype(int))



# 計分

X['CHECKITEM29SCORE_flag'] = (
     X['CHECKITEM29SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM30SCORE_flag'] = (
     X['CHECKITEM30SCORE'].fillna('').str.strip().ne('').astype(int))


####################### Missing > 80% #######################

# 檢驗

X['HST_flag'] = (
     X['HST'].fillna('').str.strip().ne('').astype(int))

X['T.Bilirubin_flag'] = (
     X['T.Bilirubin'].fillna('').str.strip().ne('').astype(int))

X['PT_flag'] = (
     X['PT'].fillna('').str.strip().ne('').astype(int))

X['HST_flag'] = (
     X['HST'].fillna('').str.strip().ne('').astype(int))

X['INR_flag'] = (
     X['INR'].fillna('').str.strip().ne('').astype(int))

X['APTT_flag'] = (
     X['APTT'].fillna('').str.strip().ne('').astype(int))

X['PCO2_flag'] = (
     X['PCO2'].fillna('').str.strip().ne('').astype(int))

X['HCO3_flag'] = (
     X['HCO3'].fillna('').str.strip().ne('').astype(int))


X['BE(ecf)_flag'] = (
     X['BE(ecf)'].fillna('').str.strip().ne('').astype(int))

X['O2 SAT_flag'] = (
     X['O2 SAT'].fillna('').str.strip().ne('').astype(int))

# 計分

X['CHECKITEM28A_flag'] = (
     X['CHECKITEM28A'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM27_flag'] = (
     X['CHECKITEM27'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM27SCORE_flag'] = (
     X['CHECKITEM27SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM28SCORE_flag'] = (
     X['CHECKITEM28SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM31SCORE_flag'] = (
     X['CHECKITEM31SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM32SCORE_flag'] = (
     X['CHECKITEM32SCORE'].fillna('').str.strip().ne('').astype(int))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

df = X

vital_cols = list(set(['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
            'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']))

# 設定每列顯示幾個圖
cols_per_row = 4
rows = math.ceil(len(vital_cols) / cols_per_row)

# 建立畫布
fig, axes = plt.subplots(rows, cols_per_row, figsize=(20, rows * 4))
axes = axes.flatten() # 將多維陣列拉平，方便迴圈讀取

for i, col in enumerate(vital_cols):
    if col in df.columns:
        # 繪製直方圖 + 密度曲線(kde)
        sns.histplot(df[col].dropna(), kde=True, ax=axes[i], bins=30)
        axes[i].set_title(f'Distribution of {col}', fontsize=12)
        axes[i].set_xlabel('')
        axes[i].set_ylabel('')
    else:
        axes[i].set_axis_off() # 如果欄位不存在就留白

# 移除多餘的空白子圖
for j in range(i + 1, len(axes)):
    axes[j].set_axis_off()

plt.tight_layout()
plt.show()

# %%
lower_bound = X.quantile(0.01)
upper_bound = X.quantile(0.99)

outliers_low = (X < lower_bound).sum()
outliers_high = (X > upper_bound).sum()

outlier_summary = pd.DataFrame({
    'Low_Outliers (<1%)': outliers_low,
    'High_Outliers (>99%)': outliers_high,
    'Total_Outliers': outliers_low + outliers_high
})

print(f"全資料集總離群值筆數: {outlier_summary['Total_Outliers'].sum()}")
print("\n各欄位離群值統計 (前 10 名):")
print(outlier_summary.sort_values('Total_Outliers', ascending=False).head(10))
# Out:
# 全資料集總離群值筆數: 3916
#
# 各欄位離群值統計 (前 10 名):
#                            Low_Outliers (<1%)  High_Outliers (>99%)  \
# VITALSIGNSPR                              105                   113
# MAP                                        99                   105
# VITALSIGNSDBP                             101                    98
# WBC                                        93                    93
# VITALSIGNSBT                               90                    96
# Ht                                         93                    91
# PLT                                        92                    92
# Absolute Neutrophil count                  92                    92
# Lymphocyte                                 84                    93
# Creatinine                                 85                    91
#
#                            Total_Outliers
# VITALSIGNSPR                          218
# MAP                                   204
# VITALSIGNSDBP                         199
# WBC                                   186
# VITALSIGNSBT                          186
# Ht                                    184
# PLT                                   184
# Absolute Neutrophil count             184
# Lymphocyte                            177
# Creatinine                            176

# %%
# outlier修改為1%或99% quantile
X = X.clip(lower=lower_bound, upper=upper_bound, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((9176, 85), (9176, 15), (2294, 85), (2294, 15))

# %%
X_train.isnull().sum(), X_test.isnull().sum()
# Out:
# (VITALSIGNSSPO2           1501
#  VITALSIGNSGCS              91
#  AUTOIMMUNE                  0
#  GPT                      2194
#  Microscopic RBC level    5148
#                           ...
#  CHECKITEM27_flag            0
#  CHECKITEM27SCORE_flag       0
#  CHECKITEM28SCORE_flag       0
#  CHECKITEM31SCORE_flag       0
#  CHECKITEM32SCORE_flag       0
#  Length: 85, dtype: int64,
#  VITALSIGNSSPO2            347
#  VITALSIGNSGCS              22
#  AUTOIMMUNE                  0
#  GPT                       515
#  Microscopic RBC level    1306
#                           ...
#  CHECKITEM27_flag            0
#  CHECKITEM27SCORE_flag       0
#  CHECKITEM28SCORE_flag       0
#  CHECKITEM31SCORE_flag       0
#  CHECKITEM32SCORE_flag       0
#  Length: 85, dtype: int64)

# %%
X_train.dtypes, X_test.dtypes
# Out:
# (VITALSIGNSSPO2           float64
#  VITALSIGNSGCS            float64
#  AUTOIMMUNE                 int64
#  GPT                      float64
#  Microscopic RBC level    float64
#                            ...
#  CHECKITEM27_flag           int64
#  CHECKITEM27SCORE_flag      int64
#  CHECKITEM28SCORE_flag      int64
#  CHECKITEM31SCORE_flag      int64
#  CHECKITEM32SCORE_flag      int64
#  Length: 85, dtype: object,
#  VITALSIGNSSPO2           float64
#  VITALSIGNSGCS            float64
#  AUTOIMMUNE                 int64
#  GPT                      float64
#  Microscopic RBC level    float64
#                            ...
#  CHECKITEM27_flag           int64
#  CHECKITEM27SCORE_flag      int64
#  CHECKITEM28SCORE_flag      int64
#  CHECKITEM31SCORE_flag      int64
#  CHECKITEM32SCORE_flag      int64
#  Length: 85, dtype: object)

# %%
y_train.sum().sort_values(ascending=False)
# Out:
# Flomoxef                       4148.0
# Amoxicillin/Clavulanic acid    1253.0
# Piperacillin/Tazobactam        1199.0
# Cefoperazone/sulbactam         1140.0
# Metronidazole                   752.0
# Ciprofloxacin                   702.0
# Cefixime                        695.0
# Azithromycin                    544.0
# Ceftriaxone                     489.0
# Cefazolin                       466.0
# Cefuroxime                      399.0
# Levofloxacin                    394.0
# Clindamycin                     300.0
# Gentamicin                      171.0
# Ampicillin                       78.0
# dtype: float64

# %%
# 轉數值

num_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
            'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']

for col in num_cols:
    X_train[col] = pd.to_numeric(X_train[col], errors='coerce')
    X_test[col] = pd.to_numeric(X_test[col], errors='coerce')

# %%
# vital sign impute
vital_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
              'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']


for col in vital_cols:
    # X_train[col + "_missing"] = X_train[col].isna().astype(int) # missing indicator
    median = X_train[col].median()
    X_train[col] = X_train[col].fillna(median)
    
    # X_test[col + "_missing"] = X_test[col].isna().astype(int) # missing indicator
    X_test[col] = X_test[col].fillna(median)

# %%
# 取 log

X_train['CRP'] = np.log1p(X_train['CRP'])
X_test['CRP'] = np.log1p(X_test['CRP'])

X_train['PLT'] = np.log1p(X_train['PLT'])
X_test['PLT'] = np.log1p(X_test['PLT'])

X_train['WBC'] = np.log1p(X_train['WBC'])
X_test['WBC'] = np.log1p(X_test['WBC'])

X_train['AGE'] = np.log1p(X_train['AGE'])
X_test['AGE'] = np.log1p(X_test['AGE'])

X_train['K'] = np.log1p(X_train['K'])
X_test['K'] = np.log1p(X_test['K'])

X_train['GPT'] = np.log1p(X_train['GPT'])
X_test['GPT'] = np.log1p(X_test['GPT'])

X_train['VITALSIGNSSPO2'] = np.log1p(X_train['VITALSIGNSSPO2'])
X_test['VITALSIGNSSPO2'] = np.log1p(X_test['VITALSIGNSSPO2'])

X_train['Absolute Neutrophil count'] = np.log1p(X_train['Absolute Neutrophil count'])
X_test['Absolute Neutrophil count'] = np.log1p(X_test['Absolute Neutrophil count'])

X_train['VITALSIGNSBT'] = np.log1p(X_train['VITALSIGNSBT'])
X_test['VITALSIGNSBT'] = np.log1p(X_test['VITALSIGNSBT'])

X_train['VITALSIGNSRR'] = np.log1p(X_train['VITALSIGNSRR'])
X_test['VITALSIGNSRR'] = np.log1p(X_test['VITALSIGNSRR'])

X_train['Creatinine'] = np.log1p(X_train['Creatinine'])
X_test['Creatinine'] = np.log1p(X_test['Creatinine'])

X_train['Na'] = np.log1p(X_train['Na'])
X_test['Na'] = np.log1p(X_test['Na'])

# X_train['Lymphocyte'] = np.log1p(X_train['Lymphocyte'])
# X_test['Lymphocyte'] = np.log1p(X_test['Lymphocyte'])

# %%
# fill score

score_cols = ['Leukocyte level_flag', 'Nitrite level_flag', 'Bacteria level_flag', 'Microscopic RBC level_flag', 'Microscopic WBC level_flag', 'PH_flag',
              'CHECKITEM29SCORE_flag', 'CHECKITEM30SCORE_flag', # 70~80% missing
              'HST_flag','T.Bilirubin_flag', 'PT_flag', 'HST_flag', 'INR_flag', 'APTT_flag', 'PCO2_flag', 'HCO3_flag', 'BE(ecf)_flag',
              'O2 SAT_flag', 'CHECKITEM28A_flag', 'CHECKITEM27_flag', 'CHECKITEM27SCORE_flag', 'CHECKITEM28SCORE_flag', 
              'CHECKITEM31SCORE_flag', 'CHECKITEM32SCORE_flag'] # > 80% missing

for col in score_cols:
    X_train[col] = pd.to_numeric(X_train[col], errors='coerce')
    X_train[col] = X_train[col].fillna(-1)

    X_test[col] = pd.to_numeric(X_test[col], errors='coerce')
    X_test[col] = X_test[col].fillna(-1)

# %%
y_train.sum(axis=1).mean() # 每人平均用1.4個抗生素
# Out:
# np.float64(1.3873147340889276)

# %%
drop_cols = ['HST', 'Leukocyte level' , 'Nitrite level', 'Bacteria level', 'Microscopic RBC level', 'Microscopic WBC level' , 
             'PH', 'T.Bilirubin', 'PT' , 'INR', 'APTT', 'PCO2' , 'HCO3', 'BE(ecf)', 'O2 SAT', 
             'CHECKITEM28A', 'CHECKITEM27', 'CHECKITEM27SCORE', 'CHECKITEM28SCORE', 'CHECKITEM29SCORE', 'CHECKITEM30SCORE', 
             'CHECKITEM31SCORE', 'CHECKITEM32SCORE']

X_train = X_train.drop(columns=drop_cols)
X_test = X_test.drop(columns=drop_cols)

# %%
scaled_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
               'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']

scaler = StandardScaler()

X_train[scaled_cols] = scaler.fit_transform(X_train[scaled_cols])
X_test[scaled_cols] = scaler.fit_transform(X_test[scaled_cols])

# %%
X_train.shape
# X_train.to_csv('X_train_scale.csv')
# Out:
# (9176, 62)

# %%
y_train.columns
# Out:
# Index(['Amoxicillin/Clavulanic acid', 'Ampicillin', 'Azithromycin',
#        'Cefazolin', 'Cefixime', 'Cefoperazone/sulbactam', 'Ceftriaxone',
#        'Cefuroxime', 'Ciprofloxacin', 'Clindamycin', 'Flomoxef', 'Gentamicin',
#        'Levofloxacin', 'Metronidazole', 'Piperacillin/Tazobactam'],
#       dtype='object')

# %%
X_train.columns
# Out:
# Index(['VITALSIGNSSPO2', 'VITALSIGNSGCS', 'AUTOIMMUNE', 'GPT', 'Ht',
#        'Lymphocyte', 'Hb', 'PLT', 'K', 'CANCER', 'FEVER', 'CNS',
#        'VITALSIGNSBT', 'Neutrophil Seg.', 'CRP', 'RESPIRATORY',
#        'INFECTIONSITE2', 'INJURELEVEL', 'VITALSIGNSRR', 'INFECTIONSITE4',
#        'StayTime_hours', 'CARDIOVASCULAR', 'Na', 'KIDNEY', 'INFECTIONSITE9',
#        'VITALSIGNSPR', 'INFECTIONSITE5', 'INFECTIONSITE3', 'LIVER',
#        'VITALSIGNSDBP', 'Absolute Neutrophil count', 'WBC',
#        'OTHERINFECTIONSITE_flag', 'DM', 'MAP', 'Creatinine', 'INFECTIONSITE1',
#        'AGE', 'SEX', 'Leukocyte level_flag', 'Nitrite level_flag',
#        'Bacteria level_flag', 'Microscopic RBC level_flag',
#        'Microscopic WBC level_flag', 'PH_flag', 'CHECKITEM29SCORE_flag',
#        'CHECKITEM30SCORE_flag', 'HST_flag', 'T.Bilirubin_flag', 'PT_flag',
#        'INR_flag', 'APTT_flag', 'PCO2_flag', 'HCO3_flag', 'BE(ecf)_flag',
#        'O2 SAT_flag', 'CHECKITEM28A_flag', 'CHECKITEM27_flag',
#        'CHECKITEM27SCORE_flag', 'CHECKITEM28SCORE_flag',
#        'CHECKITEM31SCORE_flag', 'CHECKITEM32SCORE_flag'],
#       dtype='object')

# %%
# LogisticRegressionCV?
# XGBClassifier?
# RandomForestClassifier?
# MultiOutputClassifier.fit?

# %%
base_model = XGBClassifier(n_estimators=300,
                           max_depth=5,
                           learning_rate=0.05,
                           subsample=0.8,
                           colsample_bytree=0.8,
                           eval_metric='logloss',
                           gamma=0,
                           reg_alpha=2,
                           reg_lambda=0.0,
                           min_child_weight=1,
                           scale_pos_weight=2,
                           random_state =123,
                           n_jobs=-1
    )


multi_model = MultiOutputClassifier(base_model)
multi_model.fit(X_train, y_train) # sample_weight=sample_weight

#################################################################################################

# # 用字典存所有的子模型
# models = {}

# for col in y_train.columns:
#     # 針對每一種抗生素動態計算比例
#     pos = y_train[col].sum()
#     neg = len(y_train) - pos
#     spw = neg / pos if pos > 0 else 1
    
#     # 為該藥物建立專屬模型
#     model = XGBClassifier(
#                            n_estimators=300,
#                            max_depth=5,
#                            learning_rate=0.05,
#                            subsample=0.8,
#                            colsample_bytree=0.8,
#                            eval_metric='logloss',
#                            gamma=0,
#                            reg_alpha=2.0,
#                            reg_lambda=0.0,
#                            min_child_weight=1,
#                            scale_pos_weight=spw,
#                            random_state =123,
#                            n_jobs=-1
#     )
    
#     print(f"正在訓練 {col}, scale_pos_weight: {spw:.2f}")
#     model.fit(X_train, y_train[col])
#     models[col] = model

# # 預測時手動合併
# y_prob_list = np.column_stack([models[col].predict_proba(X_test)[:, 1] for col in y_train.columns])
# Out:
# MultiOutputClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=0.8, device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric='logloss',
#                                               feature_types=None, gamma=0,
#                                               grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learning_rate=0.05, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=5,
#                                               max_leaves=None,
#                                               min_child_weight=1, missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=300, n_jobs=-1,
#                                               num_parallel_tree=None,
#                                               random_state=123, ...))

# %%
y_pred_train = multi_model.predict(X_train)
print(f1_score(y_train, y_pred_train, average='micro'))
print(f1_score(y_train, y_pred_train, average='macro'))
# Out:
# 0.8250295159386068
# 0.8493918016318938

# %%
# # # 原始機率
y_prob_list = np.column_stack([multi_model.predict_proba(X_test)[:, 1] for multi_model in multi_model.estimators_])
y_pred = multi_model.predict(X_test)
# print(y_pred[:5])

# 計算每種抗生素的使用頻率
drug_freq = y_train.mean(axis=0).values
drug_freq = np.clip(drug_freq, 1e-6, None) #避免除以0

# 計算每種抗生素權重(F1/recall)
drug_weight = []

# 用y_train去計算f1，或用cv
for i, col in enumerate(y_train.columns):
    score = 1 / (f1_score(y_train.values[:, i], y_pred_train[:, i], average='binary') + 1e-6)
    drug_weight.append(score)

drug_weight = np.clip(drug_weight, 1e-6, None)

#  normalize
drug_weight = drug_weight / drug_weight.mean()

alpha = 0.01 # penalty
belta = 0.9

# adjusted_scores = y_prob_list / (drug_freq ** alpha)
# adjusted_scores = (np.log(y_prob_list + 1e-8)+ belta * np.log(drug_weight)- alpha * np.log(drug_freq))
adjusted_scores = y_prob_list * drug_weight ** belta - alpha * np.log(drug_freq)

# %%
drug_weight
# Out:
# array([0.94679715, 0.84143384, 0.93852225, 0.95214869, 1.20204782,
#        1.08932705, 1.08550327, 1.05255145, 1.10804511, 0.89197928,
#        1.03489812, 0.85664046, 1.00414994, 0.9587044 , 1.03725115])

# %%
drug_weight ** belta
# Out:
# array([0.9519875 , 0.85608715, 0.94449598, 0.95682893, 1.18012924,
#        1.08004652, 1.07663383, 1.04717436, 1.09673498, 0.90223421,
#        1.03135419, 0.86999894, 1.00373418, 0.96275604, 1.03346443])

# %%
print(f1_score(y_test, y_pred, average='micro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# 0.5031743152548521
# 0.3305265558368426

# %%
jaccard_score(y_test, y_pred, average='samples', zero_division=0)
# Out:
# np.float64(0.4338927637314734)

# %%
hamming_loss(y_test, y_pred)
# Out:
# 0.07959895379250218

# %%
# top k hits rate

def hit_rate_at_k(y_true, proba, k=3):
    
    if isinstance(proba, list):
       proba = np.column_stack([p[:, 1] for p in proba])
    
    topk = np.argsort(proba, axis=1)[:, -k:]
    hits = 0
    for i in range(len(y_true)):
        actual = np.where(y_true[i]==1)[0]
        if len(set(actual)& set(topk[i].tolist())):
            hits += 1
    return hits /  len(y_true)

# precision@3
def precision_at_k(y_true, proba, k=3):
    # 處理 MultiOutputClassifier 的 proba 格式 (list of arrays)
    if isinstance(proba, list):
       proba = np.column_stack([p[:, 1] for p in proba])
    
    # 取得機率最高的前 k 個索引
    topk = np.argsort(proba, axis=1)[:, -k:]
    
    total_precision = 0
    for i in range(len(y_true)):
        # 該病患實際有開的藥物索引
        actual = set(np.where(y_true[i] == 1)[0])
        # 預測的前 k 個藥物索引
        predicted = set(topk[i].tolist())
        
        # 交集數量 (中了幾個) / 推薦數量 k
        hits = len(actual & predicted)
        total_precision += (hits / k)
        
    # 回傳所有樣本的平均 Precision@k
    return total_precision / len(y_true)

# recall@3

def recall_at_k(y_true, proba, k=3):
    if isinstance(proba, list):
        proba = np.column_stack([p[:, 1] for p in proba])

    topk = np.argsort(proba, axis=1)[:, -k:]
    hits = 0
    recalls = []
    for i in range(len(y_true)):
        actual = np.where(y_true[i]==1)[0]
        if len(actual) == 0:
            continue
        recall = len(set(actual) & set(topk[i])) / len(actual)
        recalls.append(recall)
    return np.mean(recalls)

# MAP@3

def map_at_k(y_true, scores, k=3):

    topk = np.argsort(scores, axis=1)[:, ::-1][:, :k]  # 排序

    APs = []

    for i in range(len(y_true)):
        actual = np.where(y_true[i] == 1)[0]

        if len(actual) == 0:
            continue

        hits = 0
        score = 0

        for j in range(k):
            if topk[i][j] in actual:
                hits += 1
                score += hits / (j + 1)

        APs.append(score / min(len(actual), k))

    return np.mean(APs)


################################

hit3 = hit_rate_at_k(y_test.values, adjusted_scores, k=5)
print('Hit@3: ', hit3)
precision3 = precision_at_k(y_test.values, adjusted_scores, k=5)
print('precision@3: ', precision3)
recall_3 = recall_at_k(y_test.values, adjusted_scores, k=5)
print('Recall@3: ', recall_3)
map_3 = map_at_k(y_test.values, adjusted_scores, k=5)
print('MAP@3: ', map_3)
# Out:
# Hit@3:  0.9241499564080209
# precision@3:  0.23775065387968122
# Recall@3:  0.8763077593722755
# MAP@3:  0.6621651893829312

# %%
drug_names = y_train.columns


def show_top3_prediction(patient_idx, proba_matrix, y_true, drug_names, k=3):
    #預測
    probs = proba_matrix[patient_idx]
    topk_idx = np.argsort(probs)[-k:][::-1]

    #實際
    actual_idx = np.where(y_true[patient_idx] == 1)[0]
    actual_drugs = drug_names[actual_idx].tolist()

    print(f"實際給藥: {actual_drugs if actual_drugs else '無'}")
    print("\n推薦藥物:")
    for rank, idx in enumerate(topk_idx, 1):
        print(f"{rank}. {drug_names[idx]} (Score: {probs[idx]:.4f})")
    print("="*50)

for i in range(10):
    show_top3_prediction(i, adjusted_scores, y_test.values, drug_names, k=10)
# Out:
# 實際給藥: ['Cefoperazone/sulbactam']
#
# 推薦藥物:
# 1. Flomoxef (Score: 0.8205)
# 2. Cefoperazone/sulbactam (Score: 0.3523)
# 3. Cefixime (Score: 0.2701)
# 4. Azithromycin (Score: 0.2491)
# 5. Piperacillin/Tazobactam (Score: 0.1777)
# 6. Ceftriaxone (Score: 0.1026)
# 7. Metronidazole (Score: 0.0861)
# 8. Ciprofloxacin (Score: 0.0811)
# 9. Levofloxacin (Score: 0.0513)
# 10. Amoxicillin/Clavulanic acid (Score: 0.0510)
# ==================================================
# 實際給藥: ['Levofloxacin']
#
# 推薦藥物:
# 1. Cefazolin (Score: 0.5832)
# 2. Flomoxef (Score: 0.5665)
# 3. Ciprofloxacin (Score: 0.3171)
# 4. Cefuroxime (Score: 0.2848)
# 5. Piperacillin/Tazobactam (Score: 0.0912)
# 6. Levofloxacin (Score: 0.0731)
# 7. Amoxicillin/Clavulanic acid (Score: 0.0719)
# 8. Ampicillin (Score: 0.0587)
# 9. Cefoperazone/sulbactam (Score: 0.0579)
# 10. Ceftriaxone (Score: 0.0555)
# ==================================================
# 實際給藥: ['Piperacillin/Tazobactam']
#
# 推薦藥物:
# 1. Piperacillin/Tazobactam (Score: 0.6867)
# 2. Flomoxef (Score: 0.3721)
# 3. Levofloxacin (Score: 0.2674)
# 4. Cefoperazone/sulbactam (Score: 0.2524)
# 5. Azithromycin (Score: 0.2254)
# 6. Metronidazole (Score: 0.0504)
# 7. Ampicillin (Score: 0.0483)
# 8. Ciprofloxacin (Score: 0.0471)
# 9. Ceftriaxone (Score: 0.0448)
# 10. Gentamicin (Score: 0.0437)
# ==================================================
# 實際給藥: ['Levofloxacin']
#
# 推薦藥物:
# 1. Flomoxef (Score: 0.6566)
# 2. Cefoperazone/sulbactam (Score: 0.3926)
# 3. Levofloxacin (Score: 0.3470)
# 4. Azithromycin (Score: 0.2133)
# 5. Cefixime (Score: 0.1683)
# 6. Piperacillin/Tazobactam (Score: 0.1363)
# 7. Amoxicillin/Clavulanic acid (Score: 0.0905)
# 8. Ceftriaxone (Score: 0.0567)
# 9. Ciprofloxacin (Score: 0.0515)
# 10. Ampicillin (Score: 0.0478)
# ==================================================
# 實際給藥: ['Piperacillin/Tazobactam']
#
# 推薦藥物:
# 1. Piperacillin/Tazobactam (Score: 0.5089)
# 2. Flomoxef (Score: 0.3914)
# 3. Azithromycin (Score: 0.2879)
# 4. Cefoperazone/sulbactam (Score: 0.2313)
# 5. Levofloxacin (Score: 0.1938)
# 6. Ciprofloxacin (Score: 0.0651)
# 7. Ceftriaxone (Score: 0.0507)
# 8. Ampicillin (Score: 0.0479)
# 9. Gentamicin (Score: 0.0420)
# 10. Metronidazole (Score: 0.0380)
# ==================================================
# 實際給藥: ['Cefuroxime', 'Flomoxef']
#
# 推薦藥物:
# 1. Flomoxef (Score: 0.9304)
# 2. Cefuroxime (Score: 0.2490)
# 3. Piperacillin/Tazobactam (Score: 0.1979)
# 4. Cefixime (Score: 0.1681)
# 5. Ciprofloxacin (Score: 0.1503)
# 6. Metronidazole (Score: 0.1320)
# 7. Cefazolin (Score: 0.1040)
# 8. Cefoperazone/sulbactam (Score: 0.0745)
# 9. Ceftriaxone (Score: 0.0492)
# 10. Ampicillin (Score: 0.0479)
# ==================================================
# 實際給藥: ['Cefoperazone/sulbactam']
#
# 推薦藥物:
# 1. Flomoxef (Score: 0.5658)
# 2. Amoxicillin/Clavulanic acid (Score: 0.3461)
# 3. Cefoperazone/sulbactam (Score: 0.2668)
# 4. Azithromycin (Score: 0.1723)
# 5. Cefixime (Score: 0.1082)
# 6. Levofloxacin (Score: 0.1079)
# 7. Piperacillin/Tazobactam (Score: 0.0661)
# 8. Ceftriaxone (Score: 0.0619)
# 9. Ampicillin (Score: 0.0483)
# 10. Clindamycin (Score: 0.0423)
# ==================================================
# 實際給藥: ['Cefoperazone/sulbactam']
#
# 推薦藥物:
# 1. Cefoperazone/sulbactam (Score: 0.5813)
# 2. Piperacillin/Tazobactam (Score: 0.5260)
# 3. Flomoxef (Score: 0.2443)
# 4. Levofloxacin (Score: 0.2268)
# 5. Ceftriaxone (Score: 0.1453)
# 6. Azithromycin (Score: 0.0946)
# 7. Ciprofloxacin (Score: 0.0700)
# 8. Ampicillin (Score: 0.0481)
# 9. Metronidazole (Score: 0.0414)
# 10. Gentamicin (Score: 0.0403)
# ==================================================
# 實際給藥: ['Amoxicillin/Clavulanic acid']
#
# 推薦藥物:
# 1. Amoxicillin/Clavulanic acid (Score: 0.8527)
# 2. Cefazolin (Score: 0.1828)
# 3. Gentamicin (Score: 0.1492)
# 4. Ceftriaxone (Score: 0.0994)
# 5. Cefixime (Score: 0.0636)
# 6. Ampicillin (Score: 0.0590)
# 7. Azithromycin (Score: 0.0484)
# 8. Cefuroxime (Score: 0.0382)
# 9. Clindamycin (Score: 0.0368)
# 10. Piperacillin/Tazobactam (Score: 0.0330)
# ==================================================
# 實際給藥: ['Amoxicillin/Clavulanic acid', 'Clindamycin']
#
# 推薦藥物:
# 1. Amoxicillin/Clavulanic acid (Score: 0.8974)
# 2. Clindamycin (Score: 0.3643)
# 3. Flomoxef (Score: 0.1368)
# 4. Ciprofloxacin (Score: 0.0917)
# 5. Cefoperazone/sulbactam (Score: 0.0914)
# 6. Ceftriaxone (Score: 0.0778)
# 7. Cefixime (Score: 0.0711)
# 8. Ampicillin (Score: 0.0480)
# 9. Gentamicin (Score: 0.0449)
# 10. Cefuroxime (Score: 0.0429)
# ==================================================

# %%
importance_all = []

for i, drug in enumerate(y_train.columns):
    
    model = multi_model.estimators_[i]
    
    # 建立 Series 並與特徵名稱對應
    imp = pd.Series(
        model.feature_importances_,
        index=X_train.columns
    )

    imp_df = imp.reset_index()
    imp_df.columns = ['feature','importance']
    # imp_df['drug'] = drug
    
    imp_df_sorted = imp_df.sort_values("importance", ascending=False)
    
    print(f"=== Drug: {drug} (Top 20 Features) ===")
    print(imp_df_sorted.head(20).to_string(index=False)) # 不印索引比較美觀
    print('\n')
    print(f"Top 20 importance sum: {imp_df_sorted.head(20)['importance'].sum().round(3)}")
    print("-" * 40)
    
    importance_all.append(imp_df_sorted)

importance_all = pd.concat(importance_all)
# Out:
# === Drug: Amoxicillin/Clavulanic acid (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE5    0.130533
#        INFECTIONSITE3    0.061939
#        INFECTIONSITE1    0.061703
#        INFECTIONSITE2    0.059113
#                   AGE    0.051442
#           O2 SAT_flag    0.034959
#        CARDIOVASCULAR    0.030296
#        INFECTIONSITE4    0.029842
#        INFECTIONSITE9    0.028216
#      T.Bilirubin_flag    0.023045
#             HCO3_flag    0.022806
#          BE(ecf)_flag    0.021791
#  Leukocyte level_flag    0.020163
#               PT_flag    0.019213
# CHECKITEM27SCORE_flag    0.019105
#           INJURELEVEL    0.018415
# CHECKITEM30SCORE_flag    0.017146
#             PCO2_flag    0.017007
# CHECKITEM28SCORE_flag    0.016558
#    Nitrite level_flag    0.016317
#
#
# Top 20 importance sum: 0.699999988079071
# ----------------------------------------
# === Drug: Ampicillin (Top 20 Features) ===
#              feature  importance
#                  AGE    0.288247
#           Creatinine    0.044614
#          RESPIRATORY    0.044318
#          INJURELEVEL    0.043918
#                  CNS    0.039890
#         VITALSIGNSPR    0.034677
#      Neutrophil Seg.    0.031795
#         BE(ecf)_flag    0.025730
#       INFECTIONSITE2    0.023212
#         VITALSIGNSBT    0.021973
# Leukocyte level_flag    0.021926
#                LIVER    0.020840
#                  CRP    0.019552
#   Nitrite level_flag    0.018966
#         VITALSIGNSRR    0.018017
#            HCO3_flag    0.017973
#           Lymphocyte    0.016732
#                   Hb    0.016355
#                    K    0.015547
#        VITALSIGNSDBP    0.014626
#
#
# Top 20 importance sum: 0.7789999842643738
# ----------------------------------------
# === Drug: Azithromycin (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE1    0.260106
#             APTT_flag    0.073702
#               PT_flag    0.069013
#        INFECTIONSITE3    0.056092
#        INFECTIONSITE5    0.034297
#        INFECTIONSITE2    0.024847
#         VITALSIGNSGCS    0.018940
# CHECKITEM28SCORE_flag    0.015279
# CHECKITEM32SCORE_flag    0.014588
#                 FEVER    0.014248
#                CANCER    0.014047
#        VITALSIGNSSPO2    0.012723
# CHECKITEM29SCORE_flag    0.012223
#        INFECTIONSITE9    0.011421
# CHECKITEM31SCORE_flag    0.010990
#      T.Bilirubin_flag    0.010896
#     CHECKITEM28A_flag    0.010895
#      CHECKITEM27_flag    0.010662
# CHECKITEM27SCORE_flag    0.010040
#                   CRP    0.009871
#
#
# Top 20 importance sum: 0.6949999928474426
# ----------------------------------------
# === Drug: Cefazolin (Top 20 Features) ===
#               feature  importance
#             APTT_flag    0.139634
#               PT_flag    0.138742
# CHECKITEM32SCORE_flag    0.091724
#      T.Bilirubin_flag    0.049344
# CHECKITEM29SCORE_flag    0.041123
#              INR_flag    0.038495
#      CHECKITEM27_flag    0.024393
# CHECKITEM28SCORE_flag    0.023188
#     CHECKITEM28A_flag    0.021959
#              HST_flag    0.020545
#                 FEVER    0.018048
#           RESPIRATORY    0.017812
#             PCO2_flag    0.017681
#                   CRP    0.017152
#        INFECTIONSITE4    0.013226
#        INFECTIONSITE2    0.012242
#        INFECTIONSITE5    0.011738
#                    Ht    0.010946
#           INJURELEVEL    0.010031
#  Leukocyte level_flag    0.010016
#
#
# Top 20 importance sum: 0.7279999852180481
# ----------------------------------------
# === Drug: Cefixime (Top 20 Features) ===
#               feature  importance
#             PCO2_flag    0.063901
#        INFECTIONSITE1    0.062154
#        INFECTIONSITE5    0.054620
#             HCO3_flag    0.047279
#               PT_flag    0.041519
#           INJURELEVEL    0.036864
#             APTT_flag    0.029324
#              INR_flag    0.025172
#        INFECTIONSITE3    0.022306
#   Bacteria level_flag    0.020747
#         VITALSIGNSGCS    0.018961
#          BE(ecf)_flag    0.018533
#        INFECTIONSITE2    0.017685
# CHECKITEM31SCORE_flag    0.017171
#           O2 SAT_flag    0.016809
#                   AGE    0.015660
#                   CRP    0.015494
#  Leukocyte level_flag    0.014972
#    Nitrite level_flag    0.014593
# CHECKITEM30SCORE_flag    0.014589
#
#
# Top 20 importance sum: 0.5680000185966492
# ----------------------------------------
# === Drug: Cefoperazone/sulbactam (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE1    0.114360
#        INFECTIONSITE3    0.056680
# CHECKITEM28SCORE_flag    0.045046
#             APTT_flag    0.044134
#     CHECKITEM28A_flag    0.038809
#   Bacteria level_flag    0.028835
#        INFECTIONSITE5    0.028761
# CHECKITEM29SCORE_flag    0.025001
#                   AGE    0.024507
#  Leukocyte level_flag    0.024392
# CHECKITEM32SCORE_flag    0.019715
#        INFECTIONSITE2    0.019537
#               PT_flag    0.019055
#    Nitrite level_flag    0.017472
#                 FEVER    0.017464
#           O2 SAT_flag    0.016311
# CHECKITEM30SCORE_flag    0.016294
#          VITALSIGNSBT    0.014979
#        INFECTIONSITE9    0.014156
#            Creatinine    0.013830
#
#
# Top 20 importance sum: 0.5989999771118164
# ----------------------------------------
# === Drug: Ceftriaxone (Top 20 Features) ===
#                 feature  importance
#          INFECTIONSITE4    0.084442
#          INFECTIONSITE2    0.048956
#          INFECTIONSITE1    0.029748
#   CHECKITEM29SCORE_flag    0.029068
#                     AGE    0.026181
#                     SEX    0.025448
#          INFECTIONSITE5    0.024141
#          CARDIOVASCULAR    0.024091
#   CHECKITEM30SCORE_flag    0.022679
#      Nitrite level_flag    0.022380
#   CHECKITEM32SCORE_flag    0.022294
#        CHECKITEM27_flag    0.020536
#     Bacteria level_flag    0.019885
#             O2 SAT_flag    0.019510
#                   FEVER    0.019156
#       CHECKITEM28A_flag    0.018272
#          INFECTIONSITE3    0.017516
#          StayTime_hours    0.017175
# OTHERINFECTIONSITE_flag    0.016114
#           VITALSIGNSDBP    0.015897
#
#
# Top 20 importance sum: 0.5230000019073486
# ----------------------------------------
# === Drug: Cefuroxime (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE1    0.100220
# CHECKITEM29SCORE_flag    0.068003
#        INFECTIONSITE3    0.050829
# CHECKITEM30SCORE_flag    0.047021
#             APTT_flag    0.026045
#        INFECTIONSITE5    0.024918
#                   CRP    0.020089
# CHECKITEM31SCORE_flag    0.019175
#           RESPIRATORY    0.018700
#          VITALSIGNSBT    0.017946
#        INFECTIONSITE2    0.017543
#        CARDIOVASCULAR    0.017319
#               PT_flag    0.017023
#          BE(ecf)_flag    0.016376
# CHECKITEM32SCORE_flag    0.016185
#      T.Bilirubin_flag    0.016054
# CHECKITEM27SCORE_flag    0.014968
#            Lymphocyte    0.014478
#         VITALSIGNSDBP    0.014351
#    Nitrite level_flag    0.014015
#
#
# Top 20 importance sum: 0.5509999990463257
# ----------------------------------------
# === Drug: Ciprofloxacin (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE1    0.136214
#               PT_flag    0.052606
#        INFECTIONSITE5    0.044600
#             APTT_flag    0.036082
#        INFECTIONSITE3    0.036020
#             PCO2_flag    0.029005
#        INFECTIONSITE2    0.025616
#              HST_flag    0.024350
#        INFECTIONSITE9    0.023956
#                   AGE    0.021441
#           INJURELEVEL    0.016279
#                    DM    0.015564
#                    Ht    0.015485
#                    Hb    0.015291
# CHECKITEM32SCORE_flag    0.014127
#  Leukocyte level_flag    0.014125
#                   GPT    0.013800
#                 LIVER    0.013743
#         VITALSIGNSGCS    0.013715
#                   MAP    0.013607
#
#
# Top 20 importance sum: 0.5759999752044678
# ----------------------------------------
# === Drug: Clindamycin (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE5    0.260984
#        INFECTIONSITE3    0.108697
#               PT_flag    0.054709
#        INFECTIONSITE2    0.043842
#        INFECTIONSITE1    0.035663
#           INJURELEVEL    0.028033
#      T.Bilirubin_flag    0.021716
#         VITALSIGNSGCS    0.020577
#             APTT_flag    0.019912
#              HST_flag    0.018053
#             PCO2_flag    0.016628
#        INFECTIONSITE9    0.015635
# CHECKITEM28SCORE_flag    0.014582
# CHECKITEM27SCORE_flag    0.013811
#  Leukocyte level_flag    0.013135
#        INFECTIONSITE4    0.012648
#                 FEVER    0.010634
#     CHECKITEM28A_flag    0.010189
#             HCO3_flag    0.010132
#        StayTime_hours    0.009839
#
#
# Top 20 importance sum: 0.7390000224113464
# ----------------------------------------
# === Drug: Flomoxef (Top 20 Features) ===
#                 feature  importance
#          INFECTIONSITE2    0.185945
#          INFECTIONSITE5    0.063398
#          INFECTIONSITE1    0.040528
#          INFECTIONSITE9    0.034832
#                     AGE    0.033168
#          INFECTIONSITE4    0.031339
#          INFECTIONSITE3    0.027131
#             O2 SAT_flag    0.022654
#            BE(ecf)_flag    0.019140
#          CARDIOVASCULAR    0.018407
#        T.Bilirubin_flag    0.018272
#                     CRP    0.016867
#   CHECKITEM27SCORE_flag    0.014378
#           VITALSIGNSGCS    0.014234
#                HST_flag    0.013263
# OTHERINFECTIONSITE_flag    0.012799
#               APTT_flag    0.012684
#                     SEX    0.012599
#              AUTOIMMUNE    0.012391
#             INJURELEVEL    0.012064
#
#
# Top 20 importance sum: 0.6159999966621399
# ----------------------------------------
# === Drug: Gentamicin (Top 20 Features) ===
#               feature  importance
#              INR_flag    0.124802
#               PT_flag    0.056569
#        CARDIOVASCULAR    0.049418
#        INFECTIONSITE4    0.046969
# CHECKITEM32SCORE_flag    0.043721
#             APTT_flag    0.041516
#             PCO2_flag    0.039794
#                   AGE    0.037462
#      T.Bilirubin_flag    0.035594
#              HST_flag    0.031676
#           RESPIRATORY    0.029100
#            AUTOIMMUNE    0.028154
#        INFECTIONSITE2    0.022181
#          BE(ecf)_flag    0.019815
#           O2 SAT_flag    0.019058
#   Bacteria level_flag    0.016868
#             HCO3_flag    0.016477
#         VITALSIGNSGCS    0.015407
#        INFECTIONSITE3    0.013782
# CHECKITEM29SCORE_flag    0.013301
#
#
# Top 20 importance sum: 0.7020000219345093
# ----------------------------------------
# === Drug: Levofloxacin (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE2    0.118465
#        INFECTIONSITE1    0.070569
# CHECKITEM30SCORE_flag    0.065313
#        INFECTIONSITE5    0.039815
# CHECKITEM28SCORE_flag    0.038778
#               PT_flag    0.029242
#        INFECTIONSITE3    0.024717
#             APTT_flag    0.021343
#         VITALSIGNSGCS    0.019901
#            Creatinine    0.018480
# CHECKITEM29SCORE_flag    0.017670
#          BE(ecf)_flag    0.016843
#                   AGE    0.016617
#   Bacteria level_flag    0.014963
#             PCO2_flag    0.013816
#    Nitrite level_flag    0.013723
#                CANCER    0.013638
#     CHECKITEM28A_flag    0.013620
#                   CRP    0.013561
#  Leukocyte level_flag    0.013393
#
#
# Top 20 importance sum: 0.593999981880188
# ----------------------------------------
# === Drug: Metronidazole (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE2    0.298508
#        INFECTIONSITE1    0.083153
#        INFECTIONSITE3    0.030882
#               PT_flag    0.030356
# CHECKITEM27SCORE_flag    0.020785
# CHECKITEM29SCORE_flag    0.019002
#              HST_flag    0.018712
#        INFECTIONSITE5    0.017040
#      T.Bilirubin_flag    0.016591
#             APTT_flag    0.015477
#                   CRP    0.014931
#           O2 SAT_flag    0.014654
# CHECKITEM30SCORE_flag    0.014299
#     CHECKITEM28A_flag    0.012283
#      CHECKITEM27_flag    0.012180
#           RESPIRATORY    0.011831
#                    Ht    0.011111
#              INR_flag    0.010774
#         VITALSIGNSGCS    0.010765
#                   SEX    0.010644
#
#
# Top 20 importance sum: 0.6740000247955322
# ----------------------------------------
# === Drug: Piperacillin/Tazobactam (Top 20 Features) ===
#                   feature  importance
#                 PCO2_flag    0.070740
#               O2 SAT_flag    0.061403
#               INJURELEVEL    0.045878
#                       CRP    0.039276
#                 HCO3_flag    0.038919
#            INFECTIONSITE1    0.032152
#          T.Bilirubin_flag    0.028417
#             VITALSIGNSGCS    0.027433
#                   PT_flag    0.024576
#     CHECKITEM28SCORE_flag    0.023837
#            INFECTIONSITE2    0.020790
#     CHECKITEM31SCORE_flag    0.019391
#                       AGE    0.017768
#     CHECKITEM27SCORE_flag    0.017426
# Absolute Neutrophil count    0.016832
#                       WBC    0.016651
#            INFECTIONSITE9    0.015763
#                    CANCER    0.014945
#     CHECKITEM29SCORE_flag    0.014762
#         CHECKITEM28A_flag    0.014741
#
#
# Top 20 importance sum: 0.5619999766349792
# ----------------------------------------

# %%
importance_summary = importance_all.groupby('feature')['importance'].mean().sort_values(ascending=False)

print(importance_summary.head(20))
# Out:
# feature
# INFECTIONSITE1           0.070428
# INFECTIONSITE2           0.062565
# INFECTIONSITE5           0.050884
# AGE                      0.038788
# PT_flag                  0.038744
# INFECTIONSITE3           0.035470
# APTT_flag                0.033019
# PCO2_flag                0.022530
# INFECTIONSITE4           0.020020
# T.Bilirubin_flag         0.019208
# CHECKITEM32SCORE_flag    0.019110
# CHECKITEM29SCORE_flag    0.019063
# INR_flag                 0.018710
# INJURELEVEL              0.018575
# CHECKITEM30SCORE_flag    0.016609
# HCO3_flag                0.016215
# O2 SAT_flag              0.016024
# CHECKITEM28SCORE_flag    0.015906
# VITALSIGNSGCS            0.015392
# CARDIOVASCULAR           0.015384
# Name: importance, dtype: float32

# %%
importance_summary = importance_all.groupby('feature')['importance'].median().sort_values(ascending=False)

print(importance_summary.head(20))
# Out:
# feature
# INFECTIONSITE1           0.061703
# PT_flag                  0.029242
# INFECTIONSITE5           0.028761
# INFECTIONSITE3           0.027131
# INFECTIONSITE2           0.024847
# APTT_flag                0.021343
# AGE                      0.017768
# T.Bilirubin_flag         0.016054
# BE(ecf)_flag             0.014674
# O2 SAT_flag              0.014654
# VITALSIGNSGCS            0.014234
# PCO2_flag                0.013816
# CHECKITEM27SCORE_flag    0.013811
# CRP                      0.013561
# CHECKITEM28SCORE_flag    0.013447
# CHECKITEM29SCORE_flag    0.013301
# Leukocyte level_flag     0.013135
# HST_flag                 0.012588
# CHECKITEM30SCORE_flag    0.012583
# INJURELEVEL              0.012064
# Name: importance, dtype: float32

# %% [raw]
# MI

# %%
from sklearn.feature_selection import mutual_info_classif
import pandas as pd

# 挑選你想診斷的藥物
target_drug = 'Levofloxacin' #  , 'Cephalexin', 'Cefadroxil'

# 計算 MI
# discrete_features: 如果你的特徵有類別型（如部位），要標註 True
mi_scores = mutual_info_classif(X_train, y_train[target_drug], discrete_features='auto', random_state=123)

# 整理成 DataFrame
mi_df = pd.DataFrame({'feature': X_train.columns, 'mi_score': mi_scores})
mi_df = mi_df.sort_values(by='mi_score', ascending=False)

print(f"=== {target_drug} 的特徵資訊量排行 ===")
print(mi_df.head(10))
# Out:
# === Levofloxacin 的特徵資訊量排行 ===
#                   feature  mi_score
# 36         INFECTIONSITE1  0.014230
# 16         INFECTIONSITE2  0.011451
# 45  CHECKITEM29SCORE_flag  0.007720
# 51              APTT_flag  0.006856
# 44                PH_flag  0.006291
# 61  CHECKITEM32SCORE_flag  0.005913
# 59  CHECKITEM28SCORE_flag  0.005896
# 37                    AGE  0.005710
# 56      CHECKITEM28A_flag  0.005258
# 15            RESPIRATORY  0.005250
