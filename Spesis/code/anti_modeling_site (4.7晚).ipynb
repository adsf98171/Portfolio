# %%
import pandas as pd
import numpy as np
import re 
from IPython.display import display, HTML

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV 
from sklearn.metrics import classification_report, confusion_matrix, f1_score, hamming_loss, jaccard_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.multioutput import MultiOutputClassifier, ClassifierChain
from scipy.stats import entropy

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_columns', None)

data= pd.read_csv(r"‪D:\ML Data\Spesis\anti_total.csv".strip("‪u202a"), index_col=False)

# %%
all_site_cols = [
    'INFECTIONSITE1', 'INFECTIONSITE2', 'INFECTIONSITE3',
    'INFECTIONSITE4', 'INFECTIONSITE5', 'INFECTIONSITE9', 
    'OTHERINFECTIONSITE_flag'
]

temp_df = data[all_site_cols].copy().astype(str).apply(lambda x: x.str.strip())
temp_df = temp_df.replace(['', 'nan', 'None', 'nan.0'], '0')

temp_df = temp_df.astype(float)

has_site_mask = (temp_df > 0).any(axis=1)

site_samples = data[has_site_mask].copy()

print(f"原始樣本數: {len(data)}")
print(f"至少標註一個部位的樣本數: {len(site_samples)}")
print(f"被排除掉的『全空/全0』樣本數: {len(data) - len(site_samples)}")
# Out:
# 原始樣本數: 27968
# 至少標註一個部位的樣本數: 11880
# 被排除掉的『全空/全0』樣本數: 16088

# %%
len(site_samples), len(site_samples['ACCOUNTNO'])
# Out:
# (11880, 11880)

# %%
roomno_mapping = {'A': '1', 'C': '2', 'D': '3', 'E': '4', 'H': '5', 'K': '6'}
site_samples['ROOMNO'] = site_samples['ROOMNO'].map(roomno_mapping)          

site_samples['SEX'] = site_samples['SEX'].map({'M': 1, 'F': 0})

yn_cols = [
    'ISSEPSIS0', 'FEVER', 'DM', 'CARDIOVASCULAR', 
    'RESPIRATORY', 'CNS', 'CANCER', 'LIVER', 'KIDNEY', 'AUTOIMMUNE'
]

for col in yn_cols:
    site_samples[col] = site_samples[col].map({'Y': 1, 'N': 0})

# %% [raw]
# 過濾抗生素使用<500次的，後刪除沒給抗生素的(沒有)

# %%
start_index = site_samples.columns.get_loc('Acyclovir')
end_index = site_samples.columns.get_loc('tenofovir/emtricitabine/rilpivirine')

# %%
abx_cols = site_samples.columns[start_index:end_index+1]
col_sum = site_samples[abx_cols].sum()

# %%
final_cols = col_sum[col_sum >= 500].index.tolist()
base_cols = [c for c in site_samples.columns if c not in abx_cols]
data_filter = site_samples[base_cols + final_cols]

# %%
data_filter[final_cols].sum().sort_values(ascending=False)
# Out:
# Flomoxef                       5190.0
# Amoxicillin/Clavulanic acid    1581.0
# Piperacillin/Tazobactam        1509.0
# Cefoperazone/sulbactam         1411.0
# Metronidazole                   916.0
# Ciprofloxacin                   872.0
# Cefixime                        851.0
# Azithromycin                    695.0
# Ceftriaxone                     609.0
# Cefazolin                       589.0
# Levofloxacin                    501.0
# dtype: float64

# %%
feature_cols = list(set(data_filter.columns) - set(abx_cols))
X = data_filter[feature_cols]
y = data_filter[final_cols]

# %%
X.shape, y.shape
# Out:
# ((11880, 68), (11880, 11))

# %%
X = X.drop(columns=['ACCOUNTNO', 'ROOMNO', 'INTIME', 'Influenza Virus A level', 'FIRST_ORDERTIME', 'ISSEPSIS0'])

# %%
X.columns
# Out:
# Index(['Hb', 'INR', 'CHECKITEM27SCORE', 'O2 SAT', 'WBC', 'AUTOIMMUNE',
#        'Neutrophil Seg.', 'CHECKITEM31SCORE', 'CHECKITEM28A', 'CRP', 'BE(ecf)',
#        'K', 'INFECTIONSITE3', 'CHECKITEM30SCORE', 'PCO2', 'DM',
#        'CHECKITEM32SCORE', 'VITALSIGNSDBP', 'Absolute Neutrophil count',
#        'VITALSIGNSSPO2', 'INJURELEVEL', 'CHECKITEM28SCORE', 'CNS',
#        'INFECTIONSITE4', 'Nitrite level', 'VITALSIGNSBT', 'VITALSIGNSRR', 'PT',
#        'Lymphocyte', 'VITALSIGNSGCS', 'INFECTIONSITE1', 'Creatinine',
#        'VITALSIGNSPR', 'INFECTIONSITE2', 'SEX', 'MAP',
#        'OTHERINFECTIONSITE_flag', 'CHECKITEM27', 'Ht', 'LIVER', 'KIDNEY',
#        'Bacteria level', 'CARDIOVASCULAR', 'RESPIRATORY', 'GPT', 'CANCER',
#        'INFECTIONSITE9', 'HCO3', 'PLT', 'Na', 'INFECTIONSITE5',
#        'Microscopic RBC level', 'CHECKITEM29SCORE', 'StayTime_hours', 'APTT',
#        'Leukocyte level', 'AGE', 'HST', 'PH', 'T.Bilirubin', 'FEVER',
#        'Microscopic WBC level'],
#       dtype='object')

# %% [raw]
# 建立flag for missing above 80%

# %%
####################### Missing 70~80% #######################

# 檢驗

X['Leukocyte level_flag'] = (
     X['Leukocyte level'].fillna('').str.strip().ne('').astype(int))

X['Nitrite level_flag'] = (
     X['Nitrite level'].fillna('').str.strip().ne('').astype(int))

X['Bacteria level_flag'] = (
     X['Bacteria level'].fillna('').str.strip().ne('').astype(int))

X['Microscopic RBC level_flag'] = (
     X['Microscopic RBC level'].fillna('').str.strip().ne('').astype(int))

X['Microscopic WBC level_flag'] = (
     X['Microscopic WBC level'].fillna('').str.strip().ne('').astype(int))

X['PH_flag'] = (
     X['Microscopic RBC level'].fillna('').str.strip().ne('').astype(int))



# 計分

X['CHECKITEM29SCORE_flag'] = (
     X['CHECKITEM29SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM30SCORE_flag'] = (
     X['CHECKITEM30SCORE'].fillna('').str.strip().ne('').astype(int))


####################### Missing > 80% #######################

# 檢驗

X['HST_flag'] = (
     X['HST'].fillna('').str.strip().ne('').astype(int))

X['T.Bilirubin_flag'] = (
     X['T.Bilirubin'].fillna('').str.strip().ne('').astype(int))

X['PT_flag'] = (
     X['PT'].fillna('').str.strip().ne('').astype(int))

X['HST_flag'] = (
     X['HST'].fillna('').str.strip().ne('').astype(int))

X['INR_flag'] = (
     X['INR'].fillna('').str.strip().ne('').astype(int))

X['APTT_flag'] = (
     X['APTT'].fillna('').str.strip().ne('').astype(int))

X['PCO2_flag'] = (
     X['PCO2'].fillna('').str.strip().ne('').astype(int))

X['HCO3_flag'] = (
     X['HCO3'].fillna('').str.strip().ne('').astype(int))


X['BE(ecf)_flag'] = (
     X['BE(ecf)'].fillna('').str.strip().ne('').astype(int))

X['O2 SAT_flag'] = (
     X['O2 SAT'].fillna('').str.strip().ne('').astype(int))

# 計分

X['CHECKITEM28A_flag'] = (
     X['CHECKITEM28A'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM27_flag'] = (
     X['CHECKITEM27'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM27SCORE_flag'] = (
     X['CHECKITEM27SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM28SCORE_flag'] = (
     X['CHECKITEM28SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM31SCORE_flag'] = (
     X['CHECKITEM31SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM32SCORE_flag'] = (
     X['CHECKITEM32SCORE'].fillna('').str.strip().ne('').astype(int))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

df = X

vital_cols = list(set(['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
            'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']))

# 設定每列顯示幾個圖
cols_per_row = 4
rows = math.ceil(len(vital_cols) / cols_per_row)

# 建立畫布
fig, axes = plt.subplots(rows, cols_per_row, figsize=(20, rows * 4))
axes = axes.flatten() # 將多維陣列拉平，方便迴圈讀取

for i, col in enumerate(vital_cols):
    if col in df.columns:
        # 繪製直方圖 + 密度曲線(kde)
        sns.histplot(df[col].dropna(), kde=True, ax=axes[i], bins=30)
        axes[i].set_title(f'Distribution of {col}', fontsize=12)
        axes[i].set_xlabel('')
        axes[i].set_ylabel('')
    else:
        axes[i].set_axis_off() # 如果欄位不存在就留白

# 移除多餘的空白子圖
for j in range(i + 1, len(axes)):
    axes[j].set_axis_off()

plt.tight_layout()
plt.show()

# %%
lower_bound = X.quantile(0.01)
upper_bound = X.quantile(0.99)

outliers_low = (X < lower_bound).sum()
outliers_high = (X > upper_bound).sum()

outlier_summary = pd.DataFrame({
    'Low_Outliers (<1%)': outliers_low,
    'High_Outliers (>99%)': outliers_high,
    'Total_Outliers': outliers_low + outliers_high
})

print(f"全資料集總離群值筆數: {outlier_summary['Total_Outliers'].sum()}")
print("\n各欄位離群值統計 (前 10 名):")
print(outlier_summary.sort_values('Total_Outliers', ascending=False).head(10))
# Out:
# 全資料集總離群值筆數: 4051
#
# 各欄位離群值統計 (前 10 名):
#                            Low_Outliers (<1%)  High_Outliers (>99%)  \
# VITALSIGNSPR                              116                   115
# VITALSIGNSDBP                             102                   111
# MAP                                       101                   106
# Absolute Neutrophil count                  96                    96
# VITALSIGNSBT                               91                   101
# WBC                                        95                    96
# Ht                                         97                    92
# PLT                                        93                    95
# Lymphocyte                                 87                    96
# Hb                                         89                    91
#
#                            Total_Outliers
# VITALSIGNSPR                          231
# VITALSIGNSDBP                         213
# MAP                                   207
# Absolute Neutrophil count             192
# VITALSIGNSBT                          192
# WBC                                   191
# Ht                                    189
# PLT                                   188
# Lymphocyte                            183
# Hb                                    180

# %%
# outlier修改為1%或99% quantile
X = X.clip(lower=lower_bound, upper=upper_bound, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 123)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((10692, 85), (10692, 11), (1188, 85), (1188, 11))

# %%
X_train.isnull().sum(), X_test.isnull().sum()
# Out:
# (Hb                       1993
#  INR                      7763
#  CHECKITEM27SCORE         7121
#  O2 SAT                   8185
#  WBC                      2091
#                           ...
#  CHECKITEM27_flag            0
#  CHECKITEM27SCORE_flag       0
#  CHECKITEM28SCORE_flag       0
#  CHECKITEM31SCORE_flag       0
#  CHECKITEM32SCORE_flag       0
#  Length: 85, dtype: int64,
#  Hb                       206
#  INR                      856
#  CHECKITEM27SCORE         817
#  O2 SAT                   919
#  WBC                      218
#                          ...
#  CHECKITEM27_flag           0
#  CHECKITEM27SCORE_flag      0
#  CHECKITEM28SCORE_flag      0
#  CHECKITEM31SCORE_flag      0
#  CHECKITEM32SCORE_flag      0
#  Length: 85, dtype: int64)

# %%
X_train.dtypes, X_test.dtypes
# Out:
# (Hb                       float64
#  INR                      float64
#  CHECKITEM27SCORE         float64
#  O2 SAT                   float64
#  WBC                      float64
#                            ...
#  CHECKITEM27_flag           int64
#  CHECKITEM27SCORE_flag      int64
#  CHECKITEM28SCORE_flag      int64
#  CHECKITEM31SCORE_flag      int64
#  CHECKITEM32SCORE_flag      int64
#  Length: 85, dtype: object,
#  Hb                       float64
#  INR                      float64
#  CHECKITEM27SCORE         float64
#  O2 SAT                   float64
#  WBC                      float64
#                            ...
#  CHECKITEM27_flag           int64
#  CHECKITEM27SCORE_flag      int64
#  CHECKITEM28SCORE_flag      int64
#  CHECKITEM31SCORE_flag      int64
#  CHECKITEM32SCORE_flag      int64
#  Length: 85, dtype: object)

# %%
y_train.sum().sort_values(ascending=False)
# Out:
# Flomoxef                       4683.0
# Amoxicillin/Clavulanic acid    1408.0
# Piperacillin/Tazobactam        1358.0
# Cefoperazone/sulbactam         1259.0
# Metronidazole                   830.0
# Ciprofloxacin                   784.0
# Cefixime                        775.0
# Azithromycin                    635.0
# Ceftriaxone                     561.0
# Cefazolin                       526.0
# Levofloxacin                    453.0
# dtype: float64

# %%
# 轉數值

num_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
            'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']

# num_cols = ['Neutrophil Seg.', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'WBC', 
#             'Lymphocyte', 'CRP', 'Hb', 'Creatinine', 'Leukocyte', 'PCO2', 'INR', 'Absolute Neutrophil count', 'Ht', 'HST', 'BE(ecf)', 'T.Bilirubin',
#            'Na', 'K', 'GPT', 'O2 SAT', 'HCO3', 'PT', 'APTT', 'PLT']

for col in num_cols:
    X_train[col] = pd.to_numeric(X_train[col], errors='coerce')
    X_test[col] = pd.to_numeric(X_test[col], errors='coerce')

# %%
# vital sign impute
vital_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
              'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']


for col in vital_cols:
    # X_train[col + "_missing"] = X_train[col].isna().astype(int) # missing indicator
    median = X_train[col].median()
    X_train[col] = X_train[col].fillna(median)
    
    # X_test[col + "_missing"] = X_test[col].isna().astype(int) # missing indicator
    X_test[col] = X_test[col].fillna(median)

# %%
# 取 log

X_train['CRP'] = np.log1p(X_train['CRP'])
X_test['CRP'] = np.log1p(X_test['CRP'])

X_train['PLT'] = np.log1p(X_train['PLT'])
X_test['PLT'] = np.log1p(X_test['PLT'])

X_train['WBC'] = np.log1p(X_train['WBC'])
X_test['WBC'] = np.log1p(X_test['WBC'])

X_train['AGE'] = np.log1p(X_train['AGE'])
X_test['AGE'] = np.log1p(X_test['AGE'])

X_train['K'] = np.log1p(X_train['K'])
X_test['K'] = np.log1p(X_test['K'])

X_train['GPT'] = np.log1p(X_train['GPT'])
X_test['GPT'] = np.log1p(X_test['GPT'])

X_train['VITALSIGNSSPO2'] = np.log1p(X_train['VITALSIGNSSPO2'])
X_test['VITALSIGNSSPO2'] = np.log1p(X_test['VITALSIGNSSPO2'])

X_train['Absolute Neutrophil count'] = np.log1p(X_train['Absolute Neutrophil count'])
X_test['Absolute Neutrophil count'] = np.log1p(X_test['Absolute Neutrophil count'])

X_train['VITALSIGNSBT'] = np.log1p(X_train['VITALSIGNSBT'])
X_test['VITALSIGNSBT'] = np.log1p(X_test['VITALSIGNSBT'])

X_train['VITALSIGNSRR'] = np.log1p(X_train['VITALSIGNSRR'])
X_test['VITALSIGNSRR'] = np.log1p(X_test['VITALSIGNSRR'])

X_train['Creatinine'] = np.log1p(X_train['Creatinine'])
X_test['Creatinine'] = np.log1p(X_test['Creatinine'])

X_train['Na'] = np.log1p(X_train['Na'])
X_test['Na'] = np.log1p(X_test['Na'])

# X_train['Lymphocyte'] = np.log1p(X_train['Lymphocyte'])
# X_test['Lymphocyte'] = np.log1p(X_test['Lymphocyte'])

# %%
X_train['Lymphocyte']
# Out:
# 26125    12.5
# 23213    18.2
# 15823    26.5
# 18061    10.6
# 11588    44.8
#          ...
# 18385    11.1
# 12239     5.0
# 3422     57.0
# 27374    37.0
# 8585     17.2
# Name: Lymphocyte, Length: 10692, dtype: float64

# %%
# fill score

score_cols = ['Leukocyte level_flag', 'Nitrite level_flag', 'Bacteria level_flag', 'Microscopic RBC level_flag', 'Microscopic WBC level_flag', 'PH_flag',
              'CHECKITEM29SCORE_flag', 'CHECKITEM30SCORE_flag', # 70~80% missing
              'HST_flag','T.Bilirubin_flag', 'PT_flag', 'HST_flag', 'INR_flag', 'APTT_flag', 'PCO2_flag', 'HCO3_flag', 'BE(ecf)_flag',
              'O2 SAT_flag', 'CHECKITEM28A_flag', 'CHECKITEM27_flag', 'CHECKITEM27SCORE_flag', 'CHECKITEM28SCORE_flag', 
              'CHECKITEM31SCORE_flag', 'CHECKITEM32SCORE_flag'] # > 80% missing

for col in score_cols:
    X_train[col] = pd.to_numeric(X_train[col], errors='coerce')
    X_train[col] = X_train[col].fillna(-1)

    X_test[col] = pd.to_numeric(X_test[col], errors='coerce')
    X_test[col] = X_test[col].fillna(-1)

# %%
y_train.sum(axis=1).mean() # 每人平均用1.65個抗生素
# Out:
# np.float64(1.2413019079685745)

# %%
drop_cols = ['HST', 'Leukocyte level' , 'Nitrite level', 'Bacteria level', 'Microscopic RBC level', 'Microscopic WBC level' , 
             'PH', 'T.Bilirubin', 'PT' , 'INR', 'APTT', 'PCO2' , 'HCO3', 'BE(ecf)', 'O2 SAT', 
             'CHECKITEM28A', 'CHECKITEM27', 'CHECKITEM27SCORE', 'CHECKITEM28SCORE', 'CHECKITEM29SCORE', 'CHECKITEM30SCORE', 
             'CHECKITEM31SCORE', 'CHECKITEM32SCORE']

X_train = X_train.drop(columns=drop_cols)
X_test = X_test.drop(columns=drop_cols)

# %%
scaled_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
               'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']

scaler = StandardScaler()

X_train[scaled_cols] = scaler.fit_transform(X_train[scaled_cols])
X_test[scaled_cols] = scaler.fit_transform(X_test[scaled_cols])

# %%
X_train.shape
# X_train.to_csv('X_train_scale.csv')
# Out:
# (10692, 62)

# %%
X_train.columns
# Out:
# Index(['Hb', 'WBC', 'AUTOIMMUNE', 'Neutrophil Seg.', 'CRP', 'K',
#        'INFECTIONSITE3', 'DM', 'VITALSIGNSDBP', 'Absolute Neutrophil count',
#        'VITALSIGNSSPO2', 'INJURELEVEL', 'CNS', 'INFECTIONSITE4',
#        'VITALSIGNSBT', 'VITALSIGNSRR', 'Lymphocyte', 'VITALSIGNSGCS',
#        'INFECTIONSITE1', 'Creatinine', 'VITALSIGNSPR', 'INFECTIONSITE2', 'SEX',
#        'MAP', 'OTHERINFECTIONSITE_flag', 'Ht', 'LIVER', 'KIDNEY',
#        'CARDIOVASCULAR', 'RESPIRATORY', 'GPT', 'CANCER', 'INFECTIONSITE9',
#        'PLT', 'Na', 'INFECTIONSITE5', 'StayTime_hours', 'AGE', 'FEVER',
#        'Leukocyte level_flag', 'Nitrite level_flag', 'Bacteria level_flag',
#        'Microscopic RBC level_flag', 'Microscopic WBC level_flag', 'PH_flag',
#        'CHECKITEM29SCORE_flag', 'CHECKITEM30SCORE_flag', 'HST_flag',
#        'T.Bilirubin_flag', 'PT_flag', 'INR_flag', 'APTT_flag', 'PCO2_flag',
#        'HCO3_flag', 'BE(ecf)_flag', 'O2 SAT_flag', 'CHECKITEM28A_flag',
#        'CHECKITEM27_flag', 'CHECKITEM27SCORE_flag', 'CHECKITEM28SCORE_flag',
#        'CHECKITEM31SCORE_flag', 'CHECKITEM32SCORE_flag'],
#       dtype='object')

# %%
# LogisticRegressionCV?
# XGBClassifier?

# %%
# base_model = LogisticRegressionCV (penalty='l1',
#                                    cv=3,
#                                    class_weight='balanced',
#                                    solver='liblinear',
#                                    max_iter=1000,
#                                    random_state=123)

base_model = RandomForestClassifier(
                                    n_estimators=800, 
                                    class_weight='balanced',
                                    min_samples_leaf=5,
                                    min_samples_split=10,
                                    max_depth=15,
                                    n_jobs=-1,
                                    random_state=123)

# base_model = XGBClassifier(n_estimators=300,
#                            max_depth=5,
#                            learning_rate=0.05,
#                            subsample=0.8,
#                            colsample_bytree=0.8,
#                            eval_metric='logloss',
#                            gamma=0,
#                            reg_alpha=1,
#                            reg_lambda=0,
#                            min_child_weight=1,
#                            random_state =123,
#                            n_jobs=-1
#     )

multi_model = MultiOutputClassifier(base_model)
# multi_model = ClassifierChain(base_model, order='random', random_state =123)
multi_model.fit(X_train, y_train)
# Out:
# MultiOutputClassifier(estimator=RandomForestClassifier(class_weight='balanced',
#                                                        max_depth=15,
#                                                        min_samples_leaf=5,
#                                                        min_samples_split=10,
#                                                        n_estimators=800,
#                                                        n_jobs=-1,
#                                                        random_state=123))

# %%
y_pred_train = multi_model.predict(X_train)
print(f1_score(y_train, y_pred_train, average='micro'))
print(f1_score(y_train, y_pred_train, average='macro'))
# Out:
# 0.8008613485890596
# 0.7724277366984832

# %%
y_prob_list = np.column_stack([multi_model.predict_proba(X_test)[:, 1] for multi_model in multi_model.estimators_])

threshold = 0.5
y_pred = (y_prob_list > threshold).astype(int)

# y_pred = multi_model.predict(X_test)
# print(y_pred[:5])

# %%
print(f1_score(y_test, y_pred, average='micro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# 0.4801088065283917
# 0.3724211497491697

# %%
hamming_loss(y_test, y_pred)
# Out:
# 0.117003367003367

# %%
jaccard_score(y_test, y_pred, average='samples', zero_division=0)
# Out:
# np.float64(0.38402076318742984)

# %%
# top k hits rate

def hit_rate_at_k(y_true, proba, k=3):
    
    if isinstance(proba, list):
       proba = np.column_stack([p[:, 1] for p in proba])
    
    topk = np.argsort(proba, axis=1)[:, -k:]
    hits = 0
    for i in range(len(y_true)):
        actual = np.where(y_true[i]==1)[0]
        if len(set(actual)& set(topk[i].tolist())):
            hits += 1
    return hits /  len(y_true)

# precision@3
def precision_at_k(y_true, proba, k=3):
    # 處理 MultiOutputClassifier 的 proba 格式 (list of arrays)
    if isinstance(proba, list):
       proba = np.column_stack([p[:, 1] for p in proba])
    
    # 取得機率最高的前 k 個索引
    topk = np.argsort(proba, axis=1)[:, -k:]
    
    total_precision = 0
    for i in range(len(y_true)):
        # 該病患實際有開的藥物索引
        actual = set(np.where(y_true[i] == 1)[0])
        # 預測的前 k 個藥物索引
        predicted = set(topk[i].tolist())
        
        # 交集數量 (中了幾個) / 推薦數量 k
        hits = len(actual & predicted)
        total_precision += (hits / k)
        
    # 回傳所有樣本的平均 Precision@k
    return total_precision / len(y_true)

# recall@3

def recall_at_k(y_true, proba, k=3):
    if isinstance(proba, list):
        proba = np.column_stack([p[:, 1] for p in proba])

    topk = np.argsort(proba, axis=1)[:, -k:]
    hits = 0
    recalls = []
    for i in range(len(y_true)):
        actual = np.where(y_true[i]==1)[0]
        if len(actual) == 0:
            continue
        recall = len(set(actual) & set(topk[i])) / len(actual)
        recalls.append(recall)
    return np.mean(recalls)

# MAP@3

def map_at_k(y_true, proba, k=3):
    if isinstance(proba, list):
        proba = np.column_stack([p[:, 1] for p in proba])

    topk = np.argsort(proba, axis=1)[:, -k:]
    hits = 0
    APs = []
    for i in range(len(y_true)):
        actual = np.where(y_true[i]==1)[0]
        if len(actual) == 0:
            continue
        score = 0
        hits = 0

        for j in range(k):
            if topk[i][j] in actual:
                hits += 1
                score += hits / (j + 1)
        APs.append(score / min(len(actual), k))
    return np.mean(APs)

# %%
hit3 = hit_rate_at_k(y_test.values, y_prob_list, k=3)
print('Hit@3: ', hit3)
# Out:
# Hit@3:  0.7803030303030303

# %%
precision3 = precision_at_k(y_test.values, y_prob_list, k=3)
print('precision@3: ', precision3)
# Out:
# precision@3:  0.30471380471380266

# %%
recall_3 = recall_at_k(y_test.values, y_prob_list, k=3)
print('Recall@3: ', recall_3)
# Out:
# Recall@3:  0.7654200059364797

# %%
map_3 = map_at_k(y_test.values, y_prob_list, k=3)
print('MAP@3: ', map_3)
# Out:
# MAP@3:  0.38129514198080533

# %%
target_names = y_train.columns

for i, col in enumerate(target_names):
    print(f'-- {col} --')
    print(classification_report(y_test.iloc[:, i], y_pred[:, i]))
# Out:
# -- Amoxicillin/Clavulanic acid --
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.96      0.96      1015
#          1.0       0.77      0.72      0.74       173
#
#     accuracy                           0.93      1188
#    macro avg       0.86      0.84      0.85      1188
# weighted avg       0.93      0.93      0.93      1188
#
# -- Azithromycin --
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.89      0.93      1128
#          1.0       0.17      0.45      0.25        60
#
#     accuracy                           0.86      1188
#    macro avg       0.57      0.67      0.59      1188
# weighted avg       0.93      0.86      0.89      1188
#
# -- Cefazolin --
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97      1125
#          1.0       0.42      0.41      0.42        63
#
#     accuracy                           0.94      1188
#    macro avg       0.69      0.69      0.69      1188
# weighted avg       0.94      0.94      0.94      1188
#
# -- Cefixime --
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.90      0.92      1112
#          1.0       0.19      0.34      0.24        76
#
#     accuracy                           0.86      1188
#    macro avg       0.57      0.62      0.58      1188
# weighted avg       0.90      0.86      0.88      1188
#
# -- Cefoperazone/sulbactam --
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.93      0.91      1036
#          1.0       0.37      0.28      0.31       152
#
#     accuracy                           0.85      1188
#    macro avg       0.63      0.60      0.61      1188
# weighted avg       0.83      0.85      0.84      1188
#
# -- Ceftriaxone --
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.98      1140
#          1.0       0.35      0.12      0.18        48
#
#     accuracy                           0.96      1188
#    macro avg       0.66      0.56      0.58      1188
# weighted avg       0.94      0.96      0.95      1188
#
# -- Ciprofloxacin --
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95      1100
#          1.0       0.40      0.38      0.39        88
#
#     accuracy                           0.91      1188
#    macro avg       0.67      0.66      0.67      1188
# weighted avg       0.91      0.91      0.91      1188
#
# -- Flomoxef --
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.74      0.74       681
#          1.0       0.65      0.64      0.65       507
#
#     accuracy                           0.70      1188
#    macro avg       0.69      0.69      0.69      1188
# weighted avg       0.70      0.70      0.70      1188
#
# -- Levofloxacin --
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97      1140
#          1.0       0.18      0.12      0.15        48
#
#     accuracy                           0.94      1188
#    macro avg       0.57      0.55      0.56      1188
# weighted avg       0.93      0.94      0.94      1188
#
# -- Metronidazole --
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.92      0.94      1102
#          1.0       0.28      0.38      0.33        86
#
#     accuracy                           0.89      1188
#    macro avg       0.62      0.65      0.63      1188
# weighted avg       0.90      0.89      0.89      1188
#
# -- Piperacillin/Tazobactam --
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.96      0.93      1037
#          1.0       0.55      0.37      0.44       151
#
#     accuracy                           0.88      1188
#    macro avg       0.73      0.66      0.69      1188
# weighted avg       0.87      0.88      0.87      1188

# %%
importance_all = []

for i, drug in enumerate(y_train.columns):
    
    model = multi_model.estimators_[i]
    
    # 建立 Series 並與特徵名稱對應
    imp = pd.Series(
        model.feature_importances_,
        index=X_train.columns
    )

    imp_df = imp.reset_index()
    imp_df.columns = ['feature','importance']
    imp_df['drug'] = drug
    
    imp_df_sorted = imp_df.sort_values("importance", ascending=False)
    
    print(f"=== Drug: {drug} (Top 10 Features) ===")
    print(imp_df_sorted.head(10).to_string(index=False)) # 不印索引比較美觀
    print("-" * 40)
    
    importance_all.append(imp_df_sorted)

importance_all = pd.concat(importance_all)
# Out:
# === Drug: Amoxicillin/Clavulanic acid (Top 10 Features) ===
#          feature  importance                        drug
#   INFECTIONSITE5    0.142334 Amoxicillin/Clavulanic acid
#   INFECTIONSITE2    0.106375 Amoxicillin/Clavulanic acid
#              AGE    0.096632 Amoxicillin/Clavulanic acid
#   INFECTIONSITE3    0.049699 Amoxicillin/Clavulanic acid
#       Creatinine    0.035289 Amoxicillin/Clavulanic acid
# T.Bilirubin_flag    0.029668 Amoxicillin/Clavulanic acid
#     VITALSIGNSPR    0.025778 Amoxicillin/Clavulanic acid
#              MAP    0.021287 Amoxicillin/Clavulanic acid
#   INFECTIONSITE1    0.021256 Amoxicillin/Clavulanic acid
#     VITALSIGNSBT    0.021152 Amoxicillin/Clavulanic acid
# ----------------------------------------
# === Drug: Azithromycin (Top 10 Features) ===
#        feature  importance         drug
# INFECTIONSITE1    0.191726 Azithromycin
# INFECTIONSITE2    0.063266 Azithromycin
# VITALSIGNSSPO2    0.051469 Azithromycin
# INFECTIONSITE3    0.045233 Azithromycin
#   VITALSIGNSBT    0.036951 Azithromycin
#            AGE    0.030078 Azithromycin
# INFECTIONSITE5    0.028466 Azithromycin
#            CRP    0.027038 Azithromycin
#   VITALSIGNSPR    0.025675 Azithromycin
#            MAP    0.023680 Azithromycin
# ----------------------------------------
# === Drug: Cefazolin (Top 10 Features) ===
#       feature  importance      drug
#     APTT_flag    0.079095 Cefazolin
#       PT_flag    0.069520 Cefazolin
#      INR_flag    0.064542 Cefazolin
#  VITALSIGNSBT    0.045645 Cefazolin
#           CRP    0.045394 Cefazolin
#  VITALSIGNSPR    0.043541 Cefazolin
#           AGE    0.037512 Cefazolin
#           MAP    0.031167 Cefazolin
#            Ht    0.028088 Cefazolin
# VITALSIGNSDBP    0.027000 Cefazolin
# ----------------------------------------
# === Drug: Cefixime (Top 10 Features) ===
#                   feature  importance     drug
#                       CRP    0.057673 Cefixime
#                       AGE    0.050764 Cefixime
#            INFECTIONSITE1    0.038264 Cefixime
#                       WBC    0.038107 Cefixime
# Absolute Neutrophil count    0.037672 Cefixime
#            INFECTIONSITE5    0.037668 Cefixime
#                Creatinine    0.037120 Cefixime
#                       MAP    0.036895 Cefixime
#              VITALSIGNSBT    0.033168 Cefixime
#                       PLT    0.032979 Cefixime
# ----------------------------------------
# === Drug: Cefoperazone/sulbactam (Top 10 Features) ===
#        feature  importance                   drug
#            AGE    0.082169 Cefoperazone/sulbactam
#   VITALSIGNSBT    0.041953 Cefoperazone/sulbactam
# INFECTIONSITE1    0.039588 Cefoperazone/sulbactam
#     Creatinine    0.039335 Cefoperazone/sulbactam
#            CRP    0.038421 Cefoperazone/sulbactam
# VITALSIGNSSPO2    0.037404 Cefoperazone/sulbactam
#   VITALSIGNSPR    0.036418 Cefoperazone/sulbactam
#     Lymphocyte    0.034420 Cefoperazone/sulbactam
#            MAP    0.034256 Cefoperazone/sulbactam
#            PLT    0.032797 Cefoperazone/sulbactam
# ----------------------------------------
# === Drug: Ceftriaxone (Top 10 Features) ===
#        feature  importance        drug
#            AGE    0.071213 Ceftriaxone
# INFECTIONSITE4    0.054809 Ceftriaxone
#   VITALSIGNSPR    0.046146 Ceftriaxone
#   VITALSIGNSBT    0.039902 Ceftriaxone
#            MAP    0.038565 Ceftriaxone
#     Creatinine    0.038510 Ceftriaxone
#  VITALSIGNSDBP    0.038322 Ceftriaxone
#     Lymphocyte    0.037572 Ceftriaxone
#            PLT    0.036919 Ceftriaxone
#            WBC    0.036432 Ceftriaxone
# ----------------------------------------
# === Drug: Ciprofloxacin (Top 10 Features) ===
#        feature  importance          drug
# INFECTIONSITE1    0.075282 Ciprofloxacin
#            AGE    0.067856 Ciprofloxacin
#            MAP    0.040718 Ciprofloxacin
#   VITALSIGNSPR    0.038599 Ciprofloxacin
#             Ht    0.037898 Ciprofloxacin
#   VITALSIGNSBT    0.036569 Ciprofloxacin
#  VITALSIGNSDBP    0.034880 Ciprofloxacin
#     Lymphocyte    0.034801 Ciprofloxacin
#     Creatinine    0.034761 Ciprofloxacin
#             Hb    0.033101 Ciprofloxacin
# ----------------------------------------
# === Drug: Flomoxef (Top 10 Features) ===
#                   feature  importance     drug
#            INFECTIONSITE2    0.098639 Flomoxef
#                       AGE    0.080835 Flomoxef
#                       CRP    0.049464 Flomoxef
#                Creatinine    0.047518 Flomoxef
#            INFECTIONSITE5    0.046342 Flomoxef
#              VITALSIGNSPR    0.039557 Flomoxef
#              VITALSIGNSBT    0.035346 Flomoxef
#                       MAP    0.031889 Flomoxef
#                       WBC    0.031339 Flomoxef
# Absolute Neutrophil count    0.030493 Flomoxef
# ----------------------------------------
# === Drug: Levofloxacin (Top 10 Features) ===
#        feature  importance         drug
# INFECTIONSITE2    0.092939 Levofloxacin
# INFECTIONSITE1    0.058198 Levofloxacin
#            AGE    0.055595 Levofloxacin
#     Creatinine    0.038985 Levofloxacin
#  VITALSIGNSDBP    0.037357 Levofloxacin
#            MAP    0.037259 Levofloxacin
#            CRP    0.036084 Levofloxacin
#   VITALSIGNSBT    0.034105 Levofloxacin
#   VITALSIGNSPR    0.031554 Levofloxacin
#     Lymphocyte    0.030901 Levofloxacin
# ----------------------------------------
# === Drug: Metronidazole (Top 10 Features) ===
#                   feature  importance          drug
#            INFECTIONSITE2    0.221753 Metronidazole
#            INFECTIONSITE1    0.070847 Metronidazole
#                       CRP    0.039796 Metronidazole
#                       AGE    0.037245 Metronidazole
# Absolute Neutrophil count    0.032049 Metronidazole
#          T.Bilirubin_flag    0.029828 Metronidazole
#                       WBC    0.029531 Metronidazole
#                Lymphocyte    0.026996 Metronidazole
#           Neutrophil Seg.    0.026100 Metronidazole
#              VITALSIGNSBT    0.024569 Metronidazole
# ----------------------------------------
# === Drug: Piperacillin/Tazobactam (Top 10 Features) ===
#                   feature  importance                    drug
#                       CRP    0.098569 Piperacillin/Tazobactam
#                       AGE    0.070292 Piperacillin/Tazobactam
#                       WBC    0.048179 Piperacillin/Tazobactam
# Absolute Neutrophil count    0.046538 Piperacillin/Tazobactam
#                Lymphocyte    0.040908 Piperacillin/Tazobactam
#                Creatinine    0.036305 Piperacillin/Tazobactam
#              VITALSIGNSPR    0.035319 Piperacillin/Tazobactam
#                       MAP    0.032496 Piperacillin/Tazobactam
#                        Ht    0.031311 Piperacillin/Tazobactam
#              VITALSIGNSBT    0.030652 Piperacillin/Tazobactam
# ----------------------------------------

# %%
importance_summary = importance_all.groupby('feature')['importance'].mean().sort_values(ascending=False)

print(importance_summary)
# Out:
# feature
# AGE                           0.061835
# INFECTIONSITE2                0.060883
# INFECTIONSITE1                0.049892
# CRP                           0.042893
# VITALSIGNSBT                  0.034546
#                                 ...
# Microscopic WBC level_flag    0.004016
# Nitrite level_flag            0.003765
# CHECKITEM31SCORE_flag         0.002821
# INFECTIONSITE9                0.002156
# OTHERINFECTIONSITE_flag       0.001697
# Name: importance, Length: 62, dtype: float64
