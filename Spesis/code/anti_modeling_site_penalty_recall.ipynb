# %%
import pandas as pd
import numpy as np
import re 
from IPython.display import display, HTML

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV 
from sklearn.metrics import classification_report, confusion_matrix, f1_score, recall_score, hamming_loss, jaccard_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from imblearn.ensemble import BalancedRandomForestClassifier
from xgboost import XGBClassifier
from sklearn.multioutput import MultiOutputClassifier, ClassifierChain
from sklearn.calibration import CalibratedClassifierCV
from scipy.stats import entropy

import shap

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

data= pd.read_csv(r"‪D:\ML Data\Spesis\anti_total.csv".strip('\u202a'), index_col=False)

# %% [raw]
# 先過濾<500，再分有無感染部位，免得有些抗生素消失(Clindamycin, Gentamicin)

# %% [raw]
# 過濾抗生素使用<500次的，後刪除沒給抗生素的(沒有)

# %%
start_index = data.columns.get_loc('Acyclovir')
end_index = data.columns.get_loc('tenofovir/emtricitabine/rilpivirine')

# %%
abx_cols = data.columns[start_index:end_index+1]
col_sum = data[abx_cols].sum()

# %%
abx_cols = data.columns[start_index:end_index+1]
col_sum = data[abx_cols].sum()

# %%
final_cols = col_sum[col_sum >= 400].index.tolist()
base_cols = [c for c in data.columns if c not in abx_cols]
data_filter = data[base_cols + final_cols]

# %%
data_filter[final_cols].sum().sort_values(ascending=False)
# Out:
# Amoxicillin/Clavulanic acid    5515.0
# Flomoxef                       5196.0
# Cefazolin                      2371.0
# Cefixime                       2166.0
# Ciprofloxacin                  2071.0
# Azithromycin                   2053.0
# Cefuroxime                     1691.0
# Piperacillin/Tazobactam        1511.0
# Cefoperazone/sulbactam         1412.0
# Peramivir                      1119.0
# Baloxavir marboxil             1085.0
# Metronidazole                  1020.0
# Cefadroxil                      918.0
# Oseltamivir                     835.0
# Levofloxacin                    720.0
# Clindamycin                     624.0
# Gentamicin                      623.0
# Ceftriaxone                     610.0
# Cephalexin                      517.0
# Ampicillin                      423.0
# dtype: float64

# %% [raw]
# 分出有感染部位紀錄的data

# %%
all_site_cols = [
    'INFECTIONSITE1', 'INFECTIONSITE2', 'INFECTIONSITE3',
    'INFECTIONSITE4', 'INFECTIONSITE5', 'INFECTIONSITE9', 
    'OTHERINFECTIONSITE_flag'
]

temp_df = data_filter[all_site_cols].copy().astype(str).apply(lambda x: x.str.strip())
temp_df = temp_df.replace(['', 'nan', 'None', 'nan.0'], '0')

temp_df = temp_df.astype(float)

has_site_mask = (temp_df > 0).any(axis=1)

site_samples = data[has_site_mask].copy()

print(f"原始樣本數: {len(data)}")
print(f"至少標註一個部位的樣本數: {len(site_samples)}")
print(f"被排除掉的『全空/全0』樣本數: {len(data) - len(site_samples)}")
# Out:
# 原始樣本數: 27968
# 至少標註一個部位的樣本數: 11880
# 被排除掉的『全空/全0』樣本數: 16088

# %%
len(site_samples), len(site_samples['ACCOUNTNO'])
# Out:
# (11880, 11880)

# %%
site_samples['Clindamycin'].sum(), site_samples['Gentamicin'].sum()
# Out:
# (np.float64(379.0), np.float64(201.0))

# %%
roomno_mapping = {'A': '1', 'C': '2', 'D': '3', 'E': '4', 'H': '5', 'K': '6'}
site_samples['ROOMNO'] = site_samples['ROOMNO'].map(roomno_mapping)          

site_samples['SEX'] = site_samples['SEX'].map({'M': 1, 'F': 0})

yn_cols = [
    'ISSEPSIS0', 'FEVER', 'DM', 'CARDIOVASCULAR', 
    'RESPIRATORY', 'CNS', 'CANCER', 'LIVER', 'KIDNEY', 'AUTOIMMUNE'
]

for col in yn_cols:
    site_samples[col] = site_samples[col].map({'Y': 1, 'N': 0})

# %%
feature_cols = list(set(site_samples.columns) - set(abx_cols))
X = site_samples[feature_cols]
y = site_samples[final_cols]

# %%
X.shape, y.shape
# Out:
# ((11880, 68), (11880, 20))

# %%
X = X.drop(columns=['ACCOUNTNO','ROOMNO', 'INTIME', 'Influenza Virus A level', 'FIRST_ORDERTIME', 'ISSEPSIS0'])
y = y.drop(columns=['Peramivir', 'Baloxavir marboxil', 'Oseltamivir', 'Cephalexin', 'Cefadroxil'])
                    #'Amoxicillin', 'Doxycycline', 'Acyclovir', 'Valaciclovir', 'Tenofovir alafenamide', 'Ceftazidime'])# 去掉抗病毒的藥(前3)

# %%
# 找出至少有一種藥物的樣本 (Row sum > 0)
has_label_mask = (y.sum(axis=1) > 0)

# 同步過濾 X 和 y
X = X[has_label_mask]
y = y[has_label_mask]

print(f"原本樣本數: {len(has_label_mask)}")
print(f"過濾後樣本數: {len(y)}")
print(f"已刪除 {len(has_label_mask) - len(y)} 筆因刪除藥物欄位而變成『無給藥』的樣本")
# Out:
# 原本樣本數: 11880
# 過濾後樣本數: 11470
# 已刪除 410 筆因刪除藥物欄位而變成『無給藥』的樣本

# %%
X.columns
# Out:
# Index(['Absolute Neutrophil count', 'PCO2', 'INFECTIONSITE4',
#        'CHECKITEM32SCORE', 'Hb', 'StayTime_hours', 'VITALSIGNSPR',
#        'VITALSIGNSRR', 'INFECTIONSITE5', 'INFECTIONSITE1', 'INJURELEVEL',
#        'Lymphocyte', 'Leukocyte level', 'Microscopic RBC level', 'Na',
#        'O2 SAT', 'Ht', 'SEX', 'VITALSIGNSGCS', 'VITALSIGNSSPO2',
#        'CHECKITEM27SCORE', 'PLT', 'INFECTIONSITE9', 'INR',
#        'Microscopic WBC level', 'HST', 'CANCER', 'CHECKITEM31SCORE',
#        'AUTOIMMUNE', 'MAP', 'BE(ecf)', 'LIVER', 'CHECKITEM30SCORE',
#        'VITALSIGNSDBP', 'APTT', 'PH', 'CHECKITEM29SCORE', 'INFECTIONSITE2',
#        'CHECKITEM28SCORE', 'CHECKITEM28A', 'RESPIRATORY', 'VITALSIGNSBT', 'PT',
#        'KIDNEY', 'GPT', 'HCO3', 'T.Bilirubin', 'CRP', 'K', 'Neutrophil Seg.',
#        'OTHERINFECTIONSITE_flag', 'CNS', 'CARDIOVASCULAR', 'Bacteria level',
#        'AGE', 'Creatinine', 'INFECTIONSITE3', 'FEVER', 'WBC', 'Nitrite level',
#        'DM', 'CHECKITEM27'],
#       dtype='object')

# %%
y[y.columns].sum().sort_values(ascending=False)
# Out:
# Flomoxef                       5190.0
# Amoxicillin/Clavulanic acid    1581.0
# Piperacillin/Tazobactam        1509.0
# Cefoperazone/sulbactam         1411.0
# Metronidazole                   916.0
# Ciprofloxacin                   872.0
# Cefixime                        851.0
# Azithromycin                    695.0
# Ceftriaxone                     609.0
# Cefazolin                       589.0
# Levofloxacin                    501.0
# Cefuroxime                      497.0
# Clindamycin                     379.0
# Gentamicin                      201.0
# Ampicillin                       88.0
# dtype: float64

# %% [raw]
# 建立flag for missing above 80%

# %%
####################### Missing 70~80% #######################

# 檢驗

X['Leukocyte level_flag'] = (
     X['Leukocyte level'].fillna('').str.strip().ne('').astype(int))

X['Nitrite level_flag'] = (
     X['Nitrite level'].fillna('').str.strip().ne('').astype(int))

X['Bacteria level_flag'] = (
     X['Bacteria level'].fillna('').str.strip().ne('').astype(int))

X['Microscopic RBC level_flag'] = (
     X['Microscopic RBC level'].fillna('').str.strip().ne('').astype(int))

X['Microscopic WBC level_flag'] = (
     X['Microscopic WBC level'].fillna('').str.strip().ne('').astype(int))

X['PH_flag'] = (
     X['Microscopic RBC level'].fillna('').str.strip().ne('').astype(int))



# 計分

X['CHECKITEM29SCORE_flag'] = (
     X['CHECKITEM29SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM30SCORE_flag'] = (
     X['CHECKITEM30SCORE'].fillna('').str.strip().ne('').astype(int))


####################### Missing > 80% #######################

# 檢驗

X['HST_flag'] = (
     X['HST'].fillna('').str.strip().ne('').astype(int))

X['T.Bilirubin_flag'] = (
     X['T.Bilirubin'].fillna('').str.strip().ne('').astype(int))

X['PT_flag'] = (
     X['PT'].fillna('').str.strip().ne('').astype(int))

X['HST_flag'] = (
     X['HST'].fillna('').str.strip().ne('').astype(int))

X['INR_flag'] = (
     X['INR'].fillna('').str.strip().ne('').astype(int))

X['APTT_flag'] = (
     X['APTT'].fillna('').str.strip().ne('').astype(int))

X['PCO2_flag'] = (
     X['PCO2'].fillna('').str.strip().ne('').astype(int))

X['HCO3_flag'] = (
     X['HCO3'].fillna('').str.strip().ne('').astype(int))


X['BE(ecf)_flag'] = (
     X['BE(ecf)'].fillna('').str.strip().ne('').astype(int))

X['O2 SAT_flag'] = (
     X['O2 SAT'].fillna('').str.strip().ne('').astype(int))

# 計分

X['CHECKITEM28A_flag'] = (
     X['CHECKITEM28A'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM27_flag'] = (
     X['CHECKITEM27'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM27SCORE_flag'] = (
     X['CHECKITEM27SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM28SCORE_flag'] = (
     X['CHECKITEM28SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM31SCORE_flag'] = (
     X['CHECKITEM31SCORE'].fillna('').str.strip().ne('').astype(int))

X['CHECKITEM32SCORE_flag'] = (
     X['CHECKITEM32SCORE'].fillna('').str.strip().ne('').astype(int))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

df = X

vital_cols = list(set(['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
            'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']))

# 設定每列顯示幾個圖
cols_per_row = 4
rows = math.ceil(len(vital_cols) / cols_per_row)

# 建立畫布
fig, axes = plt.subplots(rows, cols_per_row, figsize=(20, rows * 4))
axes = axes.flatten() # 將多維陣列拉平，方便迴圈讀取

for i, col in enumerate(vital_cols):
    if col in df.columns:
        # 繪製直方圖 + 密度曲線(kde)
        sns.histplot(df[col].dropna(), kde=True, ax=axes[i], bins=30)
        axes[i].set_title(f'Distribution of {col}', fontsize=12)
        axes[i].set_xlabel('')
        axes[i].set_ylabel('')
    else:
        axes[i].set_axis_off() # 如果欄位不存在就留白

# 移除多餘的空白子圖
for j in range(i + 1, len(axes)):
    axes[j].set_axis_off()

plt.tight_layout()
plt.show()

# %%
lower_bound = X.quantile(0.01)
upper_bound = X.quantile(0.99)

outliers_low = (X < lower_bound).sum()
outliers_high = (X > upper_bound).sum()

outlier_summary = pd.DataFrame({
    'Low_Outliers (<1%)': outliers_low,
    'High_Outliers (>99%)': outliers_high,
    'Total_Outliers': outliers_low + outliers_high
})

print(f"全資料集總離群值筆數: {outlier_summary['Total_Outliers'].sum()}")
print("\n各欄位離群值統計 (前 10 名):")
print(outlier_summary.sort_values('Total_Outliers', ascending=False).head(10))
# Out:
# 全資料集總離群值筆數: 3916
#
# 各欄位離群值統計 (前 10 名):
#                            Low_Outliers (<1%)  High_Outliers (>99%)  \
# VITALSIGNSPR                              105                   113
# MAP                                        99                   105
# VITALSIGNSDBP                             101                    98
# WBC                                        93                    93
# VITALSIGNSBT                               90                    96
# Ht                                         93                    91
# Absolute Neutrophil count                  92                    92
# PLT                                        92                    92
# Lymphocyte                                 84                    93
# Creatinine                                 85                    91
#
#                            Total_Outliers
# VITALSIGNSPR                          218
# MAP                                   204
# VITALSIGNSDBP                         199
# WBC                                   186
# VITALSIGNSBT                          186
# Ht                                    184
# Absolute Neutrophil count             184
# PLT                                   184
# Lymphocyte                            177
# Creatinine                            176

# %%
# outlier修改為1%或99% quantile
X = X.clip(lower=lower_bound, upper=upper_bound, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((9176, 85), (9176, 15), (2294, 85), (2294, 15))

# %%
X_train.isnull().sum(), X_test.isnull().sum()
# Out:
# (Absolute Neutrophil count    1838
#  PCO2                         6942
#  INFECTIONSITE4                  0
#  CHECKITEM32SCORE             6180
#  Hb                           1721
#                               ...
#  CHECKITEM27_flag                0
#  CHECKITEM27SCORE_flag           0
#  CHECKITEM28SCORE_flag           0
#  CHECKITEM31SCORE_flag           0
#  CHECKITEM32SCORE_flag           0
#  Length: 85, dtype: int64,
#  Absolute Neutrophil count     434
#  PCO2                         1729
#  INFECTIONSITE4                  0
#  CHECKITEM32SCORE             1516
#  Hb                            400
#                               ...
#  CHECKITEM27_flag                0
#  CHECKITEM27SCORE_flag           0
#  CHECKITEM28SCORE_flag           0
#  CHECKITEM31SCORE_flag           0
#  CHECKITEM32SCORE_flag           0
#  Length: 85, dtype: int64)

# %%
X_train.dtypes, X_test.dtypes
# Out:
# (Absolute Neutrophil count    float64
#  PCO2                         float64
#  INFECTIONSITE4                 int64
#  CHECKITEM32SCORE             float64
#  Hb                           float64
#                                ...
#  CHECKITEM27_flag               int64
#  CHECKITEM27SCORE_flag          int64
#  CHECKITEM28SCORE_flag          int64
#  CHECKITEM31SCORE_flag          int64
#  CHECKITEM32SCORE_flag          int64
#  Length: 85, dtype: object,
#  Absolute Neutrophil count    float64
#  PCO2                         float64
#  INFECTIONSITE4                 int64
#  CHECKITEM32SCORE             float64
#  Hb                           float64
#                                ...
#  CHECKITEM27_flag               int64
#  CHECKITEM27SCORE_flag          int64
#  CHECKITEM28SCORE_flag          int64
#  CHECKITEM31SCORE_flag          int64
#  CHECKITEM32SCORE_flag          int64
#  Length: 85, dtype: object)

# %%
y_train.sum().sort_values(ascending=False)
# Out:
# Flomoxef                       4148.0
# Amoxicillin/Clavulanic acid    1253.0
# Piperacillin/Tazobactam        1199.0
# Cefoperazone/sulbactam         1140.0
# Metronidazole                   752.0
# Ciprofloxacin                   702.0
# Cefixime                        695.0
# Azithromycin                    544.0
# Ceftriaxone                     489.0
# Cefazolin                       466.0
# Cefuroxime                      399.0
# Levofloxacin                    394.0
# Clindamycin                     300.0
# Gentamicin                      171.0
# Ampicillin                       78.0
# dtype: float64

# %%
# 轉數值

num_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
            'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']

for col in num_cols:
    X_train[col] = pd.to_numeric(X_train[col], errors='coerce')
    X_test[col] = pd.to_numeric(X_test[col], errors='coerce')

# %%
# vital sign impute
vital_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
              'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']


for col in vital_cols:
    # X_train[col + "_missing"] = X_train[col].isna().astype(int) # missing indicator
    median = X_train[col].median()
    X_train[col] = X_train[col].fillna(median)
    
    # X_test[col + "_missing"] = X_test[col].isna().astype(int) # missing indicator
    X_test[col] = X_test[col].fillna(median)

# %%
# 取 log

X_train['CRP'] = np.log1p(X_train['CRP'])
X_test['CRP'] = np.log1p(X_test['CRP'])

X_train['PLT'] = np.log1p(X_train['PLT'])
X_test['PLT'] = np.log1p(X_test['PLT'])

X_train['WBC'] = np.log1p(X_train['WBC'])
X_test['WBC'] = np.log1p(X_test['WBC'])

X_train['AGE'] = np.log1p(X_train['AGE'])
X_test['AGE'] = np.log1p(X_test['AGE'])

X_train['K'] = np.log1p(X_train['K'])
X_test['K'] = np.log1p(X_test['K'])

X_train['GPT'] = np.log1p(X_train['GPT'])
X_test['GPT'] = np.log1p(X_test['GPT'])

X_train['VITALSIGNSSPO2'] = np.log1p(X_train['VITALSIGNSSPO2'])
X_test['VITALSIGNSSPO2'] = np.log1p(X_test['VITALSIGNSSPO2'])

X_train['Absolute Neutrophil count'] = np.log1p(X_train['Absolute Neutrophil count'])
X_test['Absolute Neutrophil count'] = np.log1p(X_test['Absolute Neutrophil count'])

X_train['VITALSIGNSBT'] = np.log1p(X_train['VITALSIGNSBT'])
X_test['VITALSIGNSBT'] = np.log1p(X_test['VITALSIGNSBT'])

X_train['VITALSIGNSRR'] = np.log1p(X_train['VITALSIGNSRR'])
X_test['VITALSIGNSRR'] = np.log1p(X_test['VITALSIGNSRR'])

X_train['Creatinine'] = np.log1p(X_train['Creatinine'])
X_test['Creatinine'] = np.log1p(X_test['Creatinine'])

X_train['Na'] = np.log1p(X_train['Na'])
X_test['Na'] = np.log1p(X_test['Na'])

# X_train['Lymphocyte'] = np.log1p(X_train['Lymphocyte'])
# X_test['Lymphocyte'] = np.log1p(X_test['Lymphocyte'])

# %%
# fill score

score_cols = ['Leukocyte level_flag', 'Nitrite level_flag', 'Bacteria level_flag', 'Microscopic RBC level_flag', 'Microscopic WBC level_flag', 'PH_flag',
              'CHECKITEM29SCORE_flag', 'CHECKITEM30SCORE_flag', # 70~80% missing
              'HST_flag','T.Bilirubin_flag', 'PT_flag', 'HST_flag', 'INR_flag', 'APTT_flag', 'PCO2_flag', 'HCO3_flag', 'BE(ecf)_flag',
              'O2 SAT_flag', 'CHECKITEM28A_flag', 'CHECKITEM27_flag', 'CHECKITEM27SCORE_flag', 'CHECKITEM28SCORE_flag', 
              'CHECKITEM31SCORE_flag', 'CHECKITEM32SCORE_flag'] # > 80% missing

for col in score_cols:
    X_train[col] = pd.to_numeric(X_train[col], errors='coerce')
    X_train[col] = X_train[col].fillna(-1)

    X_test[col] = pd.to_numeric(X_test[col], errors='coerce')
    X_test[col] = X_test[col].fillna(-1)

# %%
y_train.sum(axis=1).mean() # 每人平均用1.4個抗生素
# Out:
# np.float64(1.3873147340889276)

# %%
drop_cols = ['HST', 'Leukocyte level' , 'Nitrite level', 'Bacteria level', 'Microscopic RBC level', 'Microscopic WBC level' , 
             'PH', 'T.Bilirubin', 'PT' , 'INR', 'APTT', 'PCO2' , 'HCO3', 'BE(ecf)', 'O2 SAT', 
             'CHECKITEM28A', 'CHECKITEM27', 'CHECKITEM27SCORE', 'CHECKITEM28SCORE', 'CHECKITEM29SCORE', 'CHECKITEM30SCORE', 
             'CHECKITEM31SCORE', 'CHECKITEM32SCORE']

X_train = X_train.drop(columns=drop_cols)
X_test = X_test.drop(columns=drop_cols)

# %%
scaled_cols = ['AGE', 'StayTime_hours', 'VITALSIGNSBT', 'VITALSIGNSPR', 'VITALSIGNSRR', 'VITALSIGNSSPO2', 'VITALSIGNSDBP', 'VITALSIGNSGCS', 'MAP', 'Hb', 'WBC', 
               'Ht', 'PLT', 'Lymphocyte', 'Neutrophil Seg.', 'Absolute Neutrophil count', 'Na', 'K', 'Creatinine', 'GPT', 'CRP']

scaler = StandardScaler()

X_train[scaled_cols] = scaler.fit_transform(X_train[scaled_cols])
X_test[scaled_cols] = scaler.fit_transform(X_test[scaled_cols])

# %%
X_train.shape
# X_train.to_csv('X_train_scale.csv')
# Out:
# (9176, 62)

# %%
y_train.columns
# Out:
# Index(['Amoxicillin/Clavulanic acid', 'Ampicillin', 'Azithromycin',
#        'Cefazolin', 'Cefixime', 'Cefoperazone/sulbactam', 'Ceftriaxone',
#        'Cefuroxime', 'Ciprofloxacin', 'Clindamycin', 'Flomoxef', 'Gentamicin',
#        'Levofloxacin', 'Metronidazole', 'Piperacillin/Tazobactam'],
#       dtype='object')

# %%
X_train.columns
# Out:
# Index(['Absolute Neutrophil count', 'INFECTIONSITE4', 'Hb', 'StayTime_hours',
#        'VITALSIGNSPR', 'VITALSIGNSRR', 'INFECTIONSITE5', 'INFECTIONSITE1',
#        'INJURELEVEL', 'Lymphocyte', 'Na', 'Ht', 'SEX', 'VITALSIGNSGCS',
#        'VITALSIGNSSPO2', 'PLT', 'INFECTIONSITE9', 'CANCER', 'AUTOIMMUNE',
#        'MAP', 'LIVER', 'VITALSIGNSDBP', 'INFECTIONSITE2', 'RESPIRATORY',
#        'VITALSIGNSBT', 'KIDNEY', 'GPT', 'CRP', 'K', 'Neutrophil Seg.',
#        'OTHERINFECTIONSITE_flag', 'CNS', 'CARDIOVASCULAR', 'AGE', 'Creatinine',
#        'INFECTIONSITE3', 'FEVER', 'WBC', 'DM', 'Leukocyte level_flag',
#        'Nitrite level_flag', 'Bacteria level_flag',
#        'Microscopic RBC level_flag', 'Microscopic WBC level_flag', 'PH_flag',
#        'CHECKITEM29SCORE_flag', 'CHECKITEM30SCORE_flag', 'HST_flag',
#        'T.Bilirubin_flag', 'PT_flag', 'INR_flag', 'APTT_flag', 'PCO2_flag',
#        'HCO3_flag', 'BE(ecf)_flag', 'O2 SAT_flag', 'CHECKITEM28A_flag',
#        'CHECKITEM27_flag', 'CHECKITEM27SCORE_flag', 'CHECKITEM28SCORE_flag',
#        'CHECKITEM31SCORE_flag', 'CHECKITEM32SCORE_flag'],
#       dtype='object')

# %%
# LogisticRegressionCV?
# XGBClassifier?
# RandomForestClassifier?
# MultiOutputClassifier.fit?

# %%
base_model = XGBClassifier(n_estimators=300,
                           max_depth=5,
                           learning_rate=0.05,
                           subsample=0.8,
                           colsample_bytree=0.8,
                           eval_metric='logloss',
                           gamma=0,
                           reg_alpha=2,
                           reg_lambda=0.0,
                           min_child_weight=1,
                           scale_pos_weight=2,
                           random_state =123,
                           n_jobs=-1
    )


multi_model = MultiOutputClassifier(base_model)
multi_model.fit(X_train, y_train) # sample_weight=sample_weight

#################################################################################################

# # 用字典存所有的子模型
# models = {}

# for col in y_train.columns:
#     # 針對每一種抗生素動態計算比例
#     pos = y_train[col].sum()
#     neg = len(y_train) - pos
#     spw = neg / pos if pos > 0 else 1
    
#     # 為該藥物建立專屬模型
#     model = XGBClassifier(
#                            n_estimators=300,
#                            max_depth=5,
#                            learning_rate=0.05,
#                            subsample=0.8,
#                            colsample_bytree=0.8,
#                            eval_metric='logloss',
#                            gamma=0,
#                            reg_alpha=2.0,
#                            reg_lambda=0.0,
#                            min_child_weight=1,
#                            scale_pos_weight=spw,
#                            random_state =123,
#                            n_jobs=-1
#     )
    
#     print(f"正在訓練 {col}, scale_pos_weight: {spw:.2f}")
#     model.fit(X_train, y_train[col])
#     models[col] = model

# # 預測時手動合併
# y_prob_list = np.column_stack([models[col].predict_proba(X_test)[:, 1] for col in y_train.columns])
# Out:
# MultiOutputClassifier(estimator=XGBClassifier(base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=0.8, device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric='logloss',
#                                               feature_types=None, gamma=0,
#                                               grow_policy=None,
#                                               importance_type=None,
#                                               interaction_constraints=None,
#                                               learning_rate=0.05, max_bin=None,
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None, max_depth=5,
#                                               max_leaves=None,
#                                               min_child_weight=1, missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=300, n_jobs=-1,
#                                               num_parallel_tree=None,
#                                               random_state=123, ...))

# %%
y_pred_train = multi_model.predict(X_train)
print(f1_score(y_train, y_pred_train, average='micro'))
print(f1_score(y_train, y_pred_train, average='macro'))
# Out:
# 0.8231351521841981
# 0.847498941128783

# %%
target_names = y_train.columns

for i, col in enumerate(target_names):
    print(f'-- {col} --')
    print(classification_report(y_train.iloc[:, i], y_pred_train[:, i]))
# Out:
# -- Amoxicillin/Clavulanic acid --
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98      7923
#          1.0       0.87      0.90      0.88      1253
#
#     accuracy                           0.97      9176
#    macro avg       0.93      0.94      0.93      9176
# weighted avg       0.97      0.97      0.97      9176
#
# -- Ampicillin --
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      9098
#          1.0       1.00      1.00      1.00        78
#
#     accuracy                           1.00      9176
#    macro avg       1.00      1.00      1.00      9176
# weighted avg       1.00      1.00      1.00      9176
#
# -- Azithromycin --
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      8632
#          1.0       0.96      0.84      0.90       544
#
#     accuracy                           0.99      9176
#    macro avg       0.98      0.92      0.94      9176
# weighted avg       0.99      0.99      0.99      9176
#
# -- Cefazolin --
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      8710
#          1.0       0.96      0.82      0.88       466
#
#     accuracy                           0.99      9176
#    macro avg       0.98      0.91      0.94      9176
# weighted avg       0.99      0.99      0.99      9176
#
# -- Cefixime --
#               precision    recall  f1-score   support
#
#          0.0       0.96      1.00      0.98      8481
#          1.0       0.98      0.54      0.69       695
#
#     accuracy                           0.96      9176
#    macro avg       0.97      0.77      0.84      9176
# weighted avg       0.96      0.96      0.96      9176
#
# -- Cefoperazone/sulbactam --
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      8036
#          1.0       0.91      0.70      0.79      1140
#
#     accuracy                           0.95      9176
#    macro avg       0.93      0.84      0.88      9176
# weighted avg       0.95      0.95      0.95      9176
#
# -- Ceftriaxone --
#               precision    recall  f1-score   support
#
#          0.0       0.98      1.00      0.99      8687
#          1.0       0.99      0.62      0.76       489
#
#     accuracy                           0.98      9176
#    macro avg       0.98      0.81      0.88      9176
# weighted avg       0.98      0.98      0.98      9176
#
# -- Cefuroxime --
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      8777
#          1.0       0.95      0.73      0.82       399
#
#     accuracy                           0.99      9176
#    macro avg       0.97      0.86      0.91      9176
# weighted avg       0.99      0.99      0.99      9176
#
# -- Ciprofloxacin --
#               precision    recall  f1-score   support
#
#          0.0       0.97      1.00      0.98      8474
#          1.0       0.93      0.63      0.75       702
#
#     accuracy                           0.97      9176
#    macro avg       0.95      0.81      0.87      9176
# weighted avg       0.97      0.97      0.97      9176
#
# -- Clindamycin --
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      8876
#          1.0       0.94      0.94      0.94       300
#
#     accuracy                           1.00      9176
#    macro avg       0.97      0.97      0.97      9176
# weighted avg       1.00      1.00      1.00      9176
#
# -- Flomoxef --
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.66      0.78      5028
#          1.0       0.70      0.96      0.81      4148
#
#     accuracy                           0.80      9176
#    macro avg       0.83      0.81      0.80      9176
# weighted avg       0.84      0.80      0.80      9176
#
# -- Gentamicin --
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      9005
#          1.0       0.99      0.95      0.97       171
#
#     accuracy                           1.00      9176
#    macro avg       1.00      0.98      0.99      9176
# weighted avg       1.00      1.00      1.00      9176
#
# -- Levofloxacin --
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      8782
#          1.0       0.99      0.72      0.83       394
#
#     accuracy                           0.99      9176
#    macro avg       0.99      0.86      0.91      9176
# weighted avg       0.99      0.99      0.99      9176
#
# -- Metronidazole --
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      8424
#          1.0       0.92      0.82      0.87       752
#
#     accuracy                           0.98      9176
#    macro avg       0.95      0.91      0.93      9176
# weighted avg       0.98      0.98      0.98      9176
#
# -- Piperacillin/Tazobactam --
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.99      0.97      7977
#          1.0       0.92      0.71      0.80      1199
#
#     accuracy                           0.95      9176
#    macro avg       0.94      0.85      0.89      9176
# weighted avg       0.95      0.95      0.95      9176

# %%
# # # 原始機率
y_prob_list = np.column_stack([multi_model.predict_proba(X_test)[:, 1] for multi_model in multi_model.estimators_])
y_pred = multi_model.predict(X_test)
# print(y_pred[:5])

# 計算每種抗生素的使用頻率
drug_freq = y_train.mean(axis=0).values
drug_freq = np.clip(drug_freq, 1e-6, None) #避免除以0

# 計算每種抗生素權重(F1/recall)
drug_weight = []

# 用y_train去計算f1，或用cv
for i, col in enumerate(y_train.columns):
    # score = 1 / (f1_score(y_train.values[:, i], y_pred_train[:, i], average='binary') + 1e-6)
    score = 1 / (recall_score(y_train.values[:, i], y_pred_train[:, i], average='binary') + 1e-6)
    drug_weight.append(score)

drug_weight = np.clip(drug_weight, 1e-6, None)

#  normalize
drug_weight = drug_weight / drug_weight.mean()

alpha = 0.01 # penalty
belta = 0.9

# adjusted_scores = y_prob_list / (drug_freq ** alpha)
# adjusted_scores = (np.log(y_prob_list)+ belta * np.log(drug_weight)- alpha * np.log(drug_freq))
adjusted_scores = y_prob_list * drug_weight ** belta - alpha * np.log(drug_freq)

# %%
drug_weight
# Out:
# array([0.85145279, 0.76719098, 0.91324248, 0.9408182 , 1.43332599,
#        1.09598665, 1.23406632, 1.05554858, 1.21847908, 0.81327661,
#        0.79797093, 0.80484449, 1.06060748, 0.93353963, 1.07964978])

# %%
drug_weight ** belta
# Out:
# array([0.86525579, 0.78779486, 0.92156823, 0.94657524, 1.38264434,
#        1.08598728, 1.20838312, 1.04985761, 1.19463785, 0.83026065,
#        0.81618454, 0.82250922, 1.05438499, 0.93998189, 1.07140732])

# %%
print(f1_score(y_test, y_pred, average='micro'))
print(f1_score(y_test, y_pred, average='macro'))
# Out:
# 0.5012704174228675
# 0.3313584771831612

# %%
jaccard_score(y_test, y_pred, average='samples', zero_division=0)
# Out:
# np.float64(0.4326431269979657)

# %%
hamming_loss(y_test, y_pred)
# Out:
# 0.07986050566695728

# %%
# top k hits rate

def hit_rate_at_k(y_true, proba, k=3):
    
    if isinstance(proba, list):
       proba = np.column_stack([p[:, 1] for p in proba])
    
    topk = np.argsort(proba, axis=1)[:, -k:]
    hits = 0
    for i in range(len(y_true)):
        actual = np.where(y_true[i]==1)[0]
        if len(set(actual)& set(topk[i].tolist())):
            hits += 1
    return hits /  len(y_true)

# precision@3
def precision_at_k(y_true, proba, k=3):
    # 處理 MultiOutputClassifier 的 proba 格式 (list of arrays)
    if isinstance(proba, list):
       proba = np.column_stack([p[:, 1] for p in proba])
    
    # 取得機率最高的前 k 個索引
    topk = np.argsort(proba, axis=1)[:, -k:]
    
    total_precision = 0
    for i in range(len(y_true)):
        # 該病患實際有開的藥物索引
        actual = set(np.where(y_true[i] == 1)[0])
        # 預測的前 k 個藥物索引
        predicted = set(topk[i].tolist())
        
        # 交集數量 (中了幾個) / 推薦數量 k
        hits = len(actual & predicted)
        total_precision += (hits / k)
        
    # 回傳所有樣本的平均 Precision@k
    return total_precision / len(y_true)

# recall@3

def recall_at_k(y_true, proba, k=3):
    if isinstance(proba, list):
        proba = np.column_stack([p[:, 1] for p in proba])

    topk = np.argsort(proba, axis=1)[:, -k:]
    hits = 0
    recalls = []
    for i in range(len(y_true)):
        actual = np.where(y_true[i]==1)[0]
        if len(actual) == 0:
            continue
        recall = len(set(actual) & set(topk[i])) / len(actual)
        recalls.append(recall)
    return np.mean(recalls)

# MAP@3

def map_at_k(y_true, scores, k=3):

    topk = np.argsort(scores, axis=1)[:, ::-1][:, :k]  # 排序

    APs = []

    for i in range(len(y_true)):
        actual = np.where(y_true[i] == 1)[0]

        if len(actual) == 0:
            continue

        hits = 0
        score = 0

        for j in range(k):
            if topk[i][j] in actual:
                hits += 1
                score += hits / (j + 1)

        APs.append(score / min(len(actual), k))

    return np.mean(APs)


################################

k=5
hit3 = hit_rate_at_k(y_test.values, adjusted_scores, k=k)
print(f"Hit@{k}: {hit3}")
precision3 = precision_at_k(y_test.values, adjusted_scores, k=k)
print(f"precision@{k}: {precision3}")
recall_3 = recall_at_k(y_test.values, adjusted_scores, k=k)
print(f"Recall@{k}: {recall_3}")
map_3 = map_at_k(y_test.values, adjusted_scores, k=k)
print(f"MAP@{k}: {map_3}")
# Out:
# Hit@5: 0.9224062772449869
# precision@5: 0.2374019180470745
# Recall@5: 0.8742734670154025
# MAP@5: 0.6536193451516032

# %%
drug_names = y_train.columns


def show_top3_prediction(patient_idx, proba_matrix, y_true, drug_names, k=3):
    #預測
    probs = proba_matrix[patient_idx]
    topk_idx = np.argsort(probs)[-k:][::-1]

    #實際
    actual_idx = np.where(y_true[patient_idx] == 1)[0]
    actual_drugs = drug_names[actual_idx].tolist()

    print(f"實際給藥: {actual_drugs if actual_drugs else '無'}")
    print("\n推薦藥物:")
    for rank, idx in enumerate(topk_idx, 1):
        print(f"{rank}. {drug_names[idx]} (Score: {probs[idx]:.4f})")
    print("="*50)

for i in range(10):
    show_top3_prediction(i, adjusted_scores, y_test.values, drug_names, k=k)
# Out:
# 實際給藥: ['Cefoperazone/sulbactam']
#
# 推薦藥物:
# 1. Flomoxef (Score: 0.6837)
# 2. Cefoperazone/sulbactam (Score: 0.3419)
# 3. Azithromycin (Score: 0.2462)
# 4. Cefixime (Score: 0.2455)
# 5. Piperacillin/Tazobactam (Score: 0.1538)
# ==================================================
# 實際給藥: ['Levofloxacin']
#
# 推薦藥物:
# 1. Flomoxef (Score: 0.4804)
# 2. Cefazolin (Score: 0.4362)
# 3. Ciprofloxacin (Score: 0.4067)
# 4. Cefuroxime (Score: 0.2950)
# 5. Piperacillin/Tazobactam (Score: 0.0862)
# ==================================================
# 實際給藥: ['Piperacillin/Tazobactam']
#
# 推薦藥物:
# 1. Piperacillin/Tazobactam (Score: 0.6308)
# 2. Cefoperazone/sulbactam (Score: 0.2944)
# 3. Azithromycin (Score: 0.2797)
# 4. Levofloxacin (Score: 0.2565)
# 5. Flomoxef (Score: 0.2022)
# ==================================================
# 實際給藥: ['Levofloxacin']
#
# 推薦藥物:
# 1. Cefoperazone/sulbactam (Score: 0.5054)
# 2. Flomoxef (Score: 0.4978)
# 3. Levofloxacin (Score: 0.3725)
# 4. Cefixime (Score: 0.2291)
# 5. Azithromycin (Score: 0.1816)
# ==================================================
# 實際給藥: ['Piperacillin/Tazobactam']
#
# 推薦藥物:
# 1. Piperacillin/Tazobactam (Score: 0.5694)
# 2. Cefoperazone/sulbactam (Score: 0.3475)
# 3. Flomoxef (Score: 0.2749)
# 4. Levofloxacin (Score: 0.2276)
# 5. Azithromycin (Score: 0.2061)
# ==================================================
# 實際給藥: ['Cefuroxime', 'Flomoxef']
#
# 推薦藥物:
# 1. Flomoxef (Score: 0.7300)
# 2. Cefuroxime (Score: 0.2050)
# 3. Cefixime (Score: 0.1951)
# 4. Ciprofloxacin (Score: 0.1559)
# 5. Piperacillin/Tazobactam (Score: 0.1479)
# ==================================================
# 實際給藥: ['Cefoperazone/sulbactam']
#
# 推薦藥物:
# 1. Amoxicillin/Clavulanic acid (Score: 0.4060)
# 2. Flomoxef (Score: 0.3716)
# 3. Cefoperazone/sulbactam (Score: 0.2686)
# 4. Azithromycin (Score: 0.2244)
# 5. Cefixime (Score: 0.1861)
# ==================================================
# 實際給藥: ['Cefoperazone/sulbactam']
#
# 推薦藥物:
# 1. Piperacillin/Tazobactam (Score: 0.5702)
# 2. Cefoperazone/sulbactam (Score: 0.5392)
# 3. Levofloxacin (Score: 0.2466)
# 4. Flomoxef (Score: 0.1694)
# 5. Ceftriaxone (Score: 0.1652)
# ==================================================
# 實際給藥: ['Amoxicillin/Clavulanic acid']
#
# 推薦藥物:
# 1. Amoxicillin/Clavulanic acid (Score: 0.7711)
# 2. Cefazolin (Score: 0.2309)
# 3. Ceftriaxone (Score: 0.1583)
# 4. Gentamicin (Score: 0.1549)
# 5. Azithromycin (Score: 0.0645)
# ==================================================
# 實際給藥: ['Amoxicillin/Clavulanic acid', 'Clindamycin']
#
# 推薦藥物:
# 1. Amoxicillin/Clavulanic acid (Score: 0.8233)
# 2. Clindamycin (Score: 0.3170)
# 3. Flomoxef (Score: 0.1232)
# 4. Cefoperazone/sulbactam (Score: 0.0946)
# 5. Ceftriaxone (Score: 0.0903)
# ==================================================

# %%
importance_all = []

for i, drug in enumerate(y_train.columns):
    
    model = multi_model.estimators_[i]
    
    # 建立 Series 並與特徵名稱對應
    imp = pd.Series(
        model.feature_importances_,
        index=X_train.columns
    )

    imp_df = imp.reset_index()
    imp_df.columns = ['feature','importance']
    # imp_df['drug'] = drug
    
    imp_df_sorted = imp_df.sort_values("importance", ascending=False)
    
    print(f"=== Drug: {drug} (Top 20 Features) ===")
    print(imp_df_sorted.head(20).to_string(index=False)) # 不印索引比較美觀
    print('\n')
    print(f"Top 20 importance sum: {imp_df_sorted.head(20)['importance'].sum().round(3)}")
    print("-" * 40)
    
    importance_all.append(imp_df_sorted)

importance_all = pd.concat(importance_all)
# Out:
# === Drug: Amoxicillin/Clavulanic acid (Top 20 Features) ===
#               feature  importance
#           O2 SAT_flag    0.160427
#        INFECTIONSITE5    0.128309
#        INFECTIONSITE2    0.060558
#        INFECTIONSITE3    0.054094
#                   AGE    0.046938
#        CARDIOVASCULAR    0.034702
#        INFECTIONSITE1    0.031287
#          BE(ecf)_flag    0.024944
# CHECKITEM30SCORE_flag    0.021772
#             PCO2_flag    0.021582
#               PT_flag    0.019444
#           INJURELEVEL    0.017784
#    Nitrite level_flag    0.017295
#        INFECTIONSITE9    0.016411
#             APTT_flag    0.016164
#      T.Bilirubin_flag    0.016116
#     CHECKITEM28A_flag    0.015825
# CHECKITEM28SCORE_flag    0.015790
#         VITALSIGNSGCS    0.015508
#  Leukocyte level_flag    0.014879
#
#
# Top 20 importance sum: 0.75
# ----------------------------------------
# === Drug: Ampicillin (Top 20 Features) ===
#              feature  importance
#                  AGE    0.203826
#         BE(ecf)_flag    0.106575
#           AUTOIMMUNE    0.063222
#      Neutrophil Seg.    0.045556
#           Creatinine    0.037506
#  Bacteria level_flag    0.033696
#   Nitrite level_flag    0.033509
#         VITALSIGNSBT    0.031965
#       CARDIOVASCULAR    0.027315
#                  CNS    0.026820
#          INJURELEVEL    0.025928
#          RESPIRATORY    0.022600
#            HCO3_flag    0.018607
#         VITALSIGNSRR    0.017842
#                  CRP    0.016929
# Leukocyte level_flag    0.016696
#         VITALSIGNSPR    0.016476
#                LIVER    0.015658
#       INFECTIONSITE4    0.015360
#       INFECTIONSITE2    0.014956
#
#
# Top 20 importance sum: 0.7910000085830688
# ----------------------------------------
# === Drug: Azithromycin (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE1    0.218398
#             APTT_flag    0.073660
#        INFECTIONSITE3    0.063277
#        INFECTIONSITE5    0.049763
#               PT_flag    0.047418
#        INFECTIONSITE2    0.047249
# CHECKITEM28SCORE_flag    0.022449
# CHECKITEM27SCORE_flag    0.019806
#                 FEVER    0.016008
#         VITALSIGNSGCS    0.015999
#                CANCER    0.014705
# CHECKITEM32SCORE_flag    0.013459
# CHECKITEM30SCORE_flag    0.013069
#        VITALSIGNSSPO2    0.012555
#        INFECTIONSITE9    0.011214
# CHECKITEM29SCORE_flag    0.011171
#           RESPIRATORY    0.010781
#      CHECKITEM27_flag    0.010557
#     CHECKITEM28A_flag    0.010045
#             PCO2_flag    0.009903
#
#
# Top 20 importance sum: 0.6909999847412109
# ----------------------------------------
# === Drug: Cefazolin (Top 20 Features) ===
#               feature  importance
#             APTT_flag    0.141164
#               PT_flag    0.114209
# CHECKITEM32SCORE_flag    0.077270
#      T.Bilirubin_flag    0.044124
# CHECKITEM29SCORE_flag    0.041015
#      CHECKITEM27_flag    0.031301
# CHECKITEM28SCORE_flag    0.030154
#              INR_flag    0.026304
#     CHECKITEM28A_flag    0.022532
#              HST_flag    0.022043
#           RESPIRATORY    0.018997
#             PCO2_flag    0.018674
#                   CRP    0.017669
#                 FEVER    0.016652
# CHECKITEM31SCORE_flag    0.015591
#        INFECTIONSITE4    0.015094
#        INFECTIONSITE2    0.014299
#                KIDNEY    0.012074
#           O2 SAT_flag    0.011452
#        CARDIOVASCULAR    0.010954
#
#
# Top 20 importance sum: 0.7020000219345093
# ----------------------------------------
# === Drug: Cefixime (Top 20 Features) ===
#                   feature  importance
#              BE(ecf)_flag    0.159005
#                 PCO2_flag    0.061791
#            INFECTIONSITE1    0.054657
#            INFECTIONSITE5    0.045776
#                   PT_flag    0.039063
#               INJURELEVEL    0.030081
#                 APTT_flag    0.029815
#                 HCO3_flag    0.028496
#            INFECTIONSITE3    0.017032
#        Nitrite level_flag    0.016761
#            INFECTIONSITE2    0.016411
#     CHECKITEM31SCORE_flag    0.014923
#       Bacteria level_flag    0.014427
#                       CRP    0.014305
#                       AGE    0.014264
#             VITALSIGNSGCS    0.014005
#      Leukocyte level_flag    0.013570
#                         K    0.012334
# Absolute Neutrophil count    0.012192
#            INFECTIONSITE9    0.011509
#
#
# Top 20 importance sum: 0.6200000047683716
# ----------------------------------------
# === Drug: Cefoperazone/sulbactam (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE1    0.114253
# CHECKITEM28SCORE_flag    0.070283
#        INFECTIONSITE3    0.043281
#     CHECKITEM28A_flag    0.038523
#             APTT_flag    0.030325
#        INFECTIONSITE5    0.026576
#  Leukocyte level_flag    0.026462
# CHECKITEM29SCORE_flag    0.025964
#               PT_flag    0.025951
#        INFECTIONSITE2    0.025309
#                   AGE    0.022435
#        INFECTIONSITE4    0.021132
#                 FEVER    0.019881
#   Bacteria level_flag    0.019878
# CHECKITEM32SCORE_flag    0.019484
#           O2 SAT_flag    0.015657
#    Nitrite level_flag    0.015193
#        VITALSIGNSSPO2    0.014969
#          VITALSIGNSBT    0.014142
#          BE(ecf)_flag    0.013451
#
#
# Top 20 importance sum: 0.6029999852180481
# ----------------------------------------
# === Drug: Ceftriaxone (Top 20 Features) ===
#                 feature  importance
#          INFECTIONSITE4    0.086830
#          INFECTIONSITE2    0.047374
#   CHECKITEM29SCORE_flag    0.032553
#     Bacteria level_flag    0.031202
#   CHECKITEM32SCORE_flag    0.025094
#                     AGE    0.024710
#          INFECTIONSITE5    0.024373
#                     SEX    0.023495
#          INFECTIONSITE1    0.023111
#        CHECKITEM27_flag    0.021986
#   CHECKITEM30SCORE_flag    0.021460
#      Nitrite level_flag    0.021130
#          INFECTIONSITE3    0.020215
#                   FEVER    0.019815
#   CHECKITEM27SCORE_flag    0.018909
#          CARDIOVASCULAR    0.018386
#          StayTime_hours    0.017793
#   CHECKITEM28SCORE_flag    0.016846
#              Creatinine    0.016327
# OTHERINFECTIONSITE_flag    0.015526
#
#
# Top 20 importance sum: 0.5270000100135803
# ----------------------------------------
# === Drug: Cefuroxime (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE1    0.102610
# CHECKITEM29SCORE_flag    0.060204
#        INFECTIONSITE3    0.045563
# CHECKITEM30SCORE_flag    0.039334
#        INFECTIONSITE5    0.028606
#             APTT_flag    0.028105
#        INFECTIONSITE2    0.027916
# CHECKITEM32SCORE_flag    0.027719
#                   CRP    0.021610
# CHECKITEM31SCORE_flag    0.018104
#          VITALSIGNSBT    0.017640
#           RESPIRATORY    0.016954
#        CARDIOVASCULAR    0.016684
#               PT_flag    0.016623
#              HST_flag    0.015276
#    Nitrite level_flag    0.015143
#                   CNS    0.015125
#            Lymphocyte    0.014772
#         VITALSIGNSDBP    0.014635
#             HCO3_flag    0.014238
#
#
# Top 20 importance sum: 0.5569999814033508
# ----------------------------------------
# === Drug: Ciprofloxacin (Top 20 Features) ===
#              feature  importance
#       INFECTIONSITE1    0.142726
#              PT_flag    0.051928
#            APTT_flag    0.046287
#       INFECTIONSITE3    0.038816
#            PCO2_flag    0.032488
#       INFECTIONSITE5    0.032399
#       INFECTIONSITE2    0.030948
#          O2 SAT_flag    0.025946
#             INR_flag    0.023380
#             HST_flag    0.022003
#                  AGE    0.021961
#       INFECTIONSITE9    0.020704
#          INJURELEVEL    0.019707
#                LIVER    0.016146
#                   Ht    0.015140
# Leukocyte level_flag    0.014460
#        VITALSIGNSGCS    0.013796
#  Bacteria level_flag    0.013567
#                  MAP    0.013052
#                  GPT    0.012516
#
#
# Top 20 importance sum: 0.6079999804496765
# ----------------------------------------
# === Drug: Clindamycin (Top 20 Features) ===
#              feature  importance
#       INFECTIONSITE5    0.272584
#       INFECTIONSITE3    0.051823
#       INFECTIONSITE2    0.041108
#            HCO3_flag    0.040869
#          INJURELEVEL    0.032975
#              PT_flag    0.029343
#            APTT_flag    0.028722
#          O2 SAT_flag    0.025358
#       INFECTIONSITE1    0.019987
#  Bacteria level_flag    0.019640
#       INFECTIONSITE9    0.019244
#        VITALSIGNSGCS    0.018275
#            PCO2_flag    0.017243
#         BE(ecf)_flag    0.013999
#                LIVER    0.013786
# Leukocyte level_flag    0.012840
#             HST_flag    0.012720
#    CHECKITEM28A_flag    0.012043
#                FEVER    0.011858
#     T.Bilirubin_flag    0.011629
#
#
# Top 20 importance sum: 0.7059999704360962
# ----------------------------------------
# === Drug: Flomoxef (Top 20 Features) ===
#                 feature  importance
#          INFECTIONSITE2    0.236311
#          INFECTIONSITE5    0.061568
#                     AGE    0.032101
#          INFECTIONSITE4    0.031275
#          CARDIOVASCULAR    0.022352
#          INFECTIONSITE3    0.021174
#             O2 SAT_flag    0.019687
#   CHECKITEM28SCORE_flag    0.019141
#                     CRP    0.018531
#      Nitrite level_flag    0.017878
#          INFECTIONSITE1    0.017549
#        T.Bilirubin_flag    0.015684
#                HST_flag    0.014405
#           VITALSIGNSGCS    0.014272
#              Creatinine    0.013884
#               HCO3_flag    0.013687
# OTHERINFECTIONSITE_flag    0.013427
#   CHECKITEM31SCORE_flag    0.013192
#                      DM    0.012713
#             INJURELEVEL    0.012350
#
#
# Top 20 importance sum: 0.6209999918937683
# ----------------------------------------
# === Drug: Gentamicin (Top 20 Features) ===
#               feature  importance
#               PT_flag    0.070981
#             PCO2_flag    0.069915
#        CARDIOVASCULAR    0.063141
# CHECKITEM32SCORE_flag    0.044454
#        INFECTIONSITE4    0.043891
#              HST_flag    0.042334
#                   AGE    0.041251
#      T.Bilirubin_flag    0.039196
#           RESPIRATORY    0.033604
#            AUTOIMMUNE    0.032712
#             APTT_flag    0.031878
#        INFECTIONSITE2    0.029742
#          BE(ecf)_flag    0.028965
#    Nitrite level_flag    0.020815
#        INFECTIONSITE3    0.018212
#                   CNS    0.016851
#         VITALSIGNSGCS    0.016114
#            Creatinine    0.014550
#           INJURELEVEL    0.014319
#           O2 SAT_flag    0.014128
#
#
# Top 20 importance sum: 0.6869999766349792
# ----------------------------------------
# === Drug: Levofloxacin (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE2    0.119169
#        INFECTIONSITE1    0.072110
# CHECKITEM30SCORE_flag    0.068479
# CHECKITEM28SCORE_flag    0.043033
#        INFECTIONSITE5    0.042610
#             APTT_flag    0.023214
#    Nitrite level_flag    0.021695
#        INFECTIONSITE3    0.020453
#         VITALSIGNSGCS    0.019085
#               PT_flag    0.018990
#            Creatinine    0.017392
#                   AGE    0.015900
#                   CNS    0.015857
#                   CRP    0.014244
#        INFECTIONSITE9    0.014146
#         VITALSIGNSDBP    0.013552
#                 FEVER    0.013458
# CHECKITEM29SCORE_flag    0.013450
#      T.Bilirubin_flag    0.013284
#                 LIVER    0.013024
#
#
# Top 20 importance sum: 0.5929999947547913
# ----------------------------------------
# === Drug: Metronidazole (Top 20 Features) ===
#               feature  importance
#        INFECTIONSITE2    0.352276
#        INFECTIONSITE1    0.042334
#               PT_flag    0.030070
#             APTT_flag    0.025521
#              HST_flag    0.019684
# CHECKITEM27SCORE_flag    0.016441
#                   CRP    0.015670
#      T.Bilirubin_flag    0.015227
# CHECKITEM32SCORE_flag    0.015225
#          BE(ecf)_flag    0.013884
# CHECKITEM29SCORE_flag    0.013356
# CHECKITEM28SCORE_flag    0.013095
#           O2 SAT_flag    0.012926
#                    Ht    0.012339
#              INR_flag    0.011767
#        CARDIOVASCULAR    0.011568
#           RESPIRATORY    0.011407
#            AUTOIMMUNE    0.011130
#        INFECTIONSITE3    0.010931
#         VITALSIGNSGCS    0.010465
#
#
# Top 20 importance sum: 0.6650000214576721
# ----------------------------------------
# === Drug: Piperacillin/Tazobactam (Top 20 Features) ===
#                   feature  importance
#                 PCO2_flag    0.071312
#               INJURELEVEL    0.055391
#                 HCO3_flag    0.048081
#                       CRP    0.039552
#            INFECTIONSITE1    0.033289
#                  INR_flag    0.032653
#             VITALSIGNSGCS    0.031402
#          T.Bilirubin_flag    0.031206
#            INFECTIONSITE2    0.023639
#                   PT_flag    0.021769
#              BE(ecf)_flag    0.021610
#     CHECKITEM28SCORE_flag    0.020210
#                       AGE    0.019654
#     CHECKITEM29SCORE_flag    0.019341
#     CHECKITEM31SCORE_flag    0.018788
# Absolute Neutrophil count    0.018121
#                    CANCER    0.016008
#                        DM    0.015120
#            CARDIOVASCULAR    0.015044
#                       WBC    0.014395
#
#
# Top 20 importance sum: 0.5669999718666077
# ----------------------------------------

# %%
importance_summary = importance_all.groupby('feature')['importance'].mean().sort_values(ascending=False)

print(importance_summary.head(20))
# Out:
# feature
# INFECTIONSITE2           0.072484
# INFECTIONSITE1           0.059931
# INFECTIONSITE5           0.050480
# PT_flag                  0.034377
# APTT_flag                0.033961
# AGE                      0.032918
# INFECTIONSITE3           0.029144
# BE(ecf)_flag             0.029034
# PCO2_flag                0.025211
# O2 SAT_flag              0.023280
# CHECKITEM28SCORE_flag    0.019555
# CHECKITEM32SCORE_flag    0.019060
# INJURELEVEL              0.018719
# CARDIOVASCULAR           0.018706
# INFECTIONSITE4           0.018626
# CHECKITEM29SCORE_flag    0.017527
# T.Bilirubin_flag         0.016899
# HCO3_flag                0.016572
# CHECKITEM30SCORE_flag    0.016459
# AUTOIMMUNE               0.015721
# Name: importance, dtype: float32

# %%
importance_summary = importance_all.groupby('feature')['importance'].median().sort_values(ascending=False)

print(importance_summary.head(20))
# Out:
# feature
# INFECTIONSITE1           0.033289
# INFECTIONSITE2           0.030948
# INFECTIONSITE5           0.028606
# APTT_flag                0.028105
# PT_flag                  0.025951
# INFECTIONSITE3           0.020453
# AGE                      0.019654
# CHECKITEM28SCORE_flag    0.015790
# Nitrite level_flag       0.015193
# CRP                      0.014244
# VITALSIGNSGCS            0.014120
# PCO2_flag                0.013805
# BE(ecf)_flag             0.013451
# CHECKITEM32SCORE_flag    0.012955
# INJURELEVEL              0.012856
# T.Bilirubin_flag         0.012756
# Creatinine               0.012640
# CARDIOVASCULAR           0.012351
# HST_flag                 0.012011
# Leukocyte level_flag     0.011966
# Name: importance, dtype: float32

# %% [raw]
# MI

# %%
from sklearn.feature_selection import mutual_info_classif
import pandas as pd

# 挑選你想診斷的藥物
target_drug = 'Levofloxacin' #  , 'Cephalexin', 'Cefadroxil'

# 計算 MI
# discrete_features: 如果你的特徵有類別型（如部位），要標註 True
mi_scores = mutual_info_classif(X_train, y_train[target_drug], discrete_features='auto', random_state=123)

# 整理成 DataFrame
mi_df = pd.DataFrame({'feature': X_train.columns, 'mi_score': mi_scores})
mi_df = mi_df.sort_values(by='mi_score', ascending=False)

print(f"=== {target_drug} 的特徵資訊量排行 ===")
print(mi_df.head(10))
# Out:
# === Levofloxacin 的特徵資訊量排行 ===
#                   feature  mi_score
# 22         INFECTIONSITE2  0.016126
# 7          INFECTIONSITE1  0.010844
# 45  CHECKITEM29SCORE_flag  0.007720
# 51              APTT_flag  0.006856
# 44                PH_flag  0.006291
# 61  CHECKITEM32SCORE_flag  0.005913
# 59  CHECKITEM28SCORE_flag  0.005896
# 3          StayTime_hours  0.005285
# 56      CHECKITEM28A_flag  0.005258
# 13          VITALSIGNSGCS  0.004987

# %% [raw]
# specail case

# %%
specail = X_test.index.get_loc(11711)

# %%
show_top3_prediction(specail, adjusted_scores, y_test.values, drug_names, k=5)
# Out:
# 實際給藥: ['Levofloxacin']
#
# 推薦藥物:
# 1. Flomoxef (Score: 0.4804)
# 2. Cefazolin (Score: 0.4362)
# 3. Ciprofloxacin (Score: 0.4067)
# 4. Cefuroxime (Score: 0.2950)
# 5. Piperacillin/Tazobactam (Score: 0.0862)
# ==================================================
