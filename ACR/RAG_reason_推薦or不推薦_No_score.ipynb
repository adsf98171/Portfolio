# %%
import json
import re
from pathlib import Path
from langchain_core.documents import Document
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings # pip install sentence-transformers
from langchain_classic.chains import RetrievalQA
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser
# from langchain_groq import ChatGroq
from openai import AzureOpenAI

import torch.nn.functional as F
from torch import Tensor
from transformers import AutoTokenizer, AutoModel

from concurrent.futures import ThreadPoolExecutor
# Out:
# WARNING:tensorflow:From C:\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
api_key = 'xxx'
endpoint = 'ooo'
deployment = 'gpt-4o'
api_version='2024-12-01-preview'

client = AzureOpenAI(
    api_key = api_key,
    azure_endpoint = endpoint,
    api_version = api_version
)

# %%
def normalize_medical_note(raw_text: str) -> str:
    """
    Normalize (+)/(-) polarity without medical interpretation.
    """
    normalized_lines = []

    for line in raw_text.splitlines():
        line = line.strip()
        if not line:
            continue

        # Replace (+) and (-) with explicit polarity
        # line = re.sub(r"\(\+\)", ": Yes", line)
        # line = re.sub(r"\(-\)", ": No", line)

        line = re.sub(r"([a-zA-Z0-9_]+)\s*\(\+\)", r"Yes \1", line)
        line = re.sub(r"([a-zA-Z0-9_]+)\s*\(-\)", r"No \1", line)

        normalized_lines.append(line)

    return "\n".join(normalized_lines)

# %%
def summarize(raw_text: str):
    prompt = f"""
    
Task:
From the following outpatient clinical note, extract ONLY information relevant to medical imaging decision-making.

Focus on clinical features that may influence whether imaging is indicated and which type of imaging may be appropriate.

Rules:

Ignore laboratory values unless they directly indicate infection, inflammation, bleeding risk, or other conditions that could influence imaging decisions.

Ignore purely administrative, social, psychiatric, or medication details unless they suggest:
• acute neurologic change
• structural disease
• trauma
• infection
• malignancy
• postoperative complications

Include only information that may affect imaging decisions, such as:

• Key symptoms (e.g., pain, neurologic deficit, trauma, mass, fever, focal deficits)
• Symptom onset and progression
• Relevant medical history (e.g., malignancy, trauma, surgery, infection)
• Physical examination findings related to possible structural pathology
• Red-flag symptoms (remark: Red flag are specific symptoms or physical signs used in clinical medicine to indicate the possible presence of serious or potentially life-threatening diseases, requiring doctors to pay high attention and prioritize investigation.)
• Any explicit or implicit indication that imaging may be required

Diagnostic Language Interpretation Rules:

When interpreting diagnostic phrases in radiology or clinical notes, strictly distinguish the following categories:

1. Confirmed disease
   Terms: "confirmed", "proven", "diagnosed"
   → Record as confirmed pathology.

2. Suspected disease
   Terms: "suspicious for", "highly suggestive of", "likely"
   → Record as suspected pathology.

3. Possible disease
   Terms: "possible", "cannot exclude", "may represent"
   → Record as possible pathology.

4. Rule-out consideration
   Terms: "rule out", "should be ruled out", "to exclude"
   → Do NOT convert to suspected disease.
   → Record only as "diagnostic consideration", not as suspected pathology.

Note:
1. Do NOT add interpretations, diagnoses, or facts that are not present in the clinical note.
2. All summaries must strictly reflect the source text.
3. Use concise bullet points.


Importance:

1. Track the chronological order of events if dates are present.
2. Track each symptom longitudinally across dates.
3. Expand medical abbreviations into full medical terminology when possible.
4. Internally track symptom resolution or persistence using the latest dated entry.
5. Only output the final structured result (do not output reasoning steps).


Special Case Handling:

Step 1:
If prior imaging has already revealed a structural lesion, tumor suspicion, fracture, or other significant abnormality, prioritize lesion-related clinical scenarios rather than symptom-based scenarios.

Step 2:
If surgery, radiation therapy, or other major treatment has been performed:

• If the treatment occurred within the past 6 months → treat this as follow-up imaging context
• If more than 6 months → evaluate based primarily on current symptoms


Clinical note:
{raw_text}


Output Format:

Sex:
Age:


History (chronological):
- YYYY/MM/DD: symptom or clinical event
- ...

Pathology:
-confirmed_pathology:
-suspected_pathology:
-differential_diagnosis:

Current Symptoms Status:
- remaining:
- improving/resolving:
- resolved:


Potential Imaging Indicators (based only on remaining symptoms):
- 
- 


Summary:
age_group: child / adult / elderly

primary_clinical_presentation:
(e.g., headache, abdominal pain, trauma, focal neurologic deficit, joint pain, suspected infection)

suspected_pathology_category:
(neurologic / musculoskeletal / abdominal / thoracic / oncologic / infectious / traumatic / unclear)

inflammatory_or_infectious_process:
True / False / Unclear

clinical_phase:
initial evaluation / follow-up / surveillance / unclear

red_flag_present:
True / False

imaging_decision_context:
(symptom-based / post-treatment / suspected malignancy / trauma / infection)
"""

    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(model=deployment, messages=messages, temperature=0.1, top_p=0.9, max_tokens=800)
    return response.choices[0].message.content.strip()

# %%
def structured_to_acr_indication(structured_case: str):
    prompt = f"""

Task
Convert the structured clinical case into a **single-line ACR-style imaging indication** suitable for radiology guideline retrieval.

Output Requirements

* Produce **one single sentence only**.
* Use **clear radiology clinical language similar to ACR Appropriateness Criteria indications**.
* The sentence must prioritize the **primary clinical problem** first.

Content Rules

1. Core Structure
   Follow this structure whenever possible:

[age]-year-old [sex] with [primary clinical problem] ± [key modifiers]. [Imaging stage].

Example structures:

* "65-year-old male with acute headache and neurologic deficit. Initial imaging."
* "34-year-old female with chronic low back pain and radiculopathy, failed conservative therapy. Imaging evaluation."
* "80-year-old female with new-onset headache and abnormal electroencephalogram suggesting possible structural lesion. Initial imaging."

2. Preserve Important Clinical Information
   Retain the following when present:

* Age and sex
* Primary symptom or chief complaint
* Key associated symptoms
* Known or suspected pathology (trauma, infection, tumor, hemorrhage, etc.)
* Disease progression (e.g., worsening, increasing severity)
* Imaging stage (initial imaging, follow-up imaging, post-treatment evaluation)

3. Red Flags
   If any of the following are present, incorporate them naturally into the sentence:

* neurologic deficit
* fever
* cancer history
* immunocompromise
* trauma
* new onset in older patient (>50 years)
* rapidly worsening symptoms

Do NOT explicitly write the phrase "red flag"; instead integrate the clinical finding.

4. Clinical Course
   Preserve information about:

* acute vs chronic
* failed conservative therapy
* recurrence
* post-treatment status

5. Symptoms

* Keep **active symptoms only**
* If a symptom was previously present but resolved, append "(resolved)"

6. Medical Terminology

* Expand abbreviations into full clinical terminology.
* Prefer formal medical language used in radiology indications.

7. Do NOT Include

* Dates
* Administrative metadata
* Feature-engineering variables (e.g., age_group, inflammatory=True)

Structured case:
{structured_case}

Output:
(one single sentence only)
"""

    messages = [{"role": "user", "content": prompt}]
    response = client.chat.completions.create(
        model=deployment,
        messages=messages,
        temperature=0.1,
        top_p=0.9,
        max_tokens=500
    )
    return response.choices[0].message.content.strip()

# %%
def reason_filter(patient_summary: str, variant_text: str):
    prompt = f"""

你現在是一位需要評估患者病歷與 ACR Variant 適合度的專業專科醫師，
僅討論病人本身的情況，判斷每組病例與 variant 之間是否「適合 / 不適合」，並提供主要理由。

Patient case:
{patient_summary}

Variant description:
{variant_text}


Task:

Step 1. Extract the key clinical findings from the patient case.

Include:
- primary symptom
- important associated findings
- known etiology or pathology
- red flags
- imaging phase (initial vs follow-up)

If a category is not mentioned in the case, write "None".

注意：
若病例中的問題已標記為 resolved，則不納入判斷。


Step 2. Identify the key clinical condition or diagnostic scenario targeted by the variant.

Summarize the diagnostic focus of the variant in **one short sentence**.


Step 3. Compare the patient case with the variant scenario.

List:

A. Matching findings  
Findings from the patient that directly support the variant indication.

B. Missing required findings  
Conditions explicitly required by the variant but not present in the case.

C. Conflicting findings  
A contradiction indicates that the variant's information contradicts the information in the medical record. 
If the variant does not mention the relevant context, it should be considered 'Missing required findings'.

Rules:
- Only use information explicitly stated in the patient case.
- Do NOT assume or infer missing symptoms.
- red_flag_present 並不等於 cancer、infection 或 immunosuppression，只有病例明確描述這些疾病或危險因子時才算符合。
- The red flag in variants doesn't need to match all of them; it's enough if the case mentions just one.
- Take care about age group in patient case and variant.


Step 4. Clinical judgment

Determine whether this variant is appropriate for the patient.

Decision rules:

1. Variant中若包含特定疾病或條件（例如 cancer、infection、immunosuppression、trauma、stroke、drug exposure 等），
   病例中必須明確提及該疾病或合理懷疑，否則判定為不適合。

2. 若variant包含特定評分或指標（例如 GCS、clinical decision rule 等），
   病例沒有提供相關資訊時，直接判定為不適合。

3. 若該variant有"suspicion of cancer, infection, or immunosuppression"，
   病例必須明確提到其中之一，否則即使其他症狀符合，也判定為不適合。

4. 承3.，反之，若病例有提及某些症狀與感染等醫學描述，但該variate沒有提到，仍可以判為適合。

5. 若該variant有"One or more of the following:"，則該病例必須滿足至少一項的描述，才可以被判為適合。

6. 承5.，若該variant已滿足該病例至少一項描述，則可以判為適合。

7. 承5.，若該variant有"without any of the following"，則該病例不能有任何符合的描述，否則判為不適合。

8. 每個variant的子句中，若以or連接各描述，僅需符合其中一個描述，該子句就被滿足；若以and連接各描述，需全部符合所有描述，該子句才被滿足。

9. red_flag_present 並不等於 cancer、infection 或 immunosuppression。只有病例明確描述這些疾病或相關危險因子時才算符合。

10. 若病例中的問題已標記為 resolved，則不納入判斷。

11. 若variant內容與病例的主要疾病、症狀或病程一致，但僅有 "initial imaging / follow-up imaging" 不完全一致，仍判為適合。

12. 若 patient_summary 提到 red-flag，但 variant 指出 No red flag（或反之），則判為不適合。

13. 若該病例有提供不同部位的詳細描述(例如:一個人同時有胸椎和腰椎的問題)，則該variant不用同時包含兩者的描述，只要其中一個滿足以上規則即可。

14. 「主要理由」優先討論順序：
     疾病 → 病因 → 症狀 → red flag → imaging phase。

15. Key Word:主要理由中，該variant與patient case相同的關鍵字，但"關鍵字"僅限症狀或疾病等醫學相關名詞(以patient case的原文輸出)。

16. 承12.13.，主要理由和Key Word盡量不要只有Headache、Low back pain、red flag等topic等級的描述，可以多一點病例與該variant都相符的細節。


Output must be concise and written in Chinese.


Output format:


發現:
A. Matching findings:
B. Missing required findings: 
C. Conflicting findings:

病例關鍵資訊:
- primary symptom:
- associated findings:
- etiology/pathology:
- red flags:
- imaging phase:

**綜合評估: 適合 / 不適合**

主要理由:
(一句話，優先順序：疾病 → 病因 → 症狀 → red flag → imaging phase)

Key Word:
"""
    messages = [
        {"role": "system", "content": prompt},
        {"role": "user", "content": "請根據上面的病例給出 variant 建議。"}
    ]

    response = client.chat.completions.create(
        model=deployment,
        messages=messages,
        temperature=0.1,
        top_p=0.9,
        max_tokens=3000
    )

    return response.choices[0].message.content.strip()

# %%
def process_reason_filter(args):
    """封裝單次的 API 呼叫與錯誤處理"""
    i, doc, query_acr_style = args
    variant_text = doc.page_content
    
    try:
        # 執行原本的 reason_filter
        reason_output = reason_filter(
            patient_summary=query_acr_style,
            variant_text=variant_text
        )
        return {
            "index": i,
            "content": variant_text,
            "reason": reason_output,
            "success": True
        }
    except Exception as e:
        return {
            "index": i,
            "content": variant_text,
            "reason": f"[錯誤] reason_filter 失敗：{e}",
            "success": False
        }

# %%
# 載入 ACR variants

with open(r'C:\Users\482525\Work_File\放射科RAG_model\acr_all_variants.json', 'r', encoding='utf-8') as f:
    acr_data = json.load(f)

documents = []

for item in acr_data:
    if isinstance(item, dict) and 'variant_description' in item:

        procedures_text = "\n".join(
            [f"{p['category']}: {p['procedure']}" 
             for p in item.get('procedures', [])]
        )

        full_text = f"""
Topic: {item.get('topic', '')}

Variant:
{item['variant_description']}

Recommended Procedures:
{procedures_text}
"""

        doc = Document(
            page_content=full_text,
            metadata={
                "topic": item.get('topic', '')
            }
        )

        documents.append(doc)

print(f"載入 {len(documents)} 個 variants")
# Out:
# 載入 1278 個 variants

# %%
# Embedding + FAISS
# 選項 A: bge-m3、B: nomic-embed-text-v1.5

local_model_path = r"C:\Users\482525\Desktop\bge-m3-local" # bge-m3-local / sentence-bert-base_local

embeddings = HuggingFaceEmbeddings(
    model_name=local_model_path,               
    model_kwargs={'device': 'cpu'},  # cuda
    encode_kwargs={'normalize_embeddings': True} 
)

# 儲存 index，下次直接載入
# vectorstore = FAISS.from_documents(documents, embeddings)
# vectorstore.save_local(r"C:\Users\482525\Work_File\embedding_model\faiss_acr_index2")
vectorstore = FAISS.load_local(r"C:\Users\482525\Work_File\embedding_model\faiss_acr_index_adapt", embeddings, allow_dangerous_deserialization=True)
# Out:
# C:\Users\482525\AppData\Local\Temp\ipykernel_13684\1142802330.py:6: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(

# %%
# query_file_path = Path(r'C:\Users\482525\Desktop\SOA_病例_新竹\test_headache\病歷號碼 0024841249.txt'.strip('\u202a')) # utf-8
query_file_path = Path(r'‪C:\Users\482525\Desktop\SOA_病例_新竹\test_low_back_pain\病歷號碼 0020487669.txt'.strip('\u202a'))

with open(query_file_path, 'r', encoding='utf-8') as f:
    query = f.read().strip()  # 去掉前後的換行或空白

print(f"--- Query 內容 ---")
# print(query)
print("-" * 30)
    
raw = query
raw = normalize_medical_note(raw)
structured_case = summarize(raw)
print(structured_case)
# Out:
# --- Query 內容 ---
# ------------------------------
# Sex: M
# Age: 92
#
# ---
#
# History (chronological):
# - 2025/04/09: Severe low back pain on and off for weeks, trauma suspected. Failed NSAID therapy at local medical doctor. History of pacemaker implantation 10+ years ago.
#
# ---
#
# Pathology:
# - confirmed_pathology: Wedge deformity at vertebral body of L2.
# - suspected_pathology: Acute vertebral compression fracture at L2.
# - differential_diagnosis: None explicitly mentioned.
#
# ---
#
# Current Symptoms Status:
# - remaining: Severe low back pain (VAS 9/10), local tenderness at lumbosacral junction.
# - improving/resolving: None noted.
# - resolved: None noted.
#
# ---
#
# Potential Imaging Indicators (based only on remaining symptoms):
# - Severe low back pain with intractable nature.
# - Local tenderness at lumbosacral junction.
# - Suspected acute vertebral compression fracture at L2.
#
# ---
#
# Summary:
# age_group: elderly
#
# primary_clinical_presentation: severe low back pain with suspected trauma
#
# suspected_pathology_category: musculoskeletal
#
# inflammatory_or_infectious_process: False
#
# clinical_phase: initial evaluation
#
# red_flag_present: True
#
# imaging_decision_context: trauma

# %%
query_acr_style = structured_to_acr_indication(structured_case)
print(query_acr_style)
# Out:
# "92-year-old male with severe low back pain, local tenderness, and suspected acute vertebral compression fracture at L2 following trauma. Initial imaging."

# %%
structured_case = '''
**Sex:**  
Male  

**Age:**  
82  

---

### History (chronological):  
- **2013/08/26:** Post right L3-4 posterior fusion surgery.  
- **2025/04/25:** Low back pain off and on for 6 months; walking disturbance with left leg weakness.  
- **2025/05/13:** Right peroneal nerve conduction velocity test (43.4 m/s).  
- **2025/05/23:** Patient refused admission despite aneurysmal dilatation of abdominal aorta with mural thrombus formation.  

---

### Pathology:  

**Confirmed Pathology:**  
- Status post L3-4 posterior fusion surgery.  
- Marked scoliosis of thoracic and lumbar spine.  
- Retrolisthesis at L2-3 and L5-S1.  
- Annular bulging discs at L1-2, L2-3, L4-5, and L5-S1.  
- Bilateral neuroforaminal encroachment at L1-2 and L2-3.  
- Bilateral neuroforaminal narrowing at L4-5.  
- Right neuroforaminal narrowing at L5-S1.  
- Mixed Modic type I and II endplate degeneration of L1, L2, L4, and L5 vertebral bodies.  
- Aneurysmal dilatation of abdominal aorta with mural thrombus formation.  

**Suspected Pathology:**  
None explicitly stated.  

**Differential Diagnosis:**  
None explicitly stated.  

---

### Structural Abnormalities:  
- Marked scoliosis of thoracic and lumbar spine.  
- Retrolisthesis at L2-3 and L5-S1.  
- Annular bulging discs at L1-2, L2-3, L4-5, and L5-S1.  
- Bilateral neuroforaminal encroachment at L1-2 and L2-3.  
- Bilateral neuroforaminal narrowing at L4-5.  
- Right neuroforaminal narrowing at L5-S1.  
- Mixed Modic type I and II endplate degeneration of L1, L2, L4, and L5 vertebral bodies.  
- Status post L3-4 posterior fusion surgery.  
- Aneurysmal dilatation of abdominal aorta with mural thrombus formation.  

---

### Prior Imaging Findings:  
- **2025/05/13:** Right peroneal nerve conduction velocity test (43.4 m/s).  
- **2025/05/23:** Thoracolumbar spine MRI:  
  - Annular bulging discs at L1-2, L2-3, L4-5, and L5-S1.  
  - Bilateral neuroforaminal encroachment at L1-2 and L2-3.  
  - Bilateral neuroforaminal narrowing at L4-5.  
  - Right neuroforaminal narrowing at L5-S1.  
  - Mixed Modic type I and II endplate degeneration of L1, L2, L4, and L5 vertebral bodies.  
  - Status post L3-4 posterior fusion surgery.  
  - Aneurysmal dilatation of abdominal aorta with mural thrombus formation.  

---

### Current Symptoms Status:  

**Remaining:**  
- Low back pain off and on for 6 months.  
- Walking disturbance with left leg weakness.  

**Improving/Resolving:**  
None explicitly stated.  

**Resolved:**  
None explicitly stated.  

---

### Potential Imaging Indicators:  
- Persistent low back pain for 6 months.  
- Walking disturbance with left leg weakness.  
- Structural abnormalities including scoliosis, retrolisthesis, annular bulging discs, neuroforaminal encroachment/narrowing, and Modic changes.  
- Aneurysmal dilatation of abdominal aorta with mural thrombus formation.  

---

### Summary:  

**Age Group:**  
Elderly  

**Primary Clinical Presentation:**  
Low back pain, walking disturbance, left leg weakness.  

**Suspected Pathology Category:**  
Musculoskeletal and vascular.  

**Anatomical Region:**  
Lumbar spine, thoracic spine, abdomen.  

**Inflammatory or Infectious Process:**  
Unclear.  

**Clinical Phase:**  
Follow-up.  

**Red Flag Present:**  
True (persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta).  

**Imaging Decision Context:**  
Symptom-based and post-treatment.

'''
query_acr_style = '''
82-year-old male with persistent low back pain, walking disturbance, and left leg weakness, marked scoliosis of thoracic and lumbar spine, retrolisthesis at L2-3 and L5-S1, annular bulging discs, bilateral neuroforaminal encroachment and narrowing, Modic endplate changes, and aneurysmal dilatation of abdominal aorta with mural thrombus, follow-up imaging evaluation.
'''

# %%
k = 50
docs = vectorstore.similarity_search(query_acr_style, k=k)

# print(f"\nTop {k} 配對的 variants (搜尋來源: {query_file_path.name})：")
# for i, doc in enumerate(docs, 1):
#     print(f"{i}. {doc.page_content}")
#     # print("  Procedures 數量:", len(doc.metadata.get('procedures', [])))
#     print("-" * 50)

# %%
docs_and_scores = vectorstore.similarity_search_with_score(query_acr_style, k=k)

for i, (doc, score) in enumerate(docs_and_scores, 1):
    print(f"{i}. 相似度: {score:.4f}")
    # print(f"內容摘要: {doc.page_content}...")
# Out:
# 1. 相似度: 0.6866
# 2. 相似度: 0.6956
# 3. 相似度: 0.7040
# 4. 相似度: 0.7154
# 5. 相似度: 0.7172
# 6. 相似度: 0.7197
# 7. 相似度: 0.7288
# 8. 相似度: 0.7289
# 9. 相似度: 0.7399
# 10. 相似度: 0.7456
# 11. 相似度: 0.7487
# 12. 相似度: 0.7497
# 13. 相似度: 0.7541
# 14. 相似度: 0.7725
# 15. 相似度: 0.7766
# 16. 相似度: 0.7826
# 17. 相似度: 0.7876
# 18. 相似度: 0.7879
# 19. 相似度: 0.7879
# 20. 相似度: 0.7934
# 21. 相似度: 0.7952
# 22. 相似度: 0.7967
# 23. 相似度: 0.7970
# 24. 相似度: 0.8008
# 25. 相似度: 0.8018
# 26. 相似度: 0.8024
# 27. 相似度: 0.8079
# 28. 相似度: 0.8081
# 29. 相似度: 0.8087
# 30. 相似度: 0.8114
# 31. 相似度: 0.8142
# 32. 相似度: 0.8158
# 33. 相似度: 0.8167
# 34. 相似度: 0.8175
# 35. 相似度: 0.8191
# 36. 相似度: 0.8213
# 37. 相似度: 0.8221
# 38. 相似度: 0.8241
# 39. 相似度: 0.8246
# 40. 相似度: 0.8251
# 41. 相似度: 0.8256
# 42. 相似度: 0.8258
# 43. 相似度: 0.8260
# 44. 相似度: 0.8263
# 45. 相似度: 0.8276
# 46. 相似度: 0.8286
# 47. 相似度: 0.8296
# 48. 相似度: 0.8296
# 49. 相似度: 0.8307
# 50. 相似度: 0.8332

# %%
patient_summary=structured_case
variant_text = doc.page_content

# 設定平行數量 (k)，建議 5-10
k = 20
tasks = [(i, doc, structured_case) for i, doc in enumerate(docs, 1)]

with ThreadPoolExecutor(max_workers=k) as executor:
    results = list(executor.map(process_reason_filter, tasks))
    
for res in results:
    print(f"Variate {res['index']}: {res['content']}")
    print("\n--- Filter Reason ---")
    print(res['reason'])
    print("=" * 80)
# Out:
# Variate 1:
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain without or with myelopathy or radiculopathy. One or more of the following: low-velocity trauma, osteoporosis, elderly individual, or chronic steroid use. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography thoracic spine
# Usually Appropriate: MRI thoracic spine without IV contrast
# Usually Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: MRI thoracic spine without and with IV contrast
# May Be Appropriate: Bone scan whole body
# May Be Appropriate: Bone scan with SPECT or SPECT/CT thoracic spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Elderly individual (82歲)。
# - Thoracic back pain (病例中有 thoracic spine scoliosis 和 Modic degeneration)。
# - Red flag (aneurysmal dilatation of abdominal aorta with mural thrombus formation)。
#
# B. Missing required findings:
# - None.
#
# C. Conflicting findings:
# - Imaging phase: 病例為 follow-up，但 variant 為 initial imaging。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain。
# - associated findings: Walking disturbance with left leg weakness, thoracic and lumbar scoliosis, Modic degeneration, neuroforaminal narrowing, aneurysmal dilatation of abdominal aorta。
# - etiology/pathology: Degenerative spine changes, aneurysmal dilatation of abdominal aorta。
# - red flags: Aneurysmal dilatation of abdominal aorta with mural thrombus formation。
# - imaging phase: Follow-up。
#
# **綜合評估: 適合**
#
# 主要理由: 病例中 thoracic spine 的結構異常（scoliosis 和 Modic degeneration）與 variant 的 thoracic back pain 描述一致。
#
# Key Word: Thoracic spine scoliosis, Modic degeneration
# ================================================================================
# Variate 2:
# Topic: Low Back Pain
#
# Variant:
# Low back pain with or without radiculopathy. One or more of the following: low- velocity trauma, osteoporosis, elderly individual, or chronic steroid use. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography lumbar spine
# Usually Appropriate: MRI lumbar spine without IV contrast
# Usually Appropriate: CT lumbar spine without IV contrast
# May Be Appropriate: MRI lumbar spine without and with IV contrast
# May Be Appropriate: CT myelography lumbar spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Low back pain with or without radiculopathy.
# - Elderly individual.
# - Persistent low back pain for 6 months.
# - Walking disturbance with left leg weakness.
# - Structural abnormalities including scoliosis, retrolisthesis, annular bulging discs, neuroforaminal encroachment/narrowing, and Modic changes.
#
# B. Missing required findings:
# None.
#
# C. Conflicting findings:
# None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance, left leg weakness, structural abnormalities (e.g., scoliosis, retrolisthesis, neuroforaminal narrowing).
# - etiology/pathology: Degenerative spine changes, aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 適合**
#
# 主要理由:
# 該病例符合「Low back pain with or without radiculopathy」的描述，且患者為高齡者並伴有結構性脊柱異常及神經症狀。
#
# Key Word:
# Low back pain, radiculopathy, elderly individual, structural abnormalities.
# ================================================================================
# Variate 3:
# Topic: Low Back Pain
#
# Variant:
# Subacute or chronic low back pain with or without radiculopathy. Surgery or intervention candidate with persistent or progressive symptoms during or following 6 weeks of optimal medical management. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI lumbar spine without IV contrast
# May Be Appropriate: Radiography lumbar spine
# May Be Appropriate: MRI lumbar spine without and with IV contrast
# May Be Appropriate: Bone scan whole body with SPECT or SPECT/CT complete spine
# May Be Appropriate: CT lumbar spine without IV contrast
# May Be Appropriate: CT myelography lumbar spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Subacute or chronic low back pain.
# - Radiculopathy (walking disturbance with left leg weakness).
# - Persistent symptoms for 6 months.
# - Surgery candidate (status post L3-4 posterior fusion surgery).
#
# B. Missing required findings:
# None.
#
# C. Conflicting findings:
# None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, structural abnormalities (e.g., scoliosis, retrolisthesis, annular bulging discs, neuroforaminal narrowing), aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Degenerative spine changes, post-surgical changes, vascular abnormality (aneurysmal dilatation).
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Initial imaging.
#
# **綜合評估: 適合**
#
# 主要理由:
# 病例符合「慢性下背痛合併神經根病變，且症狀持續6個月以上，為手術候選者」的情境。
#
# Key Word:
# 慢性下背痛、神經根病變、手術候選者
# ================================================================================
# Variate 4:
# Topic: Low Back Pain
#
# Variant:
# Low back pain with history of prior lumbar surgery and with or without radiculopathy. New or progressing symptoms or clinical findings. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography lumbar spine
# Usually Appropriate: MRI lumbar spine without and with IV contrast
# Usually Appropriate: MRI lumbar spine without IV contrast
# May Be Appropriate: CT lumbar spine without IV contrast
# May Be Appropriate: CT myelography lumbar spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Low back pain with history of prior lumbar surgery.
# - New or progressing symptoms (walking disturbance with left leg weakness).
# - Red flag (aneurysmal dilatation of abdominal aorta).
# - Imaging phase: Initial imaging.
#
# B. Missing required findings:
# None.
#
# C. Conflicting findings:
# None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, scoliosis, retrolisthesis, annular bulging discs, neuroforaminal encroachment/narrowing, Modic changes.
# - etiology/pathology: Status post L3-4 posterior fusion surgery, aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - red flags: Aneurysmal dilatation of abdominal aorta.
# - imaging phase: Initial imaging.
#
# **綜合評估: 適合**
#
# 主要理由:
# 病例符合「Low back pain with history of prior lumbar surgery」且有新症狀（步行障礙及左腿無力），並伴有紅旗徵象（腹主動脈瘤擴張）。
#
# Key Word:
# Low back pain, prior lumbar surgery, new symptoms, red flag.
# ================================================================================
# Variate 5:
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Subacute or chronic thoracic back pain without myelopathy or radiculopathy. No red flags. Failed conservative management. Initial imaging.
#
# Recommended Procedures:
# May Be Appropriate: Radiography thoracic spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: Subacute or chronic thoracic back pain without myelopathy or radiculopathy; No red flags; Failed conservative management.
# C. Conflicting findings: 病例中有提到 red flags（aneurysmal dilatation of abdominal aorta with mural thrombus formation、persistent pain、neurologic deficit），與 variant 要求的 "No red flags" 相矛盾。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness; marked scoliosis; retrolisthesis; annular bulging discs; neuroforaminal encroachment/narrowing; Modic changes; aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Degenerative spine changes; aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain; neurologic deficit; aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中存在 red flags（aneurysmal dilatation of abdominal aorta with mural thrombus formation），與 variant 要求的 "No red flags" 不符。
#
# Key Word: red flags
# ================================================================================
# Variate 6:
# Topic: Low Back Pain
#
# Variant:
# Low back pain with or without radiculopathy. One or more of the following: suspicion of cancer, infection, or immunosuppression. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI lumbar spine without and with IV contrast
# Usually Appropriate: MRI lumbar spine without IV contrast
# May Be Appropriate: Radiography lumbar spine
# May Be Appropriate: CT lumbar spine with IV contrast
# May Be Appropriate: CT lumbar spine without IV contrast
# May Be Appropriate: CT myelography lumbar spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Low back pain with or without radiculopathy.
# - Persistent low back pain for 6 months.
# - Walking disturbance with left leg weakness.
#
# B. Missing required findings:
# - Suspicion of cancer, infection, or immunosuppression.
#
# C. Conflicting findings:
# None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, structural abnormalities (e.g., scoliosis, retrolisthesis, neuroforaminal narrowing).
# - etiology/pathology: Degenerative changes (e.g., Modic changes, bulging discs), status post L3-4 posterior fusion surgery.
# - red flags: Aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 病例中未提及癌症、感染或免疫抑制的懷疑，無法滿足 variant 的條件。
#
# Key Word:
# 癌症、感染、免疫抑制
# ================================================================================
# Variate 7:
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain with myelopathy or radiculopathy. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI thoracic spine without IV contrast
# May Be Appropriate: Radiography thoracic spine
# May Be Appropriate: MRI thoracic spine without and with IV contrast
# May Be Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: CT myelography thoracic spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Thoracic back pain (marked scoliosis of thoracic spine).
# - Myelopathy or radiculopathy (walking disturbance with left leg weakness).
# - Red flag present (persistent pain, neurologic deficit).
#
# B. Missing required findings:
# - None.
#
# C. Conflicting findings:
# - Imaging phase is follow-up, not initial imaging.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, marked scoliosis of thoracic spine, neuroforaminal narrowing/encroachment, Modic changes.
# - etiology/pathology: Degenerative spine changes, scoliosis, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 適合**
#
# 主要理由:
# 病例中有胸椎側彎與神經根病變，且存在持續性疼痛與神經學缺損，符合該 variant 的疾病與症狀描述。
#
# Key Word:
# Thoracic back pain, myelopathy or radiculopathy, persistent pain.
# ================================================================================
# Variate 8:
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain without or with myelopathy or radiculopathy. One or more of the following: suspicion of cancer, infection, or immunosuppression. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI thoracic spine without and with IV contrast
# Usually Appropriate: MRI thoracic spine without IV contrast
# May Be Appropriate: Radiography thoracic spine
# May Be Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: CT myelography thoracic spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Thoracic back pain (marked scoliosis of thoracic spine).
# - Red flag: aneurysmal dilatation of abdominal aorta with mural thrombus formation.
#
# B. Missing required findings:
# - Suspicion of cancer, infection, or immunosuppression.
#
# C. Conflicting findings:
# - None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, marked scoliosis of thoracic and lumbar spine, retrolisthesis, annular bulging discs, neuroforaminal encroachment/narrowing, Modic changes, aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Degenerative spine changes, status post L3-4 posterior fusion surgery, vascular abnormality (aneurysmal dilatation).
# - red flags: Aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 病例中未提及癌症、感染或免疫抑制的懷疑，無法滿足 variant 的核心條件。
#
# Key Word:
# 癌症、感染、免疫抑制
# ================================================================================
# Variate 9:
# Topic: Management of Iliac Artery Occlusive Disease
#
# Variant:
# Adult. Long history of claudication. Acute-onset left lower-extremity pain. Absent left femoral pulse by palpation, faint audible DP and PT Doppler signals. Initial management.
#
# Recommended Procedures:
# Usually Appropriate: Anticoagulation adjunctive therapy
# Usually Appropriate: CTA abdomen and pelvis with bilateral lower extremity runoff with IV contrast
# Usually Appropriate: Catheter-directed angiography
# Usually Appropriate: MRA abdomen and pelvis with bilateral lower extremity runoff with IV contrast
# May Be Appropriate: US duplex Doppler lower extremity
# May Be Appropriate: Ankle brachial index
# May Be Appropriate: Risk factor analysis and lipid profile
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Elderly male patient with walking disturbance and left leg weakness.
# - Persistent symptoms (low back pain for 6 months).
# - Red flag: aneurysmal dilatation of abdominal aorta with mural thrombus formation.
#
# B. Missing required findings:
# - Acute-onset left lower-extremity pain.
# - Absent left femoral pulse by palpation.
# - Faint audible DP and PT Doppler signals.
#
# C. Conflicting findings:
# - The patient has chronic symptoms (low back pain and walking disturbance for 6 months), not acute-onset symptoms as required by the variant.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance, left leg weakness, aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - etiology/pathology: Structural abnormalities in the lumbar spine, aneurysmal dilatation of abdominal aorta.
# - red flags: Aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 該病例為慢性症狀（6個月低背痛與步行障礙），而variant要求急性發作的左下肢疼痛。
#
# Key Word:
# 急性發作
# ================================================================================
# Variate 10:
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain without or with myelopathy or radiculopathy. Post thoracic spine surgery. Follow-up imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography thoracic spine
# Usually Appropriate: MRI thoracic spine without and with IV contrast
# Usually Appropriate: MRI thoracic spine without IV contrast
# Usually Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: CT myelography thoracic spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Thoracic back pain (marked scoliosis of thoracic spine).
# - Post thoracic spine surgery (status post L3-4 posterior fusion surgery).
# - Follow-up imaging phase.
#
# B. Missing required findings:
# None.
#
# C. Conflicting findings:
# None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, marked scoliosis of thoracic and lumbar spine, post L3-4 posterior fusion surgery.
# - etiology/pathology: Structural abnormalities (e.g., scoliosis, retrolisthesis, annular bulging discs, neuroforaminal narrowing, Modic changes), aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 適合**
#
# 主要理由:
# 病例中有胸椎側彎與術後狀態，且處於追蹤影像階段，符合該 variant 的診斷情境。
#
# Key Word:
# Thoracic spine, post thoracic spine surgery, follow-up imaging.
# ================================================================================
# Variate 11:
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain without or with myelopathy or radiculopathy. Radiograph shows bone destruction or fracture or spinal deformity. Next imaging study.
#
# Recommended Procedures:
# Usually Appropriate: MRI thoracic spine without and with IV contrast
# Usually Appropriate: MRI thoracic spine without IV contrast
# Usually Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: CT myelography thoracic spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Thoracic back pain (marked scoliosis of thoracic spine).
# - Spinal deformity (marked scoliosis).
#
# B. Missing required findings:
# - Bone destruction or fracture (not mentioned in the case).
#
# C. Conflicting findings:
# - None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, marked scoliosis of thoracic and lumbar spine, neuroforaminal narrowing/encroachment, Modic changes, aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Degenerative spine changes, scoliosis, retrolisthesis, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 適合**
#
# 主要理由:
# 病例中提到胸椎脊柱變形（marked scoliosis of thoracic spine），符合該 variant 的診斷情境。
#
# Key Word:
# Spinal deformity.
# ================================================================================
# Variate 12:
# Topic: Inflammatory Back Pain: Known or Suspected Axial Spondyloarthropathy
#
# Variant:
# Inflammatory back pain. Suspected axial spondyloarthritis. Negative radiographs and negative MRI of the sacroiliac joints. Next imaging study.
#
# Recommended Procedures:
# Usually Appropriate: Radiography spine area of interest
# Usually Appropriate: MRI spine area of interest without and with IV contrast
# Usually Appropriate: MRI spine area of interest without IV contrast
# Usually Appropriate: CT spine area of interest without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Low back pain (primary symptom).
# - Walking disturbance with left leg weakness.
# - Structural abnormalities in the spine (e.g., scoliosis, retrolisthesis, annular bulging discs, neuroforaminal narrowing).
# - Follow-up imaging phase.
#
# B. Missing required findings:
# - Inflammatory back pain.
# - Suspected axial spondyloarthritis.
# - Negative radiographs and negative MRI of the sacroiliac joints.
#
# C. Conflicting findings:
# - Presence of significant degenerative changes (e.g., Modic changes, neuroforaminal narrowing) suggests a mechanical rather than inflammatory etiology.
# - No mention of inflammatory back pain or axial spondyloarthritis suspicion.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance, left leg weakness, structural abnormalities in the spine.
# - etiology/pathology: Degenerative spine changes, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 病例中無明確提及炎性背痛或懷疑軸性脊椎關節炎，且影像學改變以退行性病變為主，與variant的診斷重點不符。
#
# Key Word:
# 炎性背痛, 軸性脊椎關節炎
# ================================================================================
# Variate 13:
# Topic: Chronic Extremity Joint Pain-Suspected Inflammatory Arthritis, Crystalline Arthritis, or Erosive Osteoarthritis
#
# Variant:
# Chronic extremity joint pain. Suspect inflammatory (seropositive or seronegative arthritis), crystalline (gout or pseudogout), or erosive osteoarthritis. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography area of interest
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: None.
# B. Missing required findings: Chronic extremity joint pain; suspected inflammatory arthritis, crystalline arthritis, or erosive osteoarthritis.
# C. Conflicting findings: The patient’s symptoms and pathology are focused on the lumbar spine and vascular abnormalities, not extremity joint pain or arthritis.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness; structural abnormalities in the lumbar spine; aneurysmal dilatation of the abdominal aorta.
# - etiology/pathology: Degenerative changes in the lumbar spine; vascular abnormality (aneurysmal dilatation).
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of the abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例的主要症狀為腰痛及神經學異常，與variant中提到的慢性四肢關節痛及關節炎無關。
#
# Key Word: 慢性四肢關節痛
# ================================================================================
# Variate 14:
# Topic: Osteoporosis and Bone Mineral Density
#
# Variant:
# Males and females greater than or equal to 50 years of age. Suspected osteoporosis. Advanced degenerative changes of the spine with or without scoliosis, or other conditions that may spuriously elevate BMD. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: DXA distal forearm
# Usually Appropriate: DXA lumbar spine and hip(s)
# Usually Appropriate: QCT lumbar spine and hip(s)
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - 年齡 ≥ 50 歲 (82 歲)。
# - Advanced degenerative changes of the spine with scoliosis。
#
# B. Missing required findings:
# - Suspected osteoporosis。
#
# C. Conflicting findings:
# - 病例中未提及骨質疏鬆的懷疑或診斷。
#
# ---
#
# 病例關鍵資訊:
# - primary symptom: Low back pain。
# - associated findings: Walking disturbance with left leg weakness; advanced degenerative changes of the spine with scoliosis。
# - etiology/pathology: Advanced degenerative changes, scoliosis, retrolisthesis, Modic changes, neuroforaminal narrowing。
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta。
# - imaging phase: Follow-up。
#
# ---
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中未提及骨質疏鬆的懷疑或診斷，與 variant 的診斷重點不符。
#
# Key Word: Suspected osteoporosis。
# ================================================================================
# Variate 15:
# Topic: Demyelinating Diseases
#
# Variant:
# Adult. Acute or chronic symmetric weakness. Suspect demyelinating disease of the peripheral nervous system. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI brachial plexus without and with IV contrast
# Usually Appropriate: MRI cervical and thoracic spine without and with IV contrast
# Usually Appropriate: MRI lumbar spine without and with IV contrast
# Usually Appropriate: MRI lumbosacral plexus without and with IV contrast
# May Be Appropriate: MRI brachial plexus without IV contrast
# May Be Appropriate: MRI cervical and thoracic spine without IV contrast
# May Be Appropriate: MRI head without and with IV contrast
# May Be Appropriate: MRI lumbar spine without IV contrast
# May Be Appropriate: MRI lumbosacral plexus with IV contrast
# May Be Appropriate: MRI lumbosacral plexus without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Chronic weakness (left leg weakness for 6 months).
# - Imaging of the lumbar spine is relevant (structural abnormalities and symptoms localized to lumbar spine).
#
# B. Missing required findings:
# - Symmetric weakness (patient has left leg weakness, not symmetric).
# - Suspected demyelinating disease of the peripheral nervous system (no mention or suspicion of demyelinating disease in the case).
#
# C. Conflicting findings:
# - The patient's symptoms and findings are more consistent with structural spine abnormalities and vascular issues, not demyelinating disease.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance, left leg weakness, structural spine abnormalities, aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Structural spine abnormalities (e.g., scoliosis, retrolisthesis, neuroforaminal narrowing, Modic changes), vascular abnormality (aneurysmal dilatation of abdominal aorta).
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 病例中無明確提及或懷疑周邊神經脫髓鞘疾病，且患者的症狀與結構性脊柱異常及血管問題更為一致。
#
# Key Word:
# Demyelinating disease
# ================================================================================
# Variate 16:
# Topic: Inflammatory Back Pain: Known or Suspected Axial Spondyloarthropathy
#
# Variant:
# Inflammatory back pain. Suspected axial spondyloarthritis. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography sacroiliac joints
# Usually Appropriate: Radiography sacroiliac joints and spine area of interest
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 疑似或已知的「炎性背痛」或「中軸型脊椎關節病」。
# C. Conflicting findings: 病例中主要為退行性病變（如椎間盤膨出、神經孔狹窄、Modic變化等），無炎性背痛或中軸型脊椎關節病的相關描述。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain。
# - associated findings: Walking disturbance with left leg weakness；結構性異常（如脊柱側彎、椎間盤膨出、神經孔狹窄等）。
# - etiology/pathology: 退行性病變（如Modic變化、椎間盤膨出、神經孔狹窄等）；腹主動脈瘤伴血栓形成。
# - red flags: Persistent pain；Walking disturbance；Aneurysmal dilatation of abdominal aorta。
# - imaging phase: Follow-up。
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中無炎性背痛或中軸型脊椎關節病的相關描述，主要為退行性病變。
#
# Key Word: 中軸型脊椎關節病
# ================================================================================
# Variate 17:
# Topic: Inflammatory Back Pain: Known or Suspected Axial Spondyloarthropathy
#
# Variant:
# Axial spondyloarthritis with spine ankylosis. Suspected fracture. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography spine area of interest
# Usually Appropriate: MRI spine area of interest without IV contrast
# Usually Appropriate: CT spine area of interest without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Low back pain.
# - Walking disturbance with left leg weakness.
# - Structural abnormalities in the spine (e.g., scoliosis, retrolisthesis, annular bulging discs).
# - Red flag: Persistent pain and neurologic deficit.
#
# B. Missing required findings:
# - Axial spondyloarthritis.
# - Spine ankylosis.
# - Suspected fracture.
#
# C. Conflicting findings:
# - None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance, left leg weakness, structural abnormalities in the spine.
# - etiology/pathology: Degenerative spine changes, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 病例中未提及「Axial spondyloarthritis」或「Spine ankylosis」，與該 variant 的診斷重點不符。
#
# Key Word:
# Axial spondyloarthritis, Spine ankylosis.
# ================================================================================
# Variate 18:
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Acute thoracic back pain without myelopathy or radiculopathy. No red flags. No prior management. Initial imaging.
#
# Recommended Procedures:
#
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: Acute thoracic back pain, no red flags, no prior management, initial imaging。
# C. Conflicting findings: 病例中有 red flags（aneurysmal dilatation of abdominal aorta with mural thrombus formation, persistent pain, neurologic deficit），且為 follow-up imaging。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain。
# - associated findings: Walking disturbance with left leg weakness, marked scoliosis, retrolisthesis, annular bulging discs, neuroforaminal encroachment/narrowing, Modic changes, aneurysmal dilatation of abdominal aorta。
# - etiology/pathology: Structural abnormalities（e.g., scoliosis, retrolisthesis, disc bulging, Modic changes），vascular abnormality（aneurysmal dilatation of abdominal aorta）。
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta。
# - imaging phase: Follow-up。
#
# **綜合評估: 不適合**
#
# 主要理由: 病例有 red flags（aneurysmal dilatation of abdominal aorta, persistent pain, neurologic deficit），且為 follow-up imaging，與 variant 要求的 "no red flags" 和 "initial imaging" 不符。
#
# Key Word: red flags, follow-up imaging。
# ================================================================================
# Variate 19:
# Topic: Chronic Extremity Joint Pain-Suspected Inflammatory Arthritis, Crystalline Arthritis, or Erosive Osteoarthritis
#
# Variant:
# Chronic extremity joint pain. Suspect erosive osteoarthritis. Radiographs normal or inconclusive. Next imaging study.
#
# Recommended Procedures:
# May Be Appropriate: US area of interest
# May Be Appropriate: MRI area of interest without and with IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: None.
# B. Missing required findings: Chronic extremity joint pain, suspected erosive osteoarthritis, radiographs normal or inconclusive.
# C. Conflicting findings: The patient has low back pain and walking disturbance, not extremity joint pain.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, structural abnormalities (e.g., scoliosis, retrolisthesis, neuroforaminal narrowing).
# - etiology/pathology: Status post L3-4 posterior fusion surgery, Modic changes, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例的主要症狀為腰痛及步行障礙，與 variant 中的慢性四肢關節痛及懷疑侵蝕性骨關節炎不符。
#
# Key Word: 慢性四肢關節痛
# ================================================================================
# Variate 20:
# Topic: Management of Iliac Artery Occlusive Disease
#
# Variant:
# Adult. Nonsmoker, sedentary lifestyle. Left lower-extremity claudication on walking, asymmetrically diminished left femoral pulse. No symptoms at rest. Initial management.
#
# Recommended Procedures:
# Usually Appropriate: Best medical management including supervised exercise program only
# Usually Appropriate: Risk factor analysis and lipid profile and ABIs
# Usually Appropriate: Antiplatelet adjunctive therapy
# Usually Appropriate: US duplex Doppler lower extremity
# May Be Appropriate: CTA abdomen and pelvis with bilateral lower extremity runoff with IV contrast
# May Be Appropriate: MRA abdomen and pelvis with bilateral lower extremity runoff with IV contrast
# May Be Appropriate: Plethysmography and pulse volume recording
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Left lower-extremity symptoms (walking disturbance with left leg weakness).
# - Sedentary lifestyle (implied by age and symptoms).
# - Red flag: Persistent symptoms for 6 months.
#
# B. Missing required findings:
# - Asymmetrically diminished left femoral pulse.
# - Left lower-extremity claudication on walking.
# - No symptoms at rest (not explicitly stated).
#
# C. Conflicting findings:
# - Aneurysmal dilatation of abdominal aorta with mural thrombus formation (vascular pathology not mentioned in the variant).
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Structural abnormalities in the lumbar spine, vascular pathology (abdominal aortic aneurysm).
# - red flags: Persistent symptoms, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 該病例的主要病因為脊柱結構異常與腹主動脈瘤，而variant聚焦於髂動脈阻塞性疾病，病因不符。
#
# Key Word:
# 髂動脈阻塞性疾病
# ================================================================================
# Variate 21:
# Topic: Acute Onset Flank Pain-Suspicion of Stone Disease (Urolithiasis)
#
# Variant:
# Acute onset flank pain in patient with known current stone disease, diagnosed on recent imaging. Recurrent symptoms of stone disease. Follow-up imaging.
#
# Recommended Procedures:
# Usually Appropriate: CT abdomen and pelvis without IV contrast
# May Be Appropriate: US color Doppler kidneys and bladder retroperitoneal
# May Be Appropriate: US kidneys and bladder retroperitoneal
# May Be Appropriate: Radiography abdomen and pelvis
# May Be Appropriate: CT abdomen and pelvis with IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 急性側腹痛、近期影像診斷的結石病、結石病復發症狀。
# C. Conflicting findings: 病例主要症狀為慢性腰痛及行走困難，無急性側腹痛或結石病相關症狀。
#
# 病例關鍵資訊:
# - primary symptom: 慢性腰痛
# - associated findings: 行走困難、左腿無力
# - etiology/pathology: 腰椎結構異常（包括脊柱側彎、椎間盤突出、神經孔狹窄等），腹主動脈瘤伴附壁血栓形成
# - red flags: 持續性疼痛、神經功能缺損、腹主動脈瘤
# - imaging phase: 隨訪
#
# **綜合評估: 不適合**
#
# 主要理由: 病例無急性側腹痛或結石病相關症狀，與該 variant 的診斷重點不符。
#
# Key Word: 急性側腹痛、結石病
# ================================================================================
# Variate 22:
# Topic: Low Back Pain
#
# Variant:
# Subacute or chronic low back pain with or without radiculopathy. No red flags. No prior management. Initial imaging.
#
# Recommended Procedures:
#
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Subacute or chronic low back pain.
# - Radiculopathy (walking disturbance with left leg weakness).
#
# B. Missing required findings:
# - No prior management (patient has undergone L3-4 posterior fusion surgery and has prior imaging findings).
#
# C. Conflicting findings:
# - Presence of red flags (aneurysmal dilatation of abdominal aorta with mural thrombus formation, persistent pain, and neurologic deficit), whereas the variant specifies "No red flags."
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, structural abnormalities (scoliosis, retrolisthesis, neuroforaminal narrowing, Modic changes), aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Degenerative spine changes, vascular abnormality (abdominal aortic aneurysm).
# - red flags: True (aneurysmal dilatation of abdominal aorta, persistent pain, neurologic deficit).
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例有明確的 red flags（腹主動脈瘤擴張及血栓形成），與 variant 指出 "No red flags" 相矛盾。
#
# Key Word: red flags, aneurysmal dilatation of abdominal aorta.
# ================================================================================
# Variate 23:
# Topic: Dizziness and Ataxia
#
# Variant:
# Adult. Chronic disequilibrium with signs of sensory or proprioceptive ataxia. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI cervical and thoracic spine without and with IV contrast
# Usually Appropriate: MRI cervical and thoracic spine without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Walking disturbance with left leg weakness (ataxia-related symptom).
# - Persistent low back pain for 6 months (chronic disequilibrium may overlap).
# - Structural abnormalities in thoracic and lumbar spine (variant mentions cervical and thoracic spine imaging).
#
# B. Missing required findings:
# - No explicit mention of sensory or proprioceptive ataxia.
#
# C. Conflicting findings:
# - Imaging phase is follow-up, not initial imaging as specified in the variant.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, thoracic and lumbar spine abnormalities.
# - etiology/pathology: Degenerative spine changes, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例為 follow-up imaging，而 variant 指定為 initial imaging。
#
# Key Word: initial imaging
# ================================================================================
# Variate 24:
# Topic: Chronic Ankle Pain
#
# Variant:
# Chronic ankle pain. Multiple sites of degenerative joint disease in the hindfoot detected by ankle radiographs. Next study.
#
# Recommended Procedures:
# May Be Appropriate: Image-guided anesthetic injection ankle and hindfoot
# May Be Appropriate: MRI ankle and hindfoot without IV contrast
# May Be Appropriate: CT ankle and hindfoot without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 病例中未提及慢性踝痛或踝關節及後足的退化性關節疾病。
# C. Conflicting findings: 病例的主要症狀為腰痛及行走困難，與踝關節及後足的病變無關。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain
# - associated findings: Walking disturbance with left leg weakness
# - etiology/pathology: 腰椎退化性病變及腹主動脈瘤擴張
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta
# - imaging phase: Follow-up
#
# **綜合評估: 不適合**
#
# 主要理由: 病例的主要病因為腰椎退化性病變及腹主動脈瘤擴張，與踝關節及後足的退化性病變無關。
#
# Key Word: 腰椎退化性病變
# ================================================================================
# Variate 25:
# Topic: Radiologic Management of Mesenteric Ischemia
#
# Variant:
# History of abdominal pain after meals for the past few months and weight loss. CTA shows aortic atherosclerotic disease and suggests SMA-origin stenosis with occlusion of celiac origin and an occluded IMA. Initial therapy.
#
# Recommended Procedures:
# Usually Appropriate: Angiography with possible percutaneous transluminal angioplasty and stent placement
# May Be Appropriate: Surgical bypass or endarterectomy
# May Be Appropriate: Systemic anticoagulation
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Aneurysmal dilatation of abdominal aorta with mural thrombus formation (vascular abnormality).
#
# B. Missing required findings:
# - History of abdominal pain after meals for the past few months.
# - Weight loss.
# - Imaging findings suggesting SMA-origin stenosis, occlusion of celiac origin, and occluded IMA.
#
# C. Conflicting findings:
# - Primary symptom is low back pain and walking disturbance, not abdominal pain or mesenteric ischemia.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness.
# - etiology/pathology: Aneurysmal dilatation of abdominal aorta with mural thrombus formation; marked scoliosis; retrolisthesis; neuroforaminal narrowing; Modic changes.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例主要症狀為腰痛及行走困難，且無腹痛或腸系膜缺血相關病史或影像特徵。
#
# Key Word: 腰痛、行走困難、腹主動脈瘤
# ================================================================================
# Variate 26:
# Topic: Chronic Extremity Joint Pain-Suspected Inflammatory Arthritis, Crystalline Arthritis, or Erosive Osteoarthritis
#
# Variant:
# Chronic extremity joint pain. Suspect inflammatory arthritis (seropositive or seronegative arthritis). Radiographs normal or inconclusive. Next imaging study.
#
# Recommended Procedures:
# Usually Appropriate: US area of interest
# Usually Appropriate: MRI area of interest without and with IV contrast
# Usually Appropriate: MRI area of interest without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 病例中未提到慢性四肢關節疼痛，也未懷疑炎性關節炎、結晶性關節炎或侵蝕性骨關節炎。
# C. Conflicting findings: 病例主要集中在腰椎和胸椎的結構異常及腹主動脈瘤，與四肢關節疼痛無關。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain
# - associated findings: Walking disturbance with left leg weakness
# - etiology/pathology: 腰椎結構異常（如椎間盤突出、神經孔狹窄等）及腹主動脈瘤
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta
# - imaging phase: Follow-up
#
# **綜合評估: 不適合**
#
# 主要理由: 病例主要涉及腰椎結構異常及腹主動脈瘤，與variant中的慢性四肢關節疼痛或炎性關節炎無關。
#
# Key Word: 腰椎結構異常
# ================================================================================
# Variate 27:
# Topic: Osteoporosis and Bone Mineral Density
#
# Variant:
# Follow-up imaging. Patients with T-scores less than −1.0 (by DXA) and one or more of the following: 1) Females equal to or greater than 70 years of age or males equal to or greater than 80 years of age; 2) Historical height loss greater than 4 cm (greater than 1.5 inches); 3) Self-reported but undocumented prior vertebral fracture; 4) Glucocorticoid therapy equivalent to equal to or greater than 5 mg of prednisone or equivalent per day for equal to or greater than 3 months.
#
# Recommended Procedures:
# Usually Appropriate: DXA lumbar spine and hip(s)
# Usually Appropriate: DXA VFA
# May Be Appropriate: DXA distal forearm
# May Be Appropriate: Radiography axial skeleton
# May Be Appropriate: QCT lumbar spine and hip
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - 男性年齡 ≥80歲。
#
# B. Missing required findings:
# - T-score < -1.0 (病例未提供骨密度檢測結果)。
# - 歷史性身高減少 >4 cm。
# - 自述但未記錄的椎骨骨折。
# - 長期使用糖皮質激素治療（≥3個月）。
#
# C. Conflicting findings:
# - 病例主要集中於腰椎結構異常及腹主動脈瘤，未提及骨質疏鬆相關問題。
#
# 病例關鍵資訊:
# - primary symptom: 腰痛。
# - associated findings: 左腿無力、步態障礙。
# - etiology/pathology: 腰椎結構異常（包括椎間盤突出、神經孔狹窄等）；腹主動脈瘤。
# - red flags: 腹主動脈瘤擴張伴附壁血栓形成。
# - imaging phase: 隨訪。
#
# **綜合評估: 不適合**
#
# 主要理由: 病例未提供骨密度檢測結果，且主要病因集中於腰椎結構異常及腹主動脈瘤，與骨質疏鬆無直接關聯。
#
# Key Word: 骨密度檢測、骨質疏鬆
# ================================================================================
# Variate 28:
# Topic: Radiologic Management of Mesenteric Ischemia
#
# Variant:
# Recent onset abdominal pain, no peritoneal signs, and known atrial fibrillation. CTA shows calcified atherosclerotic plaque involving the aorta and its major branches, as well as proximal short-segment occlusion of the proximal SMA. No intramural or extra- luminal air. Initial therapy. Appropriateness
#
# Recommended Procedures:
# Usually Appropriate: Systemic anticoagulation
# May Be Appropriate: Surgical endarterectomy or bypass
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Aneurysmal dilatation of abdominal aorta with mural thrombus formation.
#
# B. Missing required findings:
# - Recent onset abdominal pain.
# - No peritoneal signs.
# - Known atrial fibrillation.
# - Proximal short-segment occlusion of the proximal SMA.
#
# C. Conflicting findings:
# - Patient has persistent low back pain and walking disturbance, which are unrelated to mesenteric ischemia.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness.
# - etiology/pathology: Aneurysmal dilatation of abdominal aorta with mural thrombus formation; marked scoliosis; retrolisthesis; neuroforaminal narrowing.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中未提及近期腹痛或近端 SMA 阻塞，與 variant 的主要診斷情境不符。
#
# Key Word: Aneurysmal dilatation of abdominal aorta
# ================================================================================
# Variate 29:
# Topic: Low Back Pain
#
# Variant:
# Acute low back pain with or without radiculopathy. No red flags. No prior management. Initial imaging.
#
# Recommended Procedures:
#
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無急性腰痛，病例中有慢性腰痛（6個月）。
# B. Missing required findings: 病例中有紅旗徵象（aneurysmal dilatation of abdominal aorta with mural thrombus formation），但variant要求「No red flags」。
# C. Conflicting findings: 病例屬於隨訪階段，variant要求初次影像檢查（Initial imaging）。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness; marked scoliosis; retrolisthesis; neuroforaminal encroachment/narrowing; Modic changes; aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - etiology/pathology: Structural abnormalities of lumbar spine; vascular pathology (abdominal aortic aneurysm).
# - red flags: True (aneurysmal dilatation of abdominal aorta with mural thrombus formation).
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例有紅旗徵象（aneurysmal dilatation of abdominal aorta with mural thrombus formation），但variant要求「No red flags」。
#
# Key Word: aneurysmal dilatation of abdominal aorta with mural thrombus formation
# ================================================================================
# Variate 30:
# Topic: Acute Elbow and Forearm Pain
#
# Variant:
# Adult. Acute elbow or forearm pain. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography area of interest
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 急性肘部或前臂疼痛。
# C. Conflicting findings: 病例主要症狀為慢性腰背痛及行走困難，與肘部或前臂疼痛無關。
#
# 病例關鍵資訊:
# - primary symptom: 慢性腰背痛。
# - associated findings: 行走困難、左腿無力。
# - etiology/pathology: 腰椎退化性病變（包括椎間盤突出、神經孔狹窄、Modic變化等）；腹主動脈瘤伴附壁血栓形成。
# - red flags: 持續性疼痛、神經功能缺損、腹主動脈瘤。
# - imaging phase: 隨訪。
#
# **綜合評估: 不適合**
#
# 主要理由: 病例的主要症狀和病因集中在腰椎退化性病變及腹主動脈瘤，與急性肘部或前臂疼痛無關。
#
# Key Word: 腰椎退化性病變、腹主動脈瘤。
# ================================================================================
# Variate 31:
# Topic: Low Back Pain
#
# Variant:
# Low back pain with suspected cauda equina syndrome. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI lumbar spine without and with IV contrast
# Usually Appropriate: MRI lumbar spine without IV contrast
# May Be Appropriate: CT lumbar spine without IV contrast
# May Be Appropriate: CT myelography lumbar spine
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Low back pain.
# - Walking disturbance with left leg weakness.
# - Structural abnormalities in the lumbar spine (e.g., retrolisthesis, annular bulging discs, neuroforaminal narrowing).
# - Red flag: Persistent pain and neurologic deficit.
#
# B. Missing required findings:
# - Suspected cauda equina syndrome (not explicitly mentioned).
#
# C. Conflicting findings:
# None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance, left leg weakness, structural abnormalities in the lumbar spine.
# - etiology/pathology: Degenerative changes in the lumbar spine, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 病例中未提及「suspected cauda equina syndrome」，不符合該variant的診斷重點。
#
# Key Word:
# suspected cauda equina syndrome
# ================================================================================
# Variate 32:
# Topic: Chronic Ankle Pain
#
# Variant:
# Chronic ankle pain. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography ankle
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 病例中未提及慢性踝痛或踝部相關症狀。
# C. Conflicting findings: 病例的主要症狀為腰痛及步行困難，與踝部無關。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain
# - associated findings: Walking disturbance, left leg weakness
# - etiology/pathology: 腰椎退行性病變及腹主動脈瘤
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta
# - imaging phase: Follow-up
#
# **綜合評估: 不適合**
#
# 主要理由: 病例的主要症狀及病因集中在腰椎及腹部，與踝部無關。
#
# Key Word: Low back pain, aneurysmal dilatation
# ================================================================================
# Variate 33:
# Topic: Inflammatory Back Pain: Known or Suspected Axial Spondyloarthropathy
#
# Variant:
# Known axial spondyloarthritis. Follow-up for treatment response or disease progression. Appropriateness Relative Radiation
#
# Recommended Procedures:
# Usually Appropriate: Radiography sacroiliac joints
# Usually Appropriate: Radiography sacroiliac joints and spine area of interest
# May Be Appropriate: MRI sacroiliac joints and spine area of interest without and with IV contrast
# May Be Appropriate: MRI sacroiliac joints and spine area of interest without IV contrast
# May Be Appropriate: MRI sacroiliac joints without and with IV contrast
# May Be Appropriate: MRI sacroiliac joints without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: Known axial spondyloarthritis。
# C. Conflicting findings: 病例中未提及任何與 axial spondyloarthritis 相關的病因或診斷。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain。
# - associated findings: Walking disturbance with left leg weakness；marked scoliosis；retrolisthesis；annular bulging discs；neuroforaminal encroachment/narrowing；Modic changes；aneurysmal dilatation of abdominal aorta。
# - etiology/pathology: 腰椎結構異常及退行性病變；腹主動脈瘤。
# - red flags: Persistent pain；neurologic deficit；aneurysmal dilatation of abdominal aorta。
# - imaging phase: Follow-up。
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中未提及 axial spondyloarthritis 的診斷或懷疑，與 variant 的疾病範疇不符。
#
# Key Word: axial spondyloarthritis。
# ================================================================================
# Variate 34:
# Topic: Chronic Foot Pain
#
# Variant:
# Adult. Chronic foot pain. Unknown etiology. Initial imaging. Appropriateness Relative Radiation
#
# Recommended Procedures:
# Usually Appropriate: Radiography foot
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 足部疼痛、未知病因、初次影像檢查。
# C. Conflicting findings: 病例主要症狀為腰痛及步態障礙，且病因已知（脊椎結構異常及腹主動脈瘤）。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain
# ...
# C. Conflicting findings: The patient has low back pain, walking disturbance, and left leg weakness, which are unrelated to chronic foot pain or soft tissue issues in the foot.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain
# - associated findings: Walking disturbance, left leg weakness
# - etiology/pathology: Scoliosis, retrolisthesis, annular bulging discs, neuroforaminal narrowing, Modic changes, aneurysmal dilatation of abdominal aorta
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta
# - imaging phase: Follow-up
#
# **綜合評估: 不適合**
#
# 主要理由: 病例的主要症狀為腰痛及步態異常，與 variant 中的慢性足痛及軟組織病變無關。
#
# Key Word: 慢性足痛
# ================================================================================
# Variate 40:
# Topic: Chronic Foot Pain
#
# Variant:
# Adult. Chronic foot pain. Suspect Baxter neuropathy or complex regional pain syndrome or entrapment syndrome or other neurogenic origin. Radiographs negative or indeterminate. Next imaging study. Relative Radiation
#
# Recommended Procedures:
# Usually Appropriate: MRI foot without IV contrast
# May Be Appropriate: US foot
# May Be Appropriate: Image-guided anesthetic +/- corticosteroid injection foot or
# May Be Appropriate: MRI foot without and with IV contrast
# May Be Appropriate: 3-phase bone scan foot
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: None.
# B. Missing required findings: Chronic foot pain, suspicion of Baxter neuropathy, complex regional pain syndrome, entrapment syndrome, or other neurogenic origin.
# C. Conflicting findings: The patient’s primary symptom is low back pain with walking disturbance and left leg weakness, not foot pain.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance, left leg weakness, structural abnormalities in the lumbar spine, aneurysmal dilatation of the abdominal aorta.
# - etiology/pathology: Degenerative spine changes, scoliosis, retrolisthesis, Modic changes, neuroforaminal narrowing, aneurysmal dilatation of the abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of the abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由:
# 該病例的主要症狀為腰痛及步行障礙，與 variant 中針對的慢性足痛及相關神經病變不符。
#
# Key Word:
# 慢性足痛
# ================================================================================
# Variate 41:
# Topic: Osteoporosis and Bone Mineral Density
#
# Variant:
# Follow-up imaging of patients demonstrated to have risk for fracture or surveillance of established low bone mineral density.
#
# Recommended Procedures:
# Usually Appropriate: DXA lumbar spine and hip(s)
# May Be Appropriate: DXA distal forearm
# May Be Appropriate: TBS lumbar spine
# May Be Appropriate: QCT lumbar spine and hip
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: None
# B. Missing required findings: Risk for fracture or established low bone mineral density.
# C. Conflicting findings: None
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, structural abnormalities (scoliosis, retrolisthesis, annular bulging discs, neuroforaminal narrowing, Modic changes), aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Degenerative spine changes, status post L3-4 posterior fusion surgery, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中未提及骨折風險或已確診的低骨密度，與該 variant 的適應症不符。
#
# Key Word: Risk for fracture or low bone mineral density
# ================================================================================
# Variate 42:
# Topic: Myelopathy
#
# Variant:
# Chronic or progressive myelopathy. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI spine area of interest without and with IV contrast
# Usually Appropriate: MRI spine area of interest without IV contrast
# May Be Appropriate: CT myelography spine area of interest
# May Be Appropriate: CT spine area of interest with IV contrast
# May Be Appropriate: CT spine area of interest without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings:
# - Chronic or progressive symptoms (low back pain for 6 months, walking disturbance with left leg weakness).
# - Structural abnormalities in the spine (scoliosis, retrolisthesis, annular bulging discs, neuroforaminal encroachment/narrowing, Modic changes).
# - Red flag present (persistent pain, neurologic deficit).
#
# B. Missing required findings:
# None.
#
# C. Conflicting findings:
# None.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance, left leg weakness, structural abnormalities in the spine.
# - etiology/pathology: Degenerative spine changes, post-surgical changes, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 適合**
#
# 主要理由:
# 該病例符合慢性或進行性脊髓病變的症狀與脊柱結構異常，且有持續性疼痛與神經功能缺損的紅旗徵象。
#
# Key Word:
# 慢性脊髓病變、脊柱結構異常、神經功能缺損
# ================================================================================
# Variate 43:
# Topic: Osteoporosis and Bone Mineral Density
#
# Variant:
# Osteoporosis screening or initial imaging of clinically suspected low bone mineral density.
#
# Recommended Procedures:
# Usually Appropriate: DXA lumbar spine and hip(s)
# May Be Appropriate: DXA distal forearm
# May Be Appropriate: QCT lumbar spine and hip
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: None
# B. Missing required findings: Clinically suspected low bone mineral density or osteoporosis.
# C. Conflicting findings: The patient case focuses on structural spinal abnormalities and vascular issues, not osteoporosis or bone mineral density concerns.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, structural spinal abnormalities, aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Spinal degeneration (e.g., scoliosis, retrolisthesis, Modic changes) and vascular pathology (aneurysmal dilatation).
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中無骨質疏鬆或骨密度降低的臨床懷疑，且主要關注脊柱結構異常與血管問題。
#
# Key Word: 骨質疏鬆
# ================================================================================
# Variate 44:
# Topic: Chronic Foot Pain
#
# Variant:
# Adult. Chronic foot pain. Suspect osteochondral lesion or cartilage abnormality or degenerative joint disease or pain of other articular origin. Radiographs negative or indeterminate. Next imaging study. Appropriateness Relative Radiation
#
# Recommended Procedures:
# Usually Appropriate: MRI foot without IV contrast
# Usually Appropriate: CT foot without IV contrast
# May Be Appropriate: US foot
# May Be Appropriate: MR arthrography foot
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 病例中無慢性足部疼痛的主訴，也無懷疑骨軟骨病變、軟骨異常、退行性關節疾病或其他關節性疼痛的描述。
# C. Conflicting findings: 病例的主要症狀為腰痛、步態障礙及左腿無力，與足部疼痛無關。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain
# - associated findings: Walking disturbance with left leg weakness
# - etiology/pathology: 腰椎結構異常（如脊柱側彎、椎間盤膨出、椎間孔狹窄等）
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta
# - imaging phase: Follow-up
#
# **綜合評估: 不適合**
#
# 主要理由: 病例的主要症狀為腰痛及步態障礙，與該 variant 的慢性足部疼痛無關。
#
# Key Word: 慢性足部疼痛
# ================================================================================
# Variate 45:
# Topic: Nonatherosclerotic Peripheral Arterial Disease
#
# Variant:
# Suspected or known other noninflammatory lower-extremity vascular diseases (such as fibromuscular dysplasia, segmental arterial mediolysis). Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Arteriography lower extremity
# Usually Appropriate: MRA lower extremity without and with IV contrast
# Usually Appropriate: CTA lower extremity with IV contrast
# May Be Appropriate: US duplex Doppler lower extremity
# May Be Appropriate: US intravascular lower extremity
# May Be Appropriate: MRA lower extremity without IV contrast
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 非動脈粥樣硬化性下肢血管疾病（如纖維肌發育不良、節段性動脈溶解症）的懷疑或已知診斷。
# C. Conflicting findings: 病例主要涉及腰椎結構異常及腹主動脈瘤擴張，與非動脈粥樣硬化性下肢血管疾病無關。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain
# - associated findings: Walking disturbance with left leg weakness, marked scoliosis, retrolisthesis, annular bulging discs, neuroforaminal encroachment/narrowing, Modic changes, abdominal aortic aneurysm with mural thrombus.
# - etiology/pathology: 腰椎退行性變化及腹主動脈瘤擴張。
# - red flags: Persistent pain, neurologic deficit, abdominal aortic aneurysm.
# - imaging phase: Follow-up
#
# **綜合評估: 不適合**
#
# 主要理由:
# 病例中未提及非動脈粥樣硬化性下肢血管疾病的懷疑或診斷，與該 variant 的適應症不符。
#
# Key Word:
# 非動脈粥樣硬化性下肢血管疾病
# ================================================================================
# Variate 46:
# Topic: Acute Onset Flank Pain-Suspicion of Stone Disease (Urolithiasis)
#
# Variant:
# Acute onset flank pain. Suspicion of stone disease. No history or remote history of stone disease. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: CT abdomen and pelvis without IV contrast
# May Be Appropriate: US color Doppler kidneys and bladder retroperitoneal
# May Be Appropriate: US kidneys and bladder retroperitoneal
# May Be Appropriate: Radiography abdomen and pelvis
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: None.
# B. Missing required findings: Acute onset flank pain, suspicion of stone disease, no history or remote history of stone disease.
# C. Conflicting findings: The patient has chronic low back pain and walking disturbance, not acute flank pain or suspicion of stone disease.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, structural abnormalities (e.g., scoliosis, retrolisthesis, neuroforaminal narrowing).
# - etiology/pathology: Degenerative spine changes, aneurysmal dilatation of abdominal aorta with mural thrombus formation.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例主要症狀為慢性腰痛與步態異常，與 variant 的急性側腹痛及疑似結石病情況不符。
#
# Key Word: 慢性腰痛
# ================================================================================
# Variate 47:
# Topic: Management of Iliac Artery Occlusive Disease
#
# Variant:
# Adult. Known atrial fibrillation and spine surgery performed within the past month. Sudden-onset right lower-extremity pain. Diminished pulses in right lower- extremity. CTA demonstrates isolated filling defect in right common iliac artery. Initial therapy.
#
# Recommended Procedures:
# Usually Appropriate: Anticoagulation adjunctive therapy
# Usually Appropriate: Catheter-directed mechanical thrombectomy
# Usually Appropriate: Surgical revascularization
# May Be Appropriate: Antiplatelet adjunctive therapy
# May Be Appropriate: Catheter-directed thrombolytic therapy
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings:
# - Known atrial fibrillation.
# - Spine surgery performed within the past month.
# - Sudden-onset right lower-extremity pain.
# - Diminished pulses in right lower-extremity.
# - CTA demonstrates isolated filling defect in right common iliac artery.
# C. Conflicting findings: 病例中未提及右下肢症狀，且主要症狀為左腿無力與腰痛。
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness.
# - etiology/pathology: Status post L3-4 posterior fusion surgery, marked scoliosis, retrolisthesis, annular bulging discs, neuroforaminal narrowing, Modic changes, aneurysmal dilatation of abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中缺乏 atrial fibrillation、右下肢症狀及 CTA 所示右髂動脈填充缺損等必要條件。
#
# Key Word: atrial fibrillation, right lower-extremity pain, iliac artery occlusion
# ================================================================================
# Variate 48:
# Topic: Left Lower Quadrant Pain
#
# Variant:
# Left lower quadrant pain. Suspected complication(s) of diverticulitis. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: CT abdomen and pelvis with IV contrast
# May Be Appropriate: Fluoroscopy contrast enema
# May Be Appropriate: Fluoroscopy cystography
# May Be Appropriate: MRI abdomen and pelvis without and with IV contrast
# May Be Appropriate: MRI abdomen and pelvis without IV contrast
# May Be Appropriate: CT abdomen and pelvis without IV contrast
# May Be Appropriate: CT pelvis with bladder contrast (CT cystography)
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: None.
# B. Missing required findings: Left lower quadrant pain, suspected complication(s) of diverticulitis.
# C. Conflicting findings: The patient presents with low back pain and walking disturbance, not left lower quadrant pain or diverticulitis-related symptoms.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness, structural abnormalities in the lumbar spine, aneurysmal dilatation of the abdominal aorta.
# - etiology/pathology: Degenerative spine changes, aneurysmal dilatation of the abdominal aorta.
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of the abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例的主要症狀為腰痛及步態異常，與 variant 聚焦的左下腹痛及憩室炎併發症無關。
#
# Key Word: 左下腹痛
# ================================================================================
# Variate 49:
# Topic: Suspected Osteomyelitis, Septic Arthritis, or Soft Tissue Infection (Excluding Spine and Diabetic Foot)
#
# Variant:
# Suspected osteomyelitis or septic arthritis or soft tissue infection (excluding spine and diabetic foot). Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography area of interest
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: None.
# B. Missing required findings: Suspected osteomyelitis, septic arthritis, or soft tissue infection (excluding spine and diabetic foot).
# C. Conflicting findings: The case focuses on lumbar spine pathology and vascular abnormalities, not on infection-related conditions.
#
# 病例關鍵資訊:
# - primary symptom: Low back pain.
# - associated findings: Walking disturbance with left leg weakness; structural abnormalities (e.g., scoliosis, retrolisthesis, annular bulging discs, neuroforaminal narrowing); aneurysmal dilatation of abdominal aorta.
# - etiology/pathology: Degenerative spine changes, post-surgical status, vascular abnormality (aneurysm).
# - red flags: Persistent pain, neurologic deficit, aneurysmal dilatation of abdominal aorta.
# - imaging phase: Follow-up.
#
# **綜合評估: 不適合**
#
# 主要理由: 病例中無骨髓炎、膿毒性關節炎或軟組織感染的相關病因或懷疑。
#
# Key Word: Osteomyelitis, septic arthritis, soft tissue infection.
# ================================================================================
# Variate 50:
# Topic: Chronic Ankle Pain
#
# Variant:
# Chronic ankle pain. Ankle radiographs normal, suspected osteochondral lesion. Next study.
#
# Recommended Procedures:
# Usually Appropriate: MRI ankle without IV contrast
# May Be Appropriate: MR arthrography ankle
# May Be Appropriate: CT ankle without IV contrast
# May Be Appropriate: CT arthrography ankle
# May Be Appropriate: Bone scan with SPECT or SPECT/CT ankle
#
#
# --- Filter Reason ---
# 發現:
# A. Matching findings: 無。
# B. Missing required findings: 慢性踝痛、踝部X光正常、懷疑骨軟骨病變。
# C. Conflicting findings: 病例主要症狀為腰痛及步態障礙，無踝部相關症狀或病理。
#
# 病例關鍵資訊:
# - primary symptom: 腰痛。
# - associated findings: 步態障礙、左腿無力。
# - etiology/pathology: 腰椎退行性病變（包括椎間盤突出、神經孔狹窄、Modic變化等）；腹主動脈瘤伴附壁血栓形成。
# - red flags: 持續性腰痛、神經功能缺損、腹主動脈瘤。
# - imaging phase: 隨訪。
#
# **綜合評估: 不適合**
#
# 主要理由: 病例主要症狀及病理集中於腰椎及腹部，與variant的慢性踝痛及骨軟骨病變診斷場景完全不符。
#
# Key Word: 腰痛、步態障礙、神經孔狹窄。
# ================================================================================

# %%
variate_blocks = []

for res in results:

    variate_key = f"variate {res['index']}"

    decision_match = re.search(r"綜合評估.*?(適合|不適合)", res['reason'])
    final_decision = decision_match.group(1) if decision_match else "未知"

    reason_match = re.search(r"主要理由[:：]\s*(.+)", res['reason'])
    main_reason = reason_match.group(1).strip() if reason_match else ""

    key_word_match = re.search(r"Key Word[:：]\s*(.+)", res['reason'])
    key_word = key_word_match.group(1).strip() if key_word_match else ""

    block = {
        "variate": res['content'],
        "decision": final_decision,
        "main_reason": main_reason,
        "key_word": key_word,
        "text": res['reason']
    }

    variate_blocks.append(block)

# %%
def parse_variate_result(block):

    if block.get("decision") != "適合":
        return None

    return {
        "variate": block["variate"],
        "decision": block["decision"],
        "main_reason": block["main_reason"],
        "key_word": block["key_word"],
    }

# %%
results = []

for b in variate_blocks:
    r = parse_variate_result(b)
    if r:
        results.append(r)

for i, r in enumerate(results, 1):

    print(f"{i}:")
    print(r["variate"])
    print()
    print(f"綜合評估: {r['decision']}")
    print(f"主要理由: {r['main_reason']}")
    print(f"Key Word: {r['key_word']}")
    print("\n" + "-"*60 + "\n")
# Out:
# 1:
#
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain without or with myelopathy or radiculopathy. One or more of the following: low-velocity trauma, osteoporosis, elderly individual, or chronic steroid use. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography thoracic spine
# Usually Appropriate: MRI thoracic spine without IV contrast
# Usually Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: MRI thoracic spine without and with IV contrast
# May Be Appropriate: Bone scan whole body
# May Be Appropriate: Bone scan with SPECT or SPECT/CT thoracic spine
#
#
# 綜合評估: 適合
# 主要理由: 病例中 thoracic spine 的結構異常（scoliosis 和 Modic degeneration）與 variant 的 thoracic back pain 描述一致。
# Key Word: Thoracic spine scoliosis, Modic degeneration
#
# ------------------------------------------------------------
#
# 2:
#
# Topic: Low Back Pain
#
# Variant:
# Low back pain with or without radiculopathy. One or more of the following: low- velocity trauma, osteoporosis, elderly individual, or chronic steroid use. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography lumbar spine
# Usually Appropriate: MRI lumbar spine without IV contrast
# Usually Appropriate: CT lumbar spine without IV contrast
# May Be Appropriate: MRI lumbar spine without and with IV contrast
# May Be Appropriate: CT myelography lumbar spine
#
#
# 綜合評估: 適合
# 主要理由: 該病例符合「Low back pain with or without radiculopathy」的描述，且患者為高齡者並伴有結構性脊柱異常及神經症狀。
# Key Word: Low back pain, radiculopathy, elderly individual, structural abnormalities.
#
# ------------------------------------------------------------
#
# 3:
#
# Topic: Low Back Pain
#
# Variant:
# Subacute or chronic low back pain with or without radiculopathy. Surgery or intervention candidate with persistent or progressive symptoms during or following 6 weeks of optimal medical management. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI lumbar spine without IV contrast
# May Be Appropriate: Radiography lumbar spine
# May Be Appropriate: MRI lumbar spine without and with IV contrast
# May Be Appropriate: Bone scan whole body with SPECT or SPECT/CT complete spine
# May Be Appropriate: CT lumbar spine without IV contrast
# May Be Appropriate: CT myelography lumbar spine
#
#
# 綜合評估: 適合
# 主要理由: 病例符合「慢性下背痛合併神經根病變，且症狀持續6個月以上，為手術候選者」的情境。
# Key Word: 慢性下背痛、神經根病變、手術候選者
#
# ------------------------------------------------------------
#
# 4:
#
# Topic: Low Back Pain
#
# Variant:
# Low back pain with history of prior lumbar surgery and with or without radiculopathy. New or progressing symptoms or clinical findings. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography lumbar spine
# Usually Appropriate: MRI lumbar spine without and with IV contrast
# Usually Appropriate: MRI lumbar spine without IV contrast
# May Be Appropriate: CT lumbar spine without IV contrast
# May Be Appropriate: CT myelography lumbar spine
#
#
# 綜合評估: 適合
# 主要理由: 病例符合「Low back pain with history of prior lumbar surgery」且有新症狀（步行障礙及左腿無力），並伴有紅旗徵象（腹主動脈瘤擴張）。
# Key Word: Low back pain, prior lumbar surgery, new symptoms, red flag.
#
# ------------------------------------------------------------
#
# 5:
#
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain with myelopathy or radiculopathy. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI thoracic spine without IV contrast
# May Be Appropriate: Radiography thoracic spine
# May Be Appropriate: MRI thoracic spine without and with IV contrast
# May Be Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: CT myelography thoracic spine
#
#
# 綜合評估: 適合
# 主要理由: 病例中有胸椎側彎與神經根病變，且存在持續性疼痛與神經學缺損，符合該 variant 的疾病與症狀描述。
# Key Word: Thoracic back pain, myelopathy or radiculopathy, persistent pain.
#
# ------------------------------------------------------------
#
# 6:
#
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain without or with myelopathy or radiculopathy. Post thoracic spine surgery. Follow-up imaging.
#
# Recommended Procedures:
# Usually Appropriate: Radiography thoracic spine
# Usually Appropriate: MRI thoracic spine without and with IV contrast
# Usually Appropriate: MRI thoracic spine without IV contrast
# Usually Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: CT myelography thoracic spine
#
#
# 綜合評估: 適合
# 主要理由: 病例中有胸椎側彎與術後狀態，且處於追蹤影像階段，符合該 variant 的診斷情境。
# Key Word: Thoracic spine, post thoracic spine surgery, follow-up imaging.
#
# ------------------------------------------------------------
#
# 7:
#
# Topic: Thoracic Back Pain
#
# Variant:
# Adult. Thoracic back pain without or with myelopathy or radiculopathy. Radiograph shows bone destruction or fracture or spinal deformity. Next imaging study.
#
# Recommended Procedures:
# Usually Appropriate: MRI thoracic spine without and with IV contrast
# Usually Appropriate: MRI thoracic spine without IV contrast
# Usually Appropriate: CT thoracic spine without IV contrast
# May Be Appropriate: CT myelography thoracic spine
#
#
# 綜合評估: 適合
# 主要理由: 病例中提到胸椎脊柱變形（marked scoliosis of thoracic spine），符合該 variant 的診斷情境。
# Key Word: Spinal deformity.
#
# ------------------------------------------------------------
#
# 8:
#
# Topic: Myelopathy
#
# Variant:
# Chronic or progressive myelopathy. Initial imaging.
#
# Recommended Procedures:
# Usually Appropriate: MRI spine area of interest without and with IV contrast
# Usually Appropriate: MRI spine area of interest without IV contrast
# May Be Appropriate: CT myelography spine area of interest
# May Be Appropriate: CT spine area of interest with IV contrast
# May Be Appropriate: CT spine area of interest without IV contrast
#
#
# 綜合評估: 適合
# 主要理由: 該病例符合慢性或進行性脊髓病變的症狀與脊柱結構異常，且有持續性疼痛與神經功能缺損的紅旗徵象。
# Key Word: 慢性脊髓病變、脊柱結構異常、神經功能缺損
#
# ------------------------------------------------------------
